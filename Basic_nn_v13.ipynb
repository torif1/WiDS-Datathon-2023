# %% [markdown]
# Link to another tutorial site that I was using to figure this out:
# https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing #Convert categorical data to neumeric values

from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/widsdatathon2023/train_data.csv
# /kaggle/input/widsdatathon2023/test_data.csv
# /kaggle/input/widsdatathon2023/sample_solution.csv

# %%
keep_columns=['lat','month','contest-tmp2m-14d__tmp2m',
              'climateregions__climateregion','lon']
X_columns=[['lat','month',
              'climateregions__climateregion','lon']]

# %%
def seperate_monthly(df):
    df[['month','day','year']]=df.startdate.str.split('/',expand=True)
    df=df.drop('day', axis=1)
    df=df.drop('startdate',axis=1)
    return df

# %%
def eliminate_columns(df):
    for col in df.columns:
        if col in keep_columns:
            print(col)
        else: 
            df=df.drop(col, axis=1)
    return df

# %%
#need to come up with a different way to do this, because it is not working
def seperate_y(df):
    y_df=df['contest-tmp2m-14d__tmp2m']
    X_df=df.drop('contest-tmp2m-14d__tmp2m',axis=1)
    return y_df,X_df

# %%
def normanlize_data(df,train_df):
    for column in df.columns:
        df[column] = df[column]  /  train_df[column].abs().max()
    return df

# %%
train_df=pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
train_df=train_df.dropna(axis=0)
test_df=pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
test_df=test_df.dropna(axis=0)
train_df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                          29.02                     31.64
# 1                          29.02                     31.64
# 2                          29.02                     31.64
# 3                          29.02                     31.64
# 4                          29.02                     31.64
# ...                          ...                       ...
# 375729                     23.13                     27.20
# 375730                     23.13                     27.20
# 375731                     23.13                     27.20
# 375732                     23.13                     27.20
# 375733                     23.13                     27.20
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                         29.57                    30.73
# 1                         29.57                    30.73
# 2                         29.57                    30.73
# 3                         29.57                    30.73
# 4                         29.57                    30.73
# ...                         ...                      ...
# 375729                    20.25                    24.43
# 375730                    20.25                    24.43
# 375731                    20.25                    24.43
# 375732                    20.25                    24.43
# 375733                    20.25                    24.43
#
#         nmme0-tmp2m-34w__cfsv20  ...  wind-vwnd-925-2010-11  \
# 0                         29.71  ...                 -27.68
# 1                         29.71  ...                 -21.13
# 2                         29.71  ...                 -10.72
# 3                         29.71  ...                   0.33
# 4                         29.71  ...                   9.83
# ...                         ...  ...                    ...
# 375729                    18.35  ...                 -15.64
# 375730                    18.35  ...                  -7.59
# 375731                    18.35  ...                  -6.25
# 375732                    18.35  ...                  -7.16
# 375733                    18.35  ...                 -12.36
#
#         wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  \
# 0                      -37.21                   8.32                   9.56
# 1                      -36.57                   8.77                  21.17
# 2                      -34.16                   6.99                  32.16
# 3                      -31.04                   6.17                  39.66
# 4                      -31.80                   7.47                  38.62
# ...                       ...                    ...                    ...
# 375729                 -75.68                  -3.09                   6.93
# 375730                 -76.42                 -13.55                  13.36
# 375731                 -70.65                 -23.93                  22.62
# 375732                 -57.67                 -33.55                  32.06
# 375733                 -44.67                 -32.46                  36.25
#
#         wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  \
# 0                       -2.03                  48.13                  28.09
# 1                        4.44                  48.60                  27.41
# 2                        5.01                  48.53                  19.21
# 3                       -1.41                  50.59                   8.29
# 4                       -5.21                  54.73                  -2.58
# ...                       ...                    ...                    ...
# 375729                 -16.69                  16.98                 -13.85
# 375730                 -15.96                  20.45                 -16.36
# 375731                 -16.71                  20.28                 -15.48
# 375732                 -16.07                  16.60                 -20.61
# 375733                 -12.72                  15.98                 -22.56
#
#         wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  wind-vwnd-925-2010-20
# 0                      -13.50                  11.90                   4.58
# 1                      -23.77                  15.44                   3.42
# 2                      -33.16                  15.11                   4.82
# 3                      -37.22                  18.24                   9.74
# 4                      -42.30                  21.91                  10.95
# ...                       ...                    ...                    ...
# 375729                  50.25                 -31.33                   0.77
# 375730                  51.65                 -30.73                  10.10
# 375731                  48.58                 -18.74                   9.28
# 375732                  39.23                 -16.26                  -0.22
# 375733                  32.53                 -21.89                  -1.20
#
# [352604 rows x 246 columns]

# %%
#Shuffeling the data
train_df = train_df.sample(frac = 1)

# %%
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
train_df['climateregions__climateregion']=le.fit_transform(train_df['climateregions__climateregion'])
test_df['climateregions__climateregion']=le.fit_transform(test_df['climateregions__climateregion'])

# %%
print('training set prep')
train_df=seperate_monthly(train_df)
#train_df=eliminate_columns(train_df)
print('test set prep')
test_df=seperate_monthly(test_df)
#test_df=eliminate_columns(test_df)
# Out:
# training set prep
# test set prep

# %%
train_df
# Out:
#          index       lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 217438  217438  0.681818  0.066667                              722.21
# 337259  337259  0.909091  0.900000                              218.48
# 302455  302455  0.863636  0.233333                               66.22
# 31586    31586  0.227273  0.700000                              227.30
# 194757  194757  0.636364  0.000000                              620.78
# ...        ...       ...       ...                                 ...
# 255329  255329  0.727273  0.866667                              186.77
# 229980  229980  0.681818  0.633333                               25.30
# 165251  165251  0.545455  0.633333                              286.40
# 239691  239691  0.727273  0.133333                              416.12
# 66289    66289  0.318182  0.700000                              164.95
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 217438                     22.61                     24.42
# 337259                     13.69                     19.51
# 302455                     -2.57                      0.33
# 31586                       2.02                      6.48
# 194757                     19.77                     19.33
# ...                          ...                       ...
# 255329                      0.10                      2.10
# 229980                      6.40                      9.36
# 165251                     17.41                     17.96
# 239691                      9.94                     10.60
# 66289                       1.04                      2.97
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 217438                    21.22                    23.70
# 337259                    14.56                    16.68
# 302455                    -2.90                     0.96
# 31586                      3.63                     4.94
# 194757                    16.91                    16.17
# ...                         ...                      ...
# 255329                     4.15                     2.29
# 229980                     6.70                     8.63
# 165251                    17.09                    14.61
# 239691                     8.77                    10.24
# 66289                      3.65                     2.69
#
#         nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 217438                    19.47                        22.27  ...
# 337259                    13.92                        15.70  ...
# 302455                     2.56                         1.87  ...
# 31586                      5.12                         7.23  ...
# 194757                    15.51                        16.34  ...
# ...                         ...                          ...  ...
# 255329                     1.22                         3.92  ...
# 229980                     9.36                         7.80  ...
# 165251                    13.79                        15.34  ...
# 239691                     9.75                        14.98  ...
# 66289                      4.18                         4.79  ...
#
#         wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 217438                 -18.81                  23.69                  28.89
# 337259                 -12.86                  26.61                 -19.73
# 302455                  27.44                  12.18                  19.25
# 31586                   71.65                 -29.17                  26.04
# 194757                 -58.61                  69.03                  32.46
# ...                       ...                    ...                    ...
# 255329                  27.60                  16.94                 -48.75
# 229980                  15.15                  44.19                 -58.10
# 165251                 101.35                  19.76                 -57.00
# 239691                  -0.78                   7.69                  14.61
# 66289                  -22.54                 -11.02                 -30.09
#
#         wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 217438                  -4.10                 -12.52                  21.06
# 337259                 -26.18                 -10.10                   6.57
# 302455                  -5.68                  43.03                  24.88
# 31586                   -8.68                  -9.32                  24.51
# 194757                   6.34                   2.54                  22.81
# ...                       ...                    ...                    ...
# 255329                 -20.25                  -8.32                 -11.92
# 229980                  -0.02                  -1.79                 -20.85
# 165251                  -4.14                 -23.52                   2.83
# 239691                 -12.08                 -37.44                  21.36
# 66289                  -87.24                  23.76                   7.26
#
#         wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 217438                  13.05                   2.48      7    15
# 337259                   2.80                 -11.04      5    15
# 302455                   3.76                  20.07      3    16
# 31586                   -0.03                 -45.96      2    15
# 194757                  25.66                  16.15      7    15
# ...                       ...                    ...    ...   ...
# 255329                  20.34                  46.32      3    15
# 229980                   5.15                  42.38     11    15
# 165251                  41.72                  32.62     10    14
# 239691                  38.46                   8.68      6    16
# 66289                   17.39                  11.89      1    16
#
# [352604 rows x 247 columns]

# %%
test_df
# Out:
#         index  lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333                              339.88
# 1      375735  0.0  0.833333                              334.63
# 2      375736  0.0  0.833333                              337.83
# 3      375737  0.0  0.833333                              345.81
# 4      375738  0.0  0.833333                              357.39
# ...       ...  ...       ...                                 ...
# 31349  407083  1.0  0.866667                               62.72
# 31350  407084  1.0  0.866667                               73.41
# 31351  407085  1.0  0.866667                               70.00
# 31352  407086  1.0  0.866667                               79.81
# 31353  407087  1.0  0.866667                               86.17
#
#        nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                         30.88                     30.92
# 1                         30.88                     30.92
# 2                         30.88                     30.92
# 3                         30.88                     30.92
# 4                         30.88                     30.92
# ...                         ...                       ...
# 31349                      4.60                      8.71
# 31350                      4.60                      8.71
# 31351                      4.60                      8.71
# 31352                      4.60                      8.71
# 31353                      4.60                      8.71
#
#        nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                        29.17                    31.02
# 1                        29.17                    31.02
# 2                        29.17                    31.02
# 3                        29.17                    31.02
# 4                        29.17                    31.02
# ...                        ...                      ...
# 31349                     6.05                    10.08
# 31350                     6.05                    10.08
# 31351                     6.05                    10.08
# 31352                     6.05                    10.08
# 31353                     6.05                    10.08
#
#        nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 0                        29.47                        30.93  ...
# 1                        29.47                        30.93  ...
# 2                        29.47                        30.93  ...
# 3                        29.47                        30.93  ...
# 4                        29.47                        30.93  ...
# ...                        ...                          ...  ...
# 31349                     6.39                         8.42  ...
# 31350                     6.39                         8.42  ...
# 31351                     6.39                         8.42  ...
# 31352                     6.39                         8.42  ...
# 31353                     6.39                         8.42  ...
#
#        wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 0                     -29.25                  40.88                  -8.31
# 1                     -28.62                  45.37                  -5.42
# 2                     -27.67                  49.76                  -1.31
# 3                     -19.32                  52.62                  -0.44
# 4                      -9.89                  51.23                  -7.57
# ...                      ...                    ...                    ...
# 31349                  32.39                  38.82                   7.42
# 31350                  26.23                  37.64                  13.01
# 31351                  21.06                  36.53                  14.15
# 31352                  20.42                  36.05                   6.38
# 31353                  26.17                  30.68                  -3.24
#
#        wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 0                      14.91                 -24.62                  31.05
# 1                      16.97                 -23.94                  28.84
# 2                      21.44                 -19.06                  26.85
# 3                      21.65                 -23.12                  23.70
# 4                      19.86                 -30.56                  20.66
# ...                      ...                    ...                    ...
# 31349                  11.75                 -23.62                  -0.24
# 31350                  17.84                 -22.05                  -3.03
# 31351                  23.12                 -25.60                  -5.88
# 31352                  29.00                 -27.06                  -1.42
# 31353                  27.70                 -28.75                   0.15
#
#        wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 0                     -23.69                   6.27     11    22
# 1                     -20.61                  14.16     11    22
# 2                     -16.78                  13.42     11    22
# 3                     -18.62                  10.69     11    22
# 4                     -25.08                  19.64     11    22
# ...                      ...                    ...    ...   ...
# 31349                  -5.94                  51.23     12    22
# 31350                   1.31                  51.45     12    22
# 31351                   9.32                  45.32     12    22
# 31352                  16.06                  31.88     12    22
# 31353                  16.64                  19.27     12    22
#
# [31354 rows x 246 columns]

# %%
train_df=train_df.astype('float')
test_df=test_df.astype('float')

# %%
y_train_df=train_df['contest-tmp2m-14d__tmp2m']
X_train_df=train_df.drop('contest-tmp2m-14d__tmp2m', axis=1)
type(y_train_df)
y_train_df=y_train_df.to_frame()
type(y_train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_df=normanlize_data(X_train_df,train_df)
test_df=normanlize_data(test_df,train_df)

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352604 entries, 217438 to 66289
# Columns: 246 entries, index to year
# dtypes: float64(246)
# memory usage: 664.5 MB

# %% [markdown]
# # Model

# %%
NN_model = Sequential()

#I might need to change the input_dim to give the actual dimentions
#Instead of being just 1
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = 246, activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               31616
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 262,273
# Trainable params: 262,273
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-22 14:18:49.725830: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-02-22 14:18:49.725888: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
checkpoint_name = 'Weights--.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train_df, y_train_df, epochs=50, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.0949 - mean_absolute_error: 1.0949
# Epoch 1: val_loss improved from inf to 0.85154, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 1.0949 - mean_absolute_error: 1.0949 - val_loss: 0.8515 - val_mean_absolute_error: 0.8515
# Epoch 2/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.8223 - mean_absolute_error: 0.8223
# Epoch 2: val_loss improved from 0.85154 to 0.83694, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 41s 5ms/step - loss: 0.8223 - mean_absolute_error: 0.8223 - val_loss: 0.8369 - val_mean_absolute_error: 0.8369
# Epoch 3/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.7448 - mean_absolute_error: 0.7448
# Epoch 3: val_loss improved from 0.83694 to 0.76953, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.7448 - mean_absolute_error: 0.7448 - val_loss: 0.7695 - val_mean_absolute_error: 0.7695
# Epoch 4/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.6980 - mean_absolute_error: 0.6980
# Epoch 4: val_loss improved from 0.76953 to 0.63366, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.6980 - mean_absolute_error: 0.6980 - val_loss: 0.6337 - val_mean_absolute_error: 0.6337
# Epoch 5/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.6634 - mean_absolute_error: 0.6634
# Epoch 5: val_loss did not improve from 0.63366
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.6634 - mean_absolute_error: 0.6634 - val_loss: 0.6553 - val_mean_absolute_error: 0.6553
# Epoch 6/50
# 8803/8816 [============================>.] - ETA: 0s - loss: 0.6349 - mean_absolute_error: 0.6349
# Epoch 6: val_loss did not improve from 0.63366
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.6348 - mean_absolute_error: 0.6348 - val_loss: 0.7118 - val_mean_absolute_error: 0.7118
# Epoch 7/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.6119 - mean_absolute_error: 0.6119
# Epoch 7: val_loss improved from 0.63366 to 0.60509, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.6119 - mean_absolute_error: 0.6119 - val_loss: 0.6051 - val_mean_absolute_error: 0.6051
# Epoch 8/50
# 8805/8816 [============================>.] - ETA: 0s - loss: 0.5970 - mean_absolute_error: 0.5970
# Epoch 8: val_loss improved from 0.60509 to 0.59647, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.5969 - mean_absolute_error: 0.5969 - val_loss: 0.5965 - val_mean_absolute_error: 0.5965
# Epoch 9/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5794 - mean_absolute_error: 0.5794
# Epoch 9: val_loss improved from 0.59647 to 0.56770, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.5794 - mean_absolute_error: 0.5794 - val_loss: 0.5677 - val_mean_absolute_error: 0.5677
# Epoch 10/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5647 - mean_absolute_error: 0.5647
# Epoch 10: val_loss improved from 0.56770 to 0.56370, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.5648 - mean_absolute_error: 0.5648 - val_loss: 0.5637 - val_mean_absolute_error: 0.5637
# Epoch 11/50
# 8805/8816 [============================>.] - ETA: 0s - loss: 0.5553 - mean_absolute_error: 0.5553
# Epoch 11: val_loss did not improve from 0.56370
# 8816/8816 [==============================] - 41s 5ms/step - loss: 0.5554 - mean_absolute_error: 0.5554 - val_loss: 0.6167 - val_mean_absolute_error: 0.6167
# Epoch 12/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5437 - mean_absolute_error: 0.5437
# Epoch 12: val_loss did not improve from 0.56370
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.5436 - mean_absolute_error: 0.5436 - val_loss: 0.6317 - val_mean_absolute_error: 0.6317
# Epoch 13/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5351 - mean_absolute_error: 0.5351
# Epoch 13: val_loss improved from 0.56370 to 0.54611, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.5351 - mean_absolute_error: 0.5351 - val_loss: 0.5461 - val_mean_absolute_error: 0.5461
# Epoch 14/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.5248 - mean_absolute_error: 0.5248
# Epoch 14: val_loss did not improve from 0.54611
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.5248 - mean_absolute_error: 0.5248 - val_loss: 0.6431 - val_mean_absolute_error: 0.6431
# Epoch 15/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.5184 - mean_absolute_error: 0.5184
# Epoch 15: val_loss improved from 0.54611 to 0.54415, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.5184 - mean_absolute_error: 0.5184 - val_loss: 0.5442 - val_mean_absolute_error: 0.5442
# Epoch 16/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5111 - mean_absolute_error: 0.5111
# Epoch 16: val_loss improved from 0.54415 to 0.50918, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 41s 5ms/step - loss: 0.5111 - mean_absolute_error: 0.5111 - val_loss: 0.5092 - val_mean_absolute_error: 0.5092
# Epoch 17/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.5037 - mean_absolute_error: 0.5037
# Epoch 17: val_loss improved from 0.50918 to 0.49716, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.5037 - mean_absolute_error: 0.5037 - val_loss: 0.4972 - val_mean_absolute_error: 0.4972
# Epoch 18/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4982 - mean_absolute_error: 0.4982
# Epoch 18: val_loss improved from 0.49716 to 0.47604, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4983 - mean_absolute_error: 0.4983 - val_loss: 0.4760 - val_mean_absolute_error: 0.4760
# Epoch 19/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4918 - mean_absolute_error: 0.4918
# Epoch 19: val_loss did not improve from 0.47604
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4918 - mean_absolute_error: 0.4918 - val_loss: 0.4934 - val_mean_absolute_error: 0.4934
# Epoch 20/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4865 - mean_absolute_error: 0.4865
# Epoch 20: val_loss improved from 0.47604 to 0.47381, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4865 - mean_absolute_error: 0.4865 - val_loss: 0.4738 - val_mean_absolute_error: 0.4738
# Epoch 21/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4813 - mean_absolute_error: 0.4813
# Epoch 21: val_loss did not improve from 0.47381
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4813 - mean_absolute_error: 0.4813 - val_loss: 0.4832 - val_mean_absolute_error: 0.4832
# Epoch 22/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.4751 - mean_absolute_error: 0.4751
# Epoch 22: val_loss did not improve from 0.47381
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4751 - mean_absolute_error: 0.4751 - val_loss: 0.5295 - val_mean_absolute_error: 0.5295
# Epoch 23/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4715 - mean_absolute_error: 0.4715
# Epoch 23: val_loss improved from 0.47381 to 0.45864, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4715 - mean_absolute_error: 0.4715 - val_loss: 0.4586 - val_mean_absolute_error: 0.4586
# Epoch 24/50
# 8805/8816 [============================>.] - ETA: 0s - loss: 0.4670 - mean_absolute_error: 0.4670
# Epoch 24: val_loss did not improve from 0.45864
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4670 - mean_absolute_error: 0.4670 - val_loss: 0.4869 - val_mean_absolute_error: 0.4869
# Epoch 25/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4624 - mean_absolute_error: 0.4624
# Epoch 25: val_loss did not improve from 0.45864
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4624 - mean_absolute_error: 0.4624 - val_loss: 0.4607 - val_mean_absolute_error: 0.4607
# Epoch 26/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.4573 - mean_absolute_error: 0.4573
# Epoch 26: val_loss improved from 0.45864 to 0.45222, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4573 - mean_absolute_error: 0.4573 - val_loss: 0.4522 - val_mean_absolute_error: 0.4522
# Epoch 27/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4535 - mean_absolute_error: 0.4535
# Epoch 27: val_loss improved from 0.45222 to 0.44287, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4535 - mean_absolute_error: 0.4535 - val_loss: 0.4429 - val_mean_absolute_error: 0.4429
# Epoch 28/50
# 8805/8816 [============================>.] - ETA: 0s - loss: 0.4502 - mean_absolute_error: 0.4502
# Epoch 28: val_loss did not improve from 0.44287
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4502 - mean_absolute_error: 0.4502 - val_loss: 0.4790 - val_mean_absolute_error: 0.4790
# Epoch 29/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4474 - mean_absolute_error: 0.4474
# Epoch 29: val_loss did not improve from 0.44287
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4474 - mean_absolute_error: 0.4474 - val_loss: 0.4531 - val_mean_absolute_error: 0.4531
# Epoch 30/50
# 8816/8816 [==============================] - ETA: 0s - loss: 0.4429 - mean_absolute_error: 0.4429
# Epoch 30: val_loss did not improve from 0.44287
# 8816/8816 [==============================] - 51s 6ms/step - loss: 0.4429 - mean_absolute_error: 0.4429 - val_loss: 0.4516 - val_mean_absolute_error: 0.4516
# Epoch 31/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4392 - mean_absolute_error: 0.4392
# Epoch 31: val_loss did not improve from 0.44287
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4392 - mean_absolute_error: 0.4392 - val_loss: 0.4498 - val_mean_absolute_error: 0.4498
# Epoch 32/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4369 - mean_absolute_error: 0.4369
# Epoch 32: val_loss improved from 0.44287 to 0.44177, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4369 - mean_absolute_error: 0.4369 - val_loss: 0.4418 - val_mean_absolute_error: 0.4418
# Epoch 33/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.4351 - mean_absolute_error: 0.4351
# Epoch 33: val_loss improved from 0.44177 to 0.43920, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 50s 6ms/step - loss: 0.4351 - mean_absolute_error: 0.4351 - val_loss: 0.4392 - val_mean_absolute_error: 0.4392
# Epoch 34/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.4324 - mean_absolute_error: 0.4324
# Epoch 34: val_loss did not improve from 0.43920
# 8816/8816 [==============================] - 46s 5ms/step - loss: 0.4324 - mean_absolute_error: 0.4324 - val_loss: 0.4630 - val_mean_absolute_error: 0.4630
# Epoch 35/50
# 8805/8816 [============================>.] - ETA: 0s - loss: 0.4280 - mean_absolute_error: 0.4280
# Epoch 35: val_loss did not improve from 0.43920
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.4280 - mean_absolute_error: 0.4280 - val_loss: 0.4517 - val_mean_absolute_error: 0.4517
# Epoch 36/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4257 - mean_absolute_error: 0.4257
# Epoch 36: val_loss improved from 0.43920 to 0.42894, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 45s 5ms/step - loss: 0.4257 - mean_absolute_error: 0.4257 - val_loss: 0.4289 - val_mean_absolute_error: 0.4289
# Epoch 37/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.4223 - mean_absolute_error: 0.4223
# Epoch 37: val_loss did not improve from 0.42894
# 8816/8816 [==============================] - 46s 5ms/step - loss: 0.4223 - mean_absolute_error: 0.4223 - val_loss: 0.4429 - val_mean_absolute_error: 0.4429
# Epoch 38/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4209 - mean_absolute_error: 0.4209
# Epoch 38: val_loss did not improve from 0.42894
# 8816/8816 [==============================] - 43s 5ms/step - loss: 0.4210 - mean_absolute_error: 0.4210 - val_loss: 0.4500 - val_mean_absolute_error: 0.4500
# Epoch 39/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.4185 - mean_absolute_error: 0.4185
# Epoch 39: val_loss improved from 0.42894 to 0.42158, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 42s 5ms/step - loss: 0.4185 - mean_absolute_error: 0.4185 - val_loss: 0.4216 - val_mean_absolute_error: 0.4216
# Epoch 40/50
# 8816/8816 [==============================] - ETA: 0s - loss: 0.4156 - mean_absolute_error: 0.4156
# Epoch 40: val_loss improved from 0.42158 to 0.41526, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4156 - mean_absolute_error: 0.4156 - val_loss: 0.4153 - val_mean_absolute_error: 0.4153
# Epoch 41/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4156 - mean_absolute_error: 0.4156
# Epoch 41: val_loss did not improve from 0.41526
# 8816/8816 [==============================] - 41s 5ms/step - loss: 0.4156 - mean_absolute_error: 0.4156 - val_loss: 0.4161 - val_mean_absolute_error: 0.4161
# Epoch 42/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.4105 - mean_absolute_error: 0.4105
# Epoch 42: val_loss did not improve from 0.41526
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4105 - mean_absolute_error: 0.4105 - val_loss: 0.4509 - val_mean_absolute_error: 0.4509
# Epoch 43/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.4102 - mean_absolute_error: 0.4102
# Epoch 43: val_loss improved from 0.41526 to 0.40650, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 36s 4ms/step - loss: 0.4102 - mean_absolute_error: 0.4102 - val_loss: 0.4065 - val_mean_absolute_error: 0.4065
# Epoch 44/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4077 - mean_absolute_error: 0.4077
# Epoch 44: val_loss did not improve from 0.40650
# 8816/8816 [==============================] - 36s 4ms/step - loss: 0.4077 - mean_absolute_error: 0.4077 - val_loss: 0.4175 - val_mean_absolute_error: 0.4175
# Epoch 45/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.4056 - mean_absolute_error: 0.4056
# Epoch 45: val_loss did not improve from 0.40650
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.4056 - mean_absolute_error: 0.4056 - val_loss: 0.4244 - val_mean_absolute_error: 0.4244
# Epoch 46/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4041 - mean_absolute_error: 0.4041
# Epoch 46: val_loss did not improve from 0.40650
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4041 - mean_absolute_error: 0.4041 - val_loss: 0.4683 - val_mean_absolute_error: 0.4683
# Epoch 47/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.4028 - mean_absolute_error: 0.4028
# Epoch 47: val_loss improved from 0.40650 to 0.40485, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4029 - mean_absolute_error: 0.4029 - val_loss: 0.4048 - val_mean_absolute_error: 0.4048
# Epoch 48/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4002 - mean_absolute_error: 0.4002
# Epoch 48: val_loss did not improve from 0.40485
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4002 - mean_absolute_error: 0.4002 - val_loss: 0.4331 - val_mean_absolute_error: 0.4331
# Epoch 49/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.3977 - mean_absolute_error: 0.3977
# Epoch 49: val_loss did not improve from 0.40485
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.3977 - mean_absolute_error: 0.3977 - val_loss: 0.4318 - val_mean_absolute_error: 0.4318
# Epoch 50/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.3960 - mean_absolute_error: 0.3960
# Epoch 50: val_loss improved from 0.40485 to 0.39823, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.3960 - mean_absolute_error: 0.3960 - val_loss: 0.3982 - val_mean_absolute_error: 0.3982

# %%
# Load wights file of the best model :
wights_file = f'Weights--.hdf5'  # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(test_df)
# Out:
# 980/980 [==============================] - 2s 2ms/step

# %% [markdown]
# # Saving Dataset in correct format

# %%
predictions
# Out:
# array([[26.040018  ],
#        [26.159216  ],
#        [26.143396  ],
#        ...,
#        [ 0.99882   ],
#        [ 0.8314048 ],
#        [ 0.28296733]], dtype=float32)

# %%
final=pd.DataFrame(predictions,columns=['contest-tmp2m-14d__tmp2m'])

# %%
i=375734
final['index']=0
while i<407088:
    final['index'][i-375734]=i
    i+=1
final
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     26.040018  375734
# 1                     26.159216  375735
# 2                     26.143396  375736
# 3                     26.220587  375737
# 4                     26.255718  375738
# ...                         ...     ...
# 31349                  2.504152  407083
# 31350                  1.904931  407084
# 31351                  0.998820  407085
# 31352                  0.831405  407086
# 31353                  0.282967  407087
#
# [31354 rows x 2 columns]

# %%
final.to_csv('/kaggle/working/wetherprediction.csv',index=False)
