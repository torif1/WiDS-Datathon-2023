# %% [markdown]
# Link to another tutorial site that I was using to figure this out:
# https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing #Convert categorical data to neumeric values

from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/widsdatathon2023/train_data.csv
# /kaggle/input/widsdatathon2023/test_data.csv
# /kaggle/input/widsdatathon2023/sample_solution.csv

# %%
keep_columns=['lat','month','contest-tmp2m-14d__tmp2m',
              'climateregions__climateregion','lon']
X_columns=[['lat','month',
              'climateregions__climateregion','lon']]

# %%
def seperate_monthly(df):
    df[['month','day','year']]=df.startdate.str.split('/',expand=True)
    df=df.drop('day', axis=1)
    df=df.drop('startdate',axis=1)
    return df

# %%
def eliminate_columns(df):
    for col in df.columns:
        if col in keep_columns:
            print(col)
        else: 
            df=df.drop(col, axis=1)
    return df

# %%
#need to come up with a different way to do this, because it is not working
def seperate_y(df):
    y_df=df['contest-tmp2m-14d__tmp2m']
    X_df=df.drop('contest-tmp2m-14d__tmp2m',axis=1)
    return y_df,X_df

# %%
def normanlize_data(df,train_df):
    for column in df.columns:
        df[column] = df[column]  /  train_df[column].abs().max()
    return df

# %%
train_df=pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
train_df=train_df.dropna(axis=0)
test_df=pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
test_df=test_df.dropna(axis=0)
train_df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                          29.02                     31.64
# 1                          29.02                     31.64
# 2                          29.02                     31.64
# 3                          29.02                     31.64
# 4                          29.02                     31.64
# ...                          ...                       ...
# 375729                     23.13                     27.20
# 375730                     23.13                     27.20
# 375731                     23.13                     27.20
# 375732                     23.13                     27.20
# 375733                     23.13                     27.20
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                         29.57                    30.73
# 1                         29.57                    30.73
# 2                         29.57                    30.73
# 3                         29.57                    30.73
# 4                         29.57                    30.73
# ...                         ...                      ...
# 375729                    20.25                    24.43
# 375730                    20.25                    24.43
# 375731                    20.25                    24.43
# 375732                    20.25                    24.43
# 375733                    20.25                    24.43
#
#         nmme0-tmp2m-34w__cfsv20  ...  wind-vwnd-925-2010-11  \
# 0                         29.71  ...                 -27.68
# 1                         29.71  ...                 -21.13
# 2                         29.71  ...                 -10.72
# 3                         29.71  ...                   0.33
# 4                         29.71  ...                   9.83
# ...                         ...  ...                    ...
# 375729                    18.35  ...                 -15.64
# 375730                    18.35  ...                  -7.59
# 375731                    18.35  ...                  -6.25
# 375732                    18.35  ...                  -7.16
# 375733                    18.35  ...                 -12.36
#
#         wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  \
# 0                      -37.21                   8.32                   9.56
# 1                      -36.57                   8.77                  21.17
# 2                      -34.16                   6.99                  32.16
# 3                      -31.04                   6.17                  39.66
# 4                      -31.80                   7.47                  38.62
# ...                       ...                    ...                    ...
# 375729                 -75.68                  -3.09                   6.93
# 375730                 -76.42                 -13.55                  13.36
# 375731                 -70.65                 -23.93                  22.62
# 375732                 -57.67                 -33.55                  32.06
# 375733                 -44.67                 -32.46                  36.25
#
#         wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  \
# 0                       -2.03                  48.13                  28.09
# 1                        4.44                  48.60                  27.41
# 2                        5.01                  48.53                  19.21
# 3                       -1.41                  50.59                   8.29
# 4                       -5.21                  54.73                  -2.58
# ...                       ...                    ...                    ...
# 375729                 -16.69                  16.98                 -13.85
# 375730                 -15.96                  20.45                 -16.36
# 375731                 -16.71                  20.28                 -15.48
# 375732                 -16.07                  16.60                 -20.61
# 375733                 -12.72                  15.98                 -22.56
#
#         wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  wind-vwnd-925-2010-20
# 0                      -13.50                  11.90                   4.58
# 1                      -23.77                  15.44                   3.42
# 2                      -33.16                  15.11                   4.82
# 3                      -37.22                  18.24                   9.74
# 4                      -42.30                  21.91                  10.95
# ...                       ...                    ...                    ...
# 375729                  50.25                 -31.33                   0.77
# 375730                  51.65                 -30.73                  10.10
# 375731                  48.58                 -18.74                   9.28
# 375732                  39.23                 -16.26                  -0.22
# 375733                  32.53                 -21.89                  -1.20
#
# [352604 rows x 246 columns]

# %%
#Shuffeling the data
train_df = train_df.sample(frac = 1)

# %%
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
train_df['climateregions__climateregion']=le.fit_transform(train_df['climateregions__climateregion'])
test_df['climateregions__climateregion']=le.fit_transform(test_df['climateregions__climateregion'])

# %%
print('training set prep')
train_df=seperate_monthly(train_df)
#train_df=eliminate_columns(train_df)
print('test set prep')
test_df=seperate_monthly(test_df)
#test_df=eliminate_columns(test_df)
# Out:
# training set prep
# test set prep

# %%
train_df
# Out:
#          index       lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 124463  124463  0.454545  0.666667                              176.08
# 67228    67228  0.318182  0.733333                              542.47
# 4958      4958  0.090909  0.833333                              418.35
# 41537    41537  0.272727  0.366667                              366.67
# 363477  363477  1.000000  0.333333                               28.66
# ...        ...       ...       ...                                 ...
# 317827  317827  0.909091  0.000000                              159.47
# 42537    42537  0.272727  0.433333                              261.42
# 173270  173270  0.590909  0.000000                              470.59
# 269542  269542  0.772727  0.566667                              103.09
# 265342  265342  0.772727  0.366667                              557.97
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 124463                     -0.18                      2.29
# 67228                      30.87                     33.10
# 4958                       18.07                     19.13
# 41537                      18.29                     19.74
# 363477                     -8.70                     -9.14
# ...                          ...                       ...
# 317827                      5.95                      7.21
# 42537                       4.96                      8.89
# 173270                     19.06                     19.21
# 269542                     -7.33                     -5.26
# 265342                     20.75                     23.26
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 124463                     0.45                    -0.33
# 67228                     27.18                    29.42
# 4958                      16.68                    18.51
# 41537                     17.56                    21.26
# 363477                    -7.17                    -9.48
# ...                         ...                      ...
# 317827                     7.20                     8.57
# 42537                      4.48                     9.49
# 173270                    17.92                    17.77
# 269542                    -4.98                    -7.47
# 265342                    18.48                    21.59
#
#         nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 124463                     3.57                         2.17  ...
# 67228                     26.97                        30.40  ...
# 4958                      14.76                        16.70  ...
# 41537                     20.43                        19.25  ...
# 363477                    -7.35                        -9.38  ...
# ...                         ...                          ...  ...
# 317827                     7.39                         8.66  ...
# 42537                      6.76                         8.19  ...
# 173270                    16.35                        18.72  ...
# 269542                    -5.11                        -7.94  ...
# 265342                    16.27                        20.70  ...
#
#         wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 124463                 -20.08                   4.47                 -30.78
# 67228                   -1.99                  54.76                 -64.76
# 4958                   -53.67                  65.11                 -22.64
# 41537                  -61.69                  68.46                 -52.22
# 363477                 -51.35                  39.84                 -72.56
# ...                       ...                    ...                    ...
# 317827                 -54.93                  73.42                 -11.87
# 42537                   16.18                 -20.91                   2.48
# 173270                  32.40                   2.40                 -98.87
# 269542                   2.77                  53.20                   1.25
# 265342                   3.64                  -3.99                 -38.41
#
#         wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 124463                  -1.57                   1.25                  30.41
# 67228                  -27.91                  18.18                  76.74
# 4958                   -39.72                  17.02                  16.16
# 41537                  -51.66                  16.08                  34.12
# 363477                 -41.05                 -18.20                  -4.18
# ...                       ...                    ...                    ...
# 317827                 -39.22                  16.16                  20.03
# 42537                   26.99                  -6.82                  67.32
# 173270                 -29.23                  -3.36                  23.79
# 269542                 -39.08                 -17.83                 -36.30
# 265342                   2.70                  10.28                  16.72
#
#         wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 124463                 -16.89                   4.58      3    15
# 67228                  -18.23                 -21.83      8    16
# 4958                    51.36                  37.24      3    16
# 41537                  -60.98                  81.00      4    16
# 363477                  -0.61                  -3.00      2    15
# ...                       ...                    ...    ...   ...
# 317827                  52.72                  36.75      3    16
# 42537                   27.10                  -8.23      1    15
# 173270                 -13.48                 -24.45      9    14
# 269542                  20.72                  20.29      2    16
# 265342                   4.07                  -4.77      8    16
#
# [352604 rows x 247 columns]

# %%
test_df
# Out:
#         index  lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333                              339.88
# 1      375735  0.0  0.833333                              334.63
# 2      375736  0.0  0.833333                              337.83
# 3      375737  0.0  0.833333                              345.81
# 4      375738  0.0  0.833333                              357.39
# ...       ...  ...       ...                                 ...
# 31349  407083  1.0  0.866667                               62.72
# 31350  407084  1.0  0.866667                               73.41
# 31351  407085  1.0  0.866667                               70.00
# 31352  407086  1.0  0.866667                               79.81
# 31353  407087  1.0  0.866667                               86.17
#
#        nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                         30.88                     30.92
# 1                         30.88                     30.92
# 2                         30.88                     30.92
# 3                         30.88                     30.92
# 4                         30.88                     30.92
# ...                         ...                       ...
# 31349                      4.60                      8.71
# 31350                      4.60                      8.71
# 31351                      4.60                      8.71
# 31352                      4.60                      8.71
# 31353                      4.60                      8.71
#
#        nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                        29.17                    31.02
# 1                        29.17                    31.02
# 2                        29.17                    31.02
# 3                        29.17                    31.02
# 4                        29.17                    31.02
# ...                        ...                      ...
# 31349                     6.05                    10.08
# 31350                     6.05                    10.08
# 31351                     6.05                    10.08
# 31352                     6.05                    10.08
# 31353                     6.05                    10.08
#
#        nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 0                        29.47                        30.93  ...
# 1                        29.47                        30.93  ...
# 2                        29.47                        30.93  ...
# 3                        29.47                        30.93  ...
# 4                        29.47                        30.93  ...
# ...                        ...                          ...  ...
# 31349                     6.39                         8.42  ...
# 31350                     6.39                         8.42  ...
# 31351                     6.39                         8.42  ...
# 31352                     6.39                         8.42  ...
# 31353                     6.39                         8.42  ...
#
#        wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 0                     -29.25                  40.88                  -8.31
# 1                     -28.62                  45.37                  -5.42
# 2                     -27.67                  49.76                  -1.31
# 3                     -19.32                  52.62                  -0.44
# 4                      -9.89                  51.23                  -7.57
# ...                      ...                    ...                    ...
# 31349                  32.39                  38.82                   7.42
# 31350                  26.23                  37.64                  13.01
# 31351                  21.06                  36.53                  14.15
# 31352                  20.42                  36.05                   6.38
# 31353                  26.17                  30.68                  -3.24
#
#        wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 0                      14.91                 -24.62                  31.05
# 1                      16.97                 -23.94                  28.84
# 2                      21.44                 -19.06                  26.85
# 3                      21.65                 -23.12                  23.70
# 4                      19.86                 -30.56                  20.66
# ...                      ...                    ...                    ...
# 31349                  11.75                 -23.62                  -0.24
# 31350                  17.84                 -22.05                  -3.03
# 31351                  23.12                 -25.60                  -5.88
# 31352                  29.00                 -27.06                  -1.42
# 31353                  27.70                 -28.75                   0.15
#
#        wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 0                     -23.69                   6.27     11    22
# 1                     -20.61                  14.16     11    22
# 2                     -16.78                  13.42     11    22
# 3                     -18.62                  10.69     11    22
# 4                     -25.08                  19.64     11    22
# ...                      ...                    ...    ...   ...
# 31349                  -5.94                  51.23     12    22
# 31350                   1.31                  51.45     12    22
# 31351                   9.32                  45.32     12    22
# 31352                  16.06                  31.88     12    22
# 31353                  16.64                  19.27     12    22
#
# [31354 rows x 246 columns]

# %%
train_df=train_df.astype('float')
test_df=test_df.astype('float')

# %%
y_train_df=train_df['contest-tmp2m-14d__tmp2m']
X_train_df=train_df.drop('contest-tmp2m-14d__tmp2m', axis=1)
type(y_train_df)
y_train_df=y_train_df.to_frame()
type(y_train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_df=normanlize_data(X_train_df,train_df)
test_df=normanlize_data(test_df,train_df)

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352604 entries, 124463 to 265342
# Columns: 246 entries, index to year
# dtypes: float64(246)
# memory usage: 664.5 MB

# %% [markdown]
# # Model

# %%
NN_model = Sequential()

#I might need to change the input_dim to give the actual dimentions
#Instead of being just 1
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = 246, activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               31616
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 256)               65792
#
#  dense_6 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 328,065
# Trainable params: 328,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights--.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train_df, y_train_df, epochs=10, batch_size=32, validation_split = 0.2, callbacks=callbacks_list,shuffle=True)
# Out:
# Epoch 1/10
# 8816/8816 [==============================] - ETA: 0s - loss: 1.1260 - mean_absolute_error: 1.1260
# Epoch 1: val_loss improved from inf to 0.84195, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 1.1260 - mean_absolute_error: 1.1260 - val_loss: 0.8419 - val_mean_absolute_error: 0.8419
# Epoch 2/10
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.8401 - mean_absolute_error: 0.8401
# Epoch 2: val_loss improved from 0.84195 to 0.79982, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.8401 - mean_absolute_error: 0.8401 - val_loss: 0.7998 - val_mean_absolute_error: 0.7998
# Epoch 3/10
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.7568 - mean_absolute_error: 0.7568
# Epoch 3: val_loss improved from 0.79982 to 0.72864, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.7568 - mean_absolute_error: 0.7568 - val_loss: 0.7286 - val_mean_absolute_error: 0.7286
# Epoch 4/10
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.7052 - mean_absolute_error: 0.7052
# Epoch 4: val_loss improved from 0.72864 to 0.69247, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.7052 - mean_absolute_error: 0.7052 - val_loss: 0.6925 - val_mean_absolute_error: 0.6925
# Epoch 5/10
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.6706 - mean_absolute_error: 0.6706
# Epoch 5: val_loss improved from 0.69247 to 0.63475, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.6707 - mean_absolute_error: 0.6707 - val_loss: 0.6347 - val_mean_absolute_error: 0.6347
# Epoch 6/10
# 8805/8816 [============================>.] - ETA: 0s - loss: 0.6457 - mean_absolute_error: 0.6457
# Epoch 6: val_loss did not improve from 0.63475
# 8816/8816 [==============================] - 52s 6ms/step - loss: 0.6458 - mean_absolute_error: 0.6458 - val_loss: 0.6673 - val_mean_absolute_error: 0.6673
# Epoch 7/10
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.6234 - mean_absolute_error: 0.6234
# Epoch 7: val_loss improved from 0.63475 to 0.61567, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.6234 - mean_absolute_error: 0.6234 - val_loss: 0.6157 - val_mean_absolute_error: 0.6157
# Epoch 8/10
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.6054 - mean_absolute_error: 0.6054
# Epoch 8: val_loss did not improve from 0.61567
# 8816/8816 [==============================] - 51s 6ms/step - loss: 0.6054 - mean_absolute_error: 0.6054 - val_loss: 0.6312 - val_mean_absolute_error: 0.6312
# Epoch 9/10
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5905 - mean_absolute_error: 0.5905
# Epoch 9: val_loss improved from 0.61567 to 0.55604, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.5905 - mean_absolute_error: 0.5905 - val_loss: 0.5560 - val_mean_absolute_error: 0.5560
# Epoch 10/10
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5784 - mean_absolute_error: 0.5784
# Epoch 10: val_loss improved from 0.55604 to 0.54243, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.5784 - mean_absolute_error: 0.5784 - val_loss: 0.5424 - val_mean_absolute_error: 0.5424

# %%
# Load wights file of the best model :
wights_file = f'Weights--.hdf5'  # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(test_df)
# Out:
# 980/980 [==============================] - 3s 3ms/step

# %% [markdown]
# # Saving Dataset in correct format

# %%
predictions
# Out:
# array([[26.391497 ],
#        [26.405092 ],
#        [26.486    ],
#        ...,
#        [ 1.5260566],
#        [ 1.3873836],
#        [ 1.0520139]], dtype=float32)

# %%
final=pd.DataFrame(predictions,columns=['contest-tmp2m-14d__tmp2m'])

# %%
i=375734
final['index']=0
while i<407088:
    final['index'][i-375734]=i
    i+=1
final
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     26.391497  375734
# 1                     26.405092  375735
# 2                     26.486000  375736
# 3                     26.595499  375737
# 4                     26.524689  375738
# ...                         ...     ...
# 31349                  3.091918  407083
# 31350                  2.476183  407084
# 31351                  1.526057  407085
# 31352                  1.387384  407086
# 31353                  1.052014  407087
#
# [31354 rows x 2 columns]

# %%
final.to_csv('/kaggle/working/wetherprediction.csv',index=False)
