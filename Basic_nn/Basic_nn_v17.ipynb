# %% [markdown]
# Link to another tutorial site that I was using to figure this out:
# https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing #Convert categorical data to neumeric values

from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/widsdatathon2023/train_data.csv
# /kaggle/input/widsdatathon2023/test_data.csv
# /kaggle/input/widsdatathon2023/sample_solution.csv

# %%
keep_columns=['lat','month','contest-tmp2m-14d__tmp2m',
              'climateregions__climateregion','lon']
X_columns=[['lat','month',
              'climateregions__climateregion','lon']]

# %%
def seperate_monthly(df):
    df[['month','day','year']]=df.startdate.str.split('/',expand=True)
    df=df.drop('day', axis=1)
    df=df.drop('startdate',axis=1)
    return df

# %%
def eliminate_columns(df):
    for col in df.columns:
        if col in keep_columns:
            print(col)
        else: 
            df=df.drop(col, axis=1)
    return df

# %%
#need to come up with a different way to do this, because it is not working
def seperate_y(df):
    y_df=df['contest-tmp2m-14d__tmp2m']
    X_df=df.drop('contest-tmp2m-14d__tmp2m',axis=1)
    return y_df,X_df

# %%
def normanlize_data(df,train_df):
    for column in df.columns:
        df[column] = df[column]  /  train_df[column].abs().max()
    return df

# %%
train_df=pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
train_df=train_df.dropna(axis=0)
test_df=pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
test_df=test_df.dropna(axis=0)
train_df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                          29.02                     31.64
# 1                          29.02                     31.64
# 2                          29.02                     31.64
# 3                          29.02                     31.64
# 4                          29.02                     31.64
# ...                          ...                       ...
# 375729                     23.13                     27.20
# 375730                     23.13                     27.20
# 375731                     23.13                     27.20
# 375732                     23.13                     27.20
# 375733                     23.13                     27.20
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                         29.57                    30.73
# 1                         29.57                    30.73
# 2                         29.57                    30.73
# 3                         29.57                    30.73
# 4                         29.57                    30.73
# ...                         ...                      ...
# 375729                    20.25                    24.43
# 375730                    20.25                    24.43
# 375731                    20.25                    24.43
# 375732                    20.25                    24.43
# 375733                    20.25                    24.43
#
#         nmme0-tmp2m-34w__cfsv20  ...  wind-vwnd-925-2010-11  \
# 0                         29.71  ...                 -27.68
# 1                         29.71  ...                 -21.13
# 2                         29.71  ...                 -10.72
# 3                         29.71  ...                   0.33
# 4                         29.71  ...                   9.83
# ...                         ...  ...                    ...
# 375729                    18.35  ...                 -15.64
# 375730                    18.35  ...                  -7.59
# 375731                    18.35  ...                  -6.25
# 375732                    18.35  ...                  -7.16
# 375733                    18.35  ...                 -12.36
#
#         wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  \
# 0                      -37.21                   8.32                   9.56
# 1                      -36.57                   8.77                  21.17
# 2                      -34.16                   6.99                  32.16
# 3                      -31.04                   6.17                  39.66
# 4                      -31.80                   7.47                  38.62
# ...                       ...                    ...                    ...
# 375729                 -75.68                  -3.09                   6.93
# 375730                 -76.42                 -13.55                  13.36
# 375731                 -70.65                 -23.93                  22.62
# 375732                 -57.67                 -33.55                  32.06
# 375733                 -44.67                 -32.46                  36.25
#
#         wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  \
# 0                       -2.03                  48.13                  28.09
# 1                        4.44                  48.60                  27.41
# 2                        5.01                  48.53                  19.21
# 3                       -1.41                  50.59                   8.29
# 4                       -5.21                  54.73                  -2.58
# ...                       ...                    ...                    ...
# 375729                 -16.69                  16.98                 -13.85
# 375730                 -15.96                  20.45                 -16.36
# 375731                 -16.71                  20.28                 -15.48
# 375732                 -16.07                  16.60                 -20.61
# 375733                 -12.72                  15.98                 -22.56
#
#         wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  wind-vwnd-925-2010-20
# 0                      -13.50                  11.90                   4.58
# 1                      -23.77                  15.44                   3.42
# 2                      -33.16                  15.11                   4.82
# 3                      -37.22                  18.24                   9.74
# 4                      -42.30                  21.91                  10.95
# ...                       ...                    ...                    ...
# 375729                  50.25                 -31.33                   0.77
# 375730                  51.65                 -30.73                  10.10
# 375731                  48.58                 -18.74                   9.28
# 375732                  39.23                 -16.26                  -0.22
# 375733                  32.53                 -21.89                  -1.20
#
# [352604 rows x 246 columns]

# %%
#Shuffeling the data
train_df = train_df.sample(frac = 1)

# %%
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
train_df['climateregions__climateregion']=le.fit_transform(train_df['climateregions__climateregion'])
test_df['climateregions__climateregion']=le.fit_transform(test_df['climateregions__climateregion'])

# %%
print('training set prep')
train_df=seperate_monthly(train_df)
#train_df=eliminate_columns(train_df)
print('test set prep')
test_df=seperate_monthly(test_df)
#test_df=eliminate_columns(test_df)
# Out:
# training set prep
# test set prep

# %%
train_df
# Out:
#          index       lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 104023  104023  0.409091  0.666667                              323.17
# 355587  355587  0.954545  0.800000                              564.31
# 276525  276525  0.772727  0.900000                              154.68
# 353679  353679  0.954545  0.700000                              230.42
# 217224  217224  0.681818  0.066667                               48.24
# ...        ...       ...       ...                                 ...
# 31934    31934  0.227273  0.700000                              210.27
# 88647    88647  0.363636  0.866667                              288.32
# 284572  284572  0.818182  0.333333                              122.54
# 187192  187192  0.590909  0.633333                              216.74
# 350024  350024  0.954545  0.533333                              162.96
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 104023                      3.54                      6.20
# 355587                     21.03                     24.06
# 276525                     -1.10                      0.65
# 353679                      4.80                      6.91
# 217224                      3.19                      5.06
# ...                          ...                       ...
# 31934                       2.64                      4.43
# 88647                       4.60                      7.87
# 284572                     -3.35                     -2.38
# 187192                      7.92                      9.57
# 350024                      4.44                      6.92
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 104023                     4.69                     1.75
# 355587                    19.88                    20.62
# 276525                     3.11                     0.78
# 353679                     7.04                     8.82
# 217224                     2.08                     2.72
# ...                         ...                      ...
# 31934                      5.23                     4.69
# 88647                      7.15                     6.15
# 284572                    -2.53                    -4.99
# 187192                     6.82                     8.92
# 350024                     5.60                     8.72
#
#         nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 104023                     5.62                         5.65  ...
# 355587                    17.26                        22.34  ...
# 276525                    -0.42                         1.66  ...
# 353679                     6.08                         6.30  ...
# 217224                     0.73                         1.20  ...
# ...                         ...                          ...  ...
# 31934                      6.50                         6.12  ...
# 88647                      6.20                         8.45  ...
# 284572                    -1.57                        -5.10  ...
# 187192                     7.00                         9.09  ...
# 350024                     6.91                         6.95  ...
#
#         wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 104023                  11.25                  57.71                 -45.77
# 355587                 -22.92                  23.04                  42.76
# 276525                  10.67                  11.09                 -64.43
# 353679                 -32.53                  67.43                 -41.40
# 217224                  49.81                  35.70                 -36.47
# ...                       ...                    ...                    ...
# 31934                  -26.52                 -26.56                 -40.80
# 88647                  -31.96                  -5.51                 -37.77
# 284572                  36.59                  30.90                 -48.66
# 187192                  37.26                  27.73                   2.47
# 350024                 -32.53                  67.43                 -41.40
#
#         wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 104023                   7.99                  -6.87                  10.41
# 355587                 -48.88                 -17.05                  42.58
# 276525                 -35.63                  17.13                  13.04
# 353679                 -54.14                 -19.30                  18.49
# 217224                 -93.17                  27.16                  -3.59
# ...                       ...                    ...                    ...
# 31934                 -106.08                  29.80                  -3.49
# 88647                  -15.81                   3.83                  29.22
# 284572                 -13.36                 -18.88                 -26.21
# 187192                  -0.90                 -26.56                  22.54
# 350024                 -54.14                 -19.30                  18.49
#
#         wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 104023                  13.87                  42.03      4    15
# 355587                 -42.16                  28.57      7    15
# 276525                  10.75                  51.39      3    15
# 353679                   0.26                  60.80      4    16
# 217224                  11.19                  -0.27     12    14
# ...                       ...                    ...    ...   ...
# 31934                   31.04                   7.17      1    16
# 88647                  -22.13                  21.05      3    15
# 284572                   3.04                  55.78      4    15
# 187192                  36.54                 -15.81     10    14
# 350024                   0.26                  60.80      4    16
#
# [352604 rows x 247 columns]

# %%
test_df
# Out:
#         index  lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333                              339.88
# 1      375735  0.0  0.833333                              334.63
# 2      375736  0.0  0.833333                              337.83
# 3      375737  0.0  0.833333                              345.81
# 4      375738  0.0  0.833333                              357.39
# ...       ...  ...       ...                                 ...
# 31349  407083  1.0  0.866667                               62.72
# 31350  407084  1.0  0.866667                               73.41
# 31351  407085  1.0  0.866667                               70.00
# 31352  407086  1.0  0.866667                               79.81
# 31353  407087  1.0  0.866667                               86.17
#
#        nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                         30.88                     30.92
# 1                         30.88                     30.92
# 2                         30.88                     30.92
# 3                         30.88                     30.92
# 4                         30.88                     30.92
# ...                         ...                       ...
# 31349                      4.60                      8.71
# 31350                      4.60                      8.71
# 31351                      4.60                      8.71
# 31352                      4.60                      8.71
# 31353                      4.60                      8.71
#
#        nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                        29.17                    31.02
# 1                        29.17                    31.02
# 2                        29.17                    31.02
# 3                        29.17                    31.02
# 4                        29.17                    31.02
# ...                        ...                      ...
# 31349                     6.05                    10.08
# 31350                     6.05                    10.08
# 31351                     6.05                    10.08
# 31352                     6.05                    10.08
# 31353                     6.05                    10.08
#
#        nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 0                        29.47                        30.93  ...
# 1                        29.47                        30.93  ...
# 2                        29.47                        30.93  ...
# 3                        29.47                        30.93  ...
# 4                        29.47                        30.93  ...
# ...                        ...                          ...  ...
# 31349                     6.39                         8.42  ...
# 31350                     6.39                         8.42  ...
# 31351                     6.39                         8.42  ...
# 31352                     6.39                         8.42  ...
# 31353                     6.39                         8.42  ...
#
#        wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 0                     -29.25                  40.88                  -8.31
# 1                     -28.62                  45.37                  -5.42
# 2                     -27.67                  49.76                  -1.31
# 3                     -19.32                  52.62                  -0.44
# 4                      -9.89                  51.23                  -7.57
# ...                      ...                    ...                    ...
# 31349                  32.39                  38.82                   7.42
# 31350                  26.23                  37.64                  13.01
# 31351                  21.06                  36.53                  14.15
# 31352                  20.42                  36.05                   6.38
# 31353                  26.17                  30.68                  -3.24
#
#        wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 0                      14.91                 -24.62                  31.05
# 1                      16.97                 -23.94                  28.84
# 2                      21.44                 -19.06                  26.85
# 3                      21.65                 -23.12                  23.70
# 4                      19.86                 -30.56                  20.66
# ...                      ...                    ...                    ...
# 31349                  11.75                 -23.62                  -0.24
# 31350                  17.84                 -22.05                  -3.03
# 31351                  23.12                 -25.60                  -5.88
# 31352                  29.00                 -27.06                  -1.42
# 31353                  27.70                 -28.75                   0.15
#
#        wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 0                     -23.69                   6.27     11    22
# 1                     -20.61                  14.16     11    22
# 2                     -16.78                  13.42     11    22
# 3                     -18.62                  10.69     11    22
# 4                     -25.08                  19.64     11    22
# ...                      ...                    ...    ...   ...
# 31349                  -5.94                  51.23     12    22
# 31350                   1.31                  51.45     12    22
# 31351                   9.32                  45.32     12    22
# 31352                  16.06                  31.88     12    22
# 31353                  16.64                  19.27     12    22
#
# [31354 rows x 246 columns]

# %%
train_df=train_df.astype('float')
test_df=test_df.astype('float')

# %%
y_train_df=train_df['contest-tmp2m-14d__tmp2m']
X_train_df=train_df.drop('contest-tmp2m-14d__tmp2m', axis=1)
type(y_train_df)
y_train_df=y_train_df.to_frame()
type(y_train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_df=normanlize_data(X_train_df,train_df)
test_df=normanlize_data(test_df,train_df)

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352604 entries, 104023 to 350024
# Columns: 246 entries, index to year
# dtypes: float64(246)
# memory usage: 664.5 MB

# %% [markdown]
# # Model

# %%
NN_model = Sequential()

#I might need to change the input_dim to give the actual dimentions
#Instead of being just 1
# The Input Layer :
NN_model.add(Dense(256, kernel_initializer='normal',input_dim = 246, activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(512, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(512, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(512, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               63232
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 917,505
# Trainable params: 917,505
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-22 17:19:08.394079: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-02-22 17:19:08.394167: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
checkpoint_name = 'Weights--.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train_df, y_train_df, epochs=20, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.1120 - mean_absolute_error: 1.1120
# Epoch 1: val_loss improved from inf to 1.12864, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 87s 10ms/step - loss: 1.1119 - mean_absolute_error: 1.1119 - val_loss: 1.1286 - val_mean_absolute_error: 1.1286
# Epoch 2/20
# 8816/8816 [==============================] - ETA: 0s - loss: 0.8350 - mean_absolute_error: 0.8350
# Epoch 2: val_loss improved from 1.12864 to 0.76775, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 86s 10ms/step - loss: 0.8350 - mean_absolute_error: 0.8350 - val_loss: 0.7678 - val_mean_absolute_error: 0.7678
# Epoch 3/20
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.7525 - mean_absolute_error: 0.7525
# Epoch 3: val_loss did not improve from 0.76775
# 8816/8816 [==============================] - 82s 9ms/step - loss: 0.7525 - mean_absolute_error: 0.7525 - val_loss: 0.8871 - val_mean_absolute_error: 0.8871
# Epoch 4/20
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.7001 - mean_absolute_error: 0.7001
# Epoch 4: val_loss did not improve from 0.76775
# 8816/8816 [==============================] - 82s 9ms/step - loss: 0.7001 - mean_absolute_error: 0.7001 - val_loss: 0.8370 - val_mean_absolute_error: 0.8370
# Epoch 5/20
# 8816/8816 [==============================] - ETA: 0s - loss: 0.6619 - mean_absolute_error: 0.6619
# Epoch 5: val_loss improved from 0.76775 to 0.65363, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 81s 9ms/step - loss: 0.6619 - mean_absolute_error: 0.6619 - val_loss: 0.6536 - val_mean_absolute_error: 0.6536
# Epoch 6/20
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.6336 - mean_absolute_error: 0.6336
# Epoch 6: val_loss improved from 0.65363 to 0.63719, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 85s 10ms/step - loss: 0.6336 - mean_absolute_error: 0.6336 - val_loss: 0.6372 - val_mean_absolute_error: 0.6372
# Epoch 7/20
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.6125 - mean_absolute_error: 0.6125
# Epoch 7: val_loss did not improve from 0.63719
# 8816/8816 [==============================] - 81s 9ms/step - loss: 0.6125 - mean_absolute_error: 0.6125 - val_loss: 0.7132 - val_mean_absolute_error: 0.7132
# Epoch 8/20
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.5938 - mean_absolute_error: 0.5938
# Epoch 8: val_loss improved from 0.63719 to 0.61891, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 85s 10ms/step - loss: 0.5938 - mean_absolute_error: 0.5938 - val_loss: 0.6189 - val_mean_absolute_error: 0.6189
# Epoch 9/20
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5808 - mean_absolute_error: 0.5808
# Epoch 9: val_loss improved from 0.61891 to 0.57385, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 85s 10ms/step - loss: 0.5808 - mean_absolute_error: 0.5808 - val_loss: 0.5739 - val_mean_absolute_error: 0.5739
# Epoch 10/20
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5676 - mean_absolute_error: 0.5676
# Epoch 10: val_loss did not improve from 0.57385
# 8816/8816 [==============================] - 83s 9ms/step - loss: 0.5676 - mean_absolute_error: 0.5676 - val_loss: 0.6023 - val_mean_absolute_error: 0.6023
# Epoch 11/20
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.5533 - mean_absolute_error: 0.5533
# Epoch 11: val_loss did not improve from 0.57385
# 8816/8816 [==============================] - 82s 9ms/step - loss: 0.5532 - mean_absolute_error: 0.5532 - val_loss: 0.6111 - val_mean_absolute_error: 0.6111
# Epoch 12/20
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5443 - mean_absolute_error: 0.5443
# Epoch 12: val_loss did not improve from 0.57385
# 8816/8816 [==============================] - 82s 9ms/step - loss: 0.5443 - mean_absolute_error: 0.5443 - val_loss: 0.5913 - val_mean_absolute_error: 0.5913
# Epoch 13/20
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.5340 - mean_absolute_error: 0.5340
# Epoch 13: val_loss improved from 0.57385 to 0.56114, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 82s 9ms/step - loss: 0.5340 - mean_absolute_error: 0.5340 - val_loss: 0.5611 - val_mean_absolute_error: 0.5611
# Epoch 14/20
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5257 - mean_absolute_error: 0.5257
# Epoch 14: val_loss improved from 0.56114 to 0.51756, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 82s 9ms/step - loss: 0.5257 - mean_absolute_error: 0.5257 - val_loss: 0.5176 - val_mean_absolute_error: 0.5176
# Epoch 15/20
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.5188 - mean_absolute_error: 0.5188
# Epoch 15: val_loss did not improve from 0.51756
# 8816/8816 [==============================] - 85s 10ms/step - loss: 0.5188 - mean_absolute_error: 0.5188 - val_loss: 0.5237 - val_mean_absolute_error: 0.5237
# Epoch 16/20
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.5098 - mean_absolute_error: 0.5098
# Epoch 16: val_loss did not improve from 0.51756
# 8816/8816 [==============================] - 84s 10ms/step - loss: 0.5098 - mean_absolute_error: 0.5098 - val_loss: 0.5501 - val_mean_absolute_error: 0.5501
# Epoch 17/20
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5050 - mean_absolute_error: 0.5050
# Epoch 17: val_loss improved from 0.51756 to 0.50002, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 82s 9ms/step - loss: 0.5050 - mean_absolute_error: 0.5050 - val_loss: 0.5000 - val_mean_absolute_error: 0.5000
# Epoch 18/20
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4974 - mean_absolute_error: 0.4974
# Epoch 18: val_loss did not improve from 0.50002
# 8816/8816 [==============================] - 85s 10ms/step - loss: 0.4974 - mean_absolute_error: 0.4974 - val_loss: 0.5527 - val_mean_absolute_error: 0.5527
# Epoch 19/20
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4924 - mean_absolute_error: 0.4924
# Epoch 19: val_loss improved from 0.50002 to 0.47266, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 82s 9ms/step - loss: 0.4924 - mean_absolute_error: 0.4924 - val_loss: 0.4727 - val_mean_absolute_error: 0.4727
# Epoch 20/20
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4877 - mean_absolute_error: 0.4877
# Epoch 20: val_loss did not improve from 0.47266
# 8816/8816 [==============================] - 85s 10ms/step - loss: 0.4877 - mean_absolute_error: 0.4877 - val_loss: 0.4929 - val_mean_absolute_error: 0.4929

# %%
# Load wights file of the best model :
wights_file = f'Weights--.hdf5'  # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(test_df)
# Out:
# 980/980 [==============================] - 3s 3ms/step

# %% [markdown]
# # Saving Dataset in correct format

# %%
predictions
# Out:
# array([[25.764565  ],
#        [25.573013  ],
#        [25.653282  ],
#        ...,
#        [ 0.8812042 ],
#        [ 0.8720275 ],
#        [-0.23160505]], dtype=float32)

# %%
final=pd.DataFrame(predictions,columns=['contest-tmp2m-14d__tmp2m'])

# %%
i=375734
final['index']=0
while i<407088:
    final['index'][i-375734]=i
    i+=1
final
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     25.764565  375734
# 1                     25.573013  375735
# 2                     25.653282  375736
# 3                     25.745491  375737
# 4                     25.688221  375738
# ...                         ...     ...
# 31349                  2.293659  407083
# 31350                  2.334102  407084
# 31351                  0.881204  407085
# 31352                  0.872028  407086
# 31353                 -0.231605  407087
#
# [31354 rows x 2 columns]

# %%
final.to_csv('/kaggle/working/wetherprediction.csv',index=False)
