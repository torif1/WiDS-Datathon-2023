# %% [markdown]
# Link to another tutorial site that I was using to figure this out:
# https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing #Convert categorical data to neumeric values

from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/widsdatathon2023/train_data.csv
# /kaggle/input/widsdatathon2023/test_data.csv
# /kaggle/input/widsdatathon2023/sample_solution.csv

# %%
keep_columns=['lat','month','contest-tmp2m-14d__tmp2m',
              'climateregions__climateregion','lon']
X_columns=[['lat','month',
              'climateregions__climateregion','lon']]

# %%
def seperate_monthly(df):
    df[['month','day','year']]=df.startdate.str.split('/',expand=True)
    df=df.drop('day', axis=1)
    df=df.drop('startdate',axis=1)
    return df

# %%
def eliminate_columns(df):
    for col in df.columns:
        if col in keep_columns:
            print(col)
        else: 
            df=df.drop(col, axis=1)
    return df

# %%
#need to come up with a different way to do this, because it is not working
def seperate_y(df):
    y_df=df['contest-tmp2m-14d__tmp2m']
    X_df=df.drop('contest-tmp2m-14d__tmp2m',axis=1)
    return y_df,X_df

# %%
def normanlize_data(df,train_df):
    for column in df.columns:
        df[column] = df[column]  /  train_df[column].abs().max()
    return df

# %%
train_df=pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
train_df=train_df.dropna(axis=0)
test_df=pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
test_df=test_df.dropna(axis=0)
train_df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                          29.02                     31.64
# 1                          29.02                     31.64
# 2                          29.02                     31.64
# 3                          29.02                     31.64
# 4                          29.02                     31.64
# ...                          ...                       ...
# 375729                     23.13                     27.20
# 375730                     23.13                     27.20
# 375731                     23.13                     27.20
# 375732                     23.13                     27.20
# 375733                     23.13                     27.20
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                         29.57                    30.73
# 1                         29.57                    30.73
# 2                         29.57                    30.73
# 3                         29.57                    30.73
# 4                         29.57                    30.73
# ...                         ...                      ...
# 375729                    20.25                    24.43
# 375730                    20.25                    24.43
# 375731                    20.25                    24.43
# 375732                    20.25                    24.43
# 375733                    20.25                    24.43
#
#         nmme0-tmp2m-34w__cfsv20  ...  wind-vwnd-925-2010-11  \
# 0                         29.71  ...                 -27.68
# 1                         29.71  ...                 -21.13
# 2                         29.71  ...                 -10.72
# 3                         29.71  ...                   0.33
# 4                         29.71  ...                   9.83
# ...                         ...  ...                    ...
# 375729                    18.35  ...                 -15.64
# 375730                    18.35  ...                  -7.59
# 375731                    18.35  ...                  -6.25
# 375732                    18.35  ...                  -7.16
# 375733                    18.35  ...                 -12.36
#
#         wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  \
# 0                      -37.21                   8.32                   9.56
# 1                      -36.57                   8.77                  21.17
# 2                      -34.16                   6.99                  32.16
# 3                      -31.04                   6.17                  39.66
# 4                      -31.80                   7.47                  38.62
# ...                       ...                    ...                    ...
# 375729                 -75.68                  -3.09                   6.93
# 375730                 -76.42                 -13.55                  13.36
# 375731                 -70.65                 -23.93                  22.62
# 375732                 -57.67                 -33.55                  32.06
# 375733                 -44.67                 -32.46                  36.25
#
#         wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  \
# 0                       -2.03                  48.13                  28.09
# 1                        4.44                  48.60                  27.41
# 2                        5.01                  48.53                  19.21
# 3                       -1.41                  50.59                   8.29
# 4                       -5.21                  54.73                  -2.58
# ...                       ...                    ...                    ...
# 375729                 -16.69                  16.98                 -13.85
# 375730                 -15.96                  20.45                 -16.36
# 375731                 -16.71                  20.28                 -15.48
# 375732                 -16.07                  16.60                 -20.61
# 375733                 -12.72                  15.98                 -22.56
#
#         wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  wind-vwnd-925-2010-20
# 0                      -13.50                  11.90                   4.58
# 1                      -23.77                  15.44                   3.42
# 2                      -33.16                  15.11                   4.82
# 3                      -37.22                  18.24                   9.74
# 4                      -42.30                  21.91                  10.95
# ...                       ...                    ...                    ...
# 375729                  50.25                 -31.33                   0.77
# 375730                  51.65                 -30.73                  10.10
# 375731                  48.58                 -18.74                   9.28
# 375732                  39.23                 -16.26                  -0.22
# 375733                  32.53                 -21.89                  -1.20
#
# [352604 rows x 246 columns]

# %%
#Shuffeling the data
train_df = train_df.sample(frac = 1)

# %%
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
train_df['climateregions__climateregion']=le.fit_transform(train_df['climateregions__climateregion'])
test_df['climateregions__climateregion']=le.fit_transform(test_df['climateregions__climateregion'])

# %%
print('training set')
train_df=seperate_monthly(train_df)
train_df=eliminate_columns(train_df)
print('test set')
test_df=seperate_monthly(test_df)
test_df=eliminate_columns(test_df)
# Out:
# training set
# lat
# lon
# contest-tmp2m-14d__tmp2m
# climateregions__climateregion
# month
# test set
# lat
# lon
# climateregions__climateregion
# month

# %%
train_df
# Out:
#              lat       lon  contest-tmp2m-14d__tmp2m  \
# 292093  0.818182  0.666667                  5.313776
# 61581   0.318182  0.500000                  1.778277
# 370196  1.000000  0.633333                 20.521100
# 212261  0.636364  0.800000                 20.089100
# 235088  0.681818  0.866667                  4.980204
# ...          ...       ...                       ...
# 235108  0.681818  0.866667                  3.741193
# 288815  0.818182  0.533333                 -9.076846
# 372088  1.000000  0.733333                 11.585034
# 347347  0.954545  0.433333                -11.929829
# 337715  0.909091  0.900000                 19.720748
#
#         climateregions__climateregion month
# 292093                              1    10
# 61581                               1     2
# 370196                              9     7
# 212261                              8     5
# 235088                              8    11
# ...                               ...   ...
# 235108                              8    12
# 288815                              1    11
# 372088                              9     9
# 347347                              1     1
# 337715                              9     8
#
# [352604 rows x 5 columns]

# %%
test_df
# Out:
#        lat       lon  climateregions__climateregion month
# 0      0.0  0.833333                              0    11
# 1      0.0  0.833333                              0    11
# 2      0.0  0.833333                              0    11
# 3      0.0  0.833333                              0    11
# 4      0.0  0.833333                              0    11
# ...    ...       ...                            ...   ...
# 31349  1.0  0.866667                              9    12
# 31350  1.0  0.866667                              9    12
# 31351  1.0  0.866667                              9    12
# 31352  1.0  0.866667                              9    12
# 31353  1.0  0.866667                              9    12
#
# [31354 rows x 4 columns]

# %%
train_df=train_df.astype('float')
test_df=test_df.astype('float')

# %%
y_train_df=train_df['contest-tmp2m-14d__tmp2m']
X_train_df=train_df.drop('contest-tmp2m-14d__tmp2m', axis=1)
type(y_train_df)
y_train_df=y_train_df.to_frame()
type(y_train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_df=normanlize_data(X_train_df,train_df)
test_df=normanlize_data(test_df,train_df)

# %%
test_df
# Out:
#        lat       lon  climateregions__climateregion     month
# 0      0.0  0.833333                       0.000000  0.916667
# 1      0.0  0.833333                       0.000000  0.916667
# 2      0.0  0.833333                       0.000000  0.916667
# 3      0.0  0.833333                       0.000000  0.916667
# 4      0.0  0.833333                       0.000000  0.916667
# ...    ...       ...                            ...       ...
# 31349  1.0  0.866667                       0.642857  1.000000
# 31350  1.0  0.866667                       0.642857  1.000000
# 31351  1.0  0.866667                       0.642857  1.000000
# 31352  1.0  0.866667                       0.642857  1.000000
# 31353  1.0  0.866667                       0.642857  1.000000
#
# [31354 rows x 4 columns]

# %% [markdown]
# # Model

# %%
NN_model = Sequential()

#I might need to change the input_dim to give the actual dimentions
#Instead of being just 1
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = 4, activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               640
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 165,505
# Trainable params: 165,505
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-21 18:02:00.112866: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-02-21 18:02:00.112974: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
checkpoint_name = 'Weights--.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train_df, y_train_df, epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 2.6946 - mean_absolute_error: 2.6946
# Epoch 1: val_loss improved from inf to 2.36335, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 2.6942 - mean_absolute_error: 2.6942 - val_loss: 2.3633 - val_mean_absolute_error: 2.3633
# Epoch 2/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 2.2487 - mean_absolute_error: 2.2487
# Epoch 2: val_loss improved from 2.36335 to 2.18594, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 2.2486 - mean_absolute_error: 2.2486 - val_loss: 2.1859 - val_mean_absolute_error: 2.1859
# Epoch 3/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 2.1631 - mean_absolute_error: 2.1631
# Epoch 3: val_loss improved from 2.18594 to 2.14688, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 33s 4ms/step - loss: 2.1630 - mean_absolute_error: 2.1630 - val_loss: 2.1469 - val_mean_absolute_error: 2.1469
# Epoch 4/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 2.1090 - mean_absolute_error: 2.1090
# Epoch 4: val_loss improved from 2.14688 to 2.03552, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 33s 4ms/step - loss: 2.1089 - mean_absolute_error: 2.1089 - val_loss: 2.0355 - val_mean_absolute_error: 2.0355
# Epoch 5/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 2.0770 - mean_absolute_error: 2.0770
# Epoch 5: val_loss improved from 2.03552 to 2.02326, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 33s 4ms/step - loss: 2.0771 - mean_absolute_error: 2.0771 - val_loss: 2.0233 - val_mean_absolute_error: 2.0233
# Epoch 6/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 2.0521 - mean_absolute_error: 2.0521
# Epoch 6: val_loss improved from 2.02326 to 2.00847, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 32s 4ms/step - loss: 2.0521 - mean_absolute_error: 2.0521 - val_loss: 2.0085 - val_mean_absolute_error: 2.0085
# Epoch 7/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 2.0343 - mean_absolute_error: 2.0343
# Epoch 7: val_loss did not improve from 2.00847
# 8816/8816 [==============================] - 31s 4ms/step - loss: 2.0343 - mean_absolute_error: 2.0343 - val_loss: 2.0955 - val_mean_absolute_error: 2.0955
# Epoch 8/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 2.0198 - mean_absolute_error: 2.0198
# Epoch 8: val_loss improved from 2.00847 to 1.97330, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 2.0196 - mean_absolute_error: 2.0196 - val_loss: 1.9733 - val_mean_absolute_error: 1.9733
# Epoch 9/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 2.0040 - mean_absolute_error: 2.0040
# Epoch 9: val_loss did not improve from 1.97330
# 8816/8816 [==============================] - 29s 3ms/step - loss: 2.0040 - mean_absolute_error: 2.0040 - val_loss: 1.9987 - val_mean_absolute_error: 1.9987
# Epoch 10/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.9957 - mean_absolute_error: 1.9957
# Epoch 10: val_loss did not improve from 1.97330
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.9958 - mean_absolute_error: 1.9958 - val_loss: 1.9837 - val_mean_absolute_error: 1.9837
# Epoch 11/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.9863 - mean_absolute_error: 1.9863
# Epoch 11: val_loss improved from 1.97330 to 1.95463, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9863 - mean_absolute_error: 1.9863 - val_loss: 1.9546 - val_mean_absolute_error: 1.9546
# Epoch 12/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.9780 - mean_absolute_error: 1.9780
# Epoch 12: val_loss improved from 1.95463 to 1.93968, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9779 - mean_absolute_error: 1.9779 - val_loss: 1.9397 - val_mean_absolute_error: 1.9397
# Epoch 13/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.9674 - mean_absolute_error: 1.9674
# Epoch 13: val_loss did not improve from 1.93968
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9673 - mean_absolute_error: 1.9673 - val_loss: 1.9888 - val_mean_absolute_error: 1.9888
# Epoch 14/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.9611 - mean_absolute_error: 1.9611
# Epoch 14: val_loss did not improve from 1.93968
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9611 - mean_absolute_error: 1.9611 - val_loss: 2.0234 - val_mean_absolute_error: 2.0234
# Epoch 15/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.9560 - mean_absolute_error: 1.9560
# Epoch 15: val_loss improved from 1.93968 to 1.93036, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.9560 - mean_absolute_error: 1.9560 - val_loss: 1.9304 - val_mean_absolute_error: 1.9304
# Epoch 16/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.9491 - mean_absolute_error: 1.9491
# Epoch 16: val_loss did not improve from 1.93036
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9491 - mean_absolute_error: 1.9491 - val_loss: 1.9897 - val_mean_absolute_error: 1.9897
# Epoch 17/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.9441 - mean_absolute_error: 1.9441
# Epoch 17: val_loss improved from 1.93036 to 1.92643, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9440 - mean_absolute_error: 1.9440 - val_loss: 1.9264 - val_mean_absolute_error: 1.9264
# Epoch 18/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.9387 - mean_absolute_error: 1.9387
# Epoch 18: val_loss improved from 1.92643 to 1.91080, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.9386 - mean_absolute_error: 1.9386 - val_loss: 1.9108 - val_mean_absolute_error: 1.9108
# Epoch 19/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.9340 - mean_absolute_error: 1.9340
# Epoch 19: val_loss did not improve from 1.91080
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.9342 - mean_absolute_error: 1.9342 - val_loss: 1.9183 - val_mean_absolute_error: 1.9183
# Epoch 20/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.9294 - mean_absolute_error: 1.9294
# Epoch 20: val_loss improved from 1.91080 to 1.90201, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9294 - mean_absolute_error: 1.9294 - val_loss: 1.9020 - val_mean_absolute_error: 1.9020
# Epoch 21/500
# 8801/8816 [============================>.] - ETA: 0s - loss: 1.9249 - mean_absolute_error: 1.9249
# Epoch 21: val_loss did not improve from 1.90201
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9250 - mean_absolute_error: 1.9250 - val_loss: 1.9053 - val_mean_absolute_error: 1.9053
# Epoch 22/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.9244 - mean_absolute_error: 1.9244
# Epoch 22: val_loss did not improve from 1.90201
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.9244 - mean_absolute_error: 1.9244 - val_loss: 1.9461 - val_mean_absolute_error: 1.9461
# Epoch 23/500
# 8800/8816 [============================>.] - ETA: 0s - loss: 1.9209 - mean_absolute_error: 1.9209
# Epoch 23: val_loss did not improve from 1.90201
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.9208 - mean_absolute_error: 1.9208 - val_loss: 1.9217 - val_mean_absolute_error: 1.9217
# Epoch 24/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.9171 - mean_absolute_error: 1.9171
# Epoch 24: val_loss did not improve from 1.90201
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.9171 - mean_absolute_error: 1.9171 - val_loss: 1.9261 - val_mean_absolute_error: 1.9261
# Epoch 25/500
# 8800/8816 [============================>.] - ETA: 0s - loss: 1.9151 - mean_absolute_error: 1.9151
# Epoch 25: val_loss did not improve from 1.90201
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9149 - mean_absolute_error: 1.9149 - val_loss: 1.9183 - val_mean_absolute_error: 1.9183
# Epoch 26/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.9111 - mean_absolute_error: 1.9111
# Epoch 26: val_loss did not improve from 1.90201
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.9112 - mean_absolute_error: 1.9112 - val_loss: 1.9935 - val_mean_absolute_error: 1.9935
# Epoch 27/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.9110 - mean_absolute_error: 1.9110
# Epoch 27: val_loss improved from 1.90201 to 1.89630, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.9110 - mean_absolute_error: 1.9110 - val_loss: 1.8963 - val_mean_absolute_error: 1.8963
# Epoch 28/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.9073 - mean_absolute_error: 1.9073
# Epoch 28: val_loss did not improve from 1.89630
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.9073 - mean_absolute_error: 1.9073 - val_loss: 1.9154 - val_mean_absolute_error: 1.9154
# Epoch 29/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.9039 - mean_absolute_error: 1.9039
# Epoch 29: val_loss improved from 1.89630 to 1.87746, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.9040 - mean_absolute_error: 1.9040 - val_loss: 1.8775 - val_mean_absolute_error: 1.8775
# Epoch 30/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.9031 - mean_absolute_error: 1.9031
# Epoch 30: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.9031 - mean_absolute_error: 1.9031 - val_loss: 1.8787 - val_mean_absolute_error: 1.8787
# Epoch 31/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.9008 - mean_absolute_error: 1.9008
# Epoch 31: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9007 - mean_absolute_error: 1.9007 - val_loss: 1.8869 - val_mean_absolute_error: 1.8869
# Epoch 32/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.9012 - mean_absolute_error: 1.9012
# Epoch 32: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.9013 - mean_absolute_error: 1.9013 - val_loss: 1.9222 - val_mean_absolute_error: 1.9222
# Epoch 33/500
# 8800/8816 [============================>.] - ETA: 0s - loss: 1.8987 - mean_absolute_error: 1.8987
# Epoch 33: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8986 - mean_absolute_error: 1.8986 - val_loss: 1.9716 - val_mean_absolute_error: 1.9716
# Epoch 34/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8959 - mean_absolute_error: 1.8959
# Epoch 34: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8960 - mean_absolute_error: 1.8960 - val_loss: 1.9056 - val_mean_absolute_error: 1.9056
# Epoch 35/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8943 - mean_absolute_error: 1.8943
# Epoch 35: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8944 - mean_absolute_error: 1.8944 - val_loss: 1.8904 - val_mean_absolute_error: 1.8904
# Epoch 36/500
# 8801/8816 [============================>.] - ETA: 0s - loss: 1.8947 - mean_absolute_error: 1.8947
# Epoch 36: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8946 - mean_absolute_error: 1.8946 - val_loss: 1.9124 - val_mean_absolute_error: 1.9124
# Epoch 37/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8921 - mean_absolute_error: 1.8921
# Epoch 37: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8922 - mean_absolute_error: 1.8922 - val_loss: 1.8886 - val_mean_absolute_error: 1.8886
# Epoch 38/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8903 - mean_absolute_error: 1.8903
# Epoch 38: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8903 - mean_absolute_error: 1.8903 - val_loss: 1.8930 - val_mean_absolute_error: 1.8930
# Epoch 39/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8889 - mean_absolute_error: 1.8889
# Epoch 39: val_loss did not improve from 1.87746
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8890 - mean_absolute_error: 1.8890 - val_loss: 1.8818 - val_mean_absolute_error: 1.8818
# Epoch 40/500
# 8802/8816 [============================>.] - ETA: 0s - loss: 1.8883 - mean_absolute_error: 1.8883
# Epoch 40: val_loss improved from 1.87746 to 1.86928, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8884 - mean_absolute_error: 1.8884 - val_loss: 1.8693 - val_mean_absolute_error: 1.8693
# Epoch 41/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.8863 - mean_absolute_error: 1.8863
# Epoch 41: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8863 - mean_absolute_error: 1.8863 - val_loss: 1.8742 - val_mean_absolute_error: 1.8742
# Epoch 42/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8849 - mean_absolute_error: 1.8849
# Epoch 42: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8849 - mean_absolute_error: 1.8849 - val_loss: 1.8901 - val_mean_absolute_error: 1.8901
# Epoch 43/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8845 - mean_absolute_error: 1.8845
# Epoch 43: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8844 - mean_absolute_error: 1.8844 - val_loss: 1.8834 - val_mean_absolute_error: 1.8834
# Epoch 44/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8842 - mean_absolute_error: 1.8842
# Epoch 44: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8842 - mean_absolute_error: 1.8842 - val_loss: 1.8717 - val_mean_absolute_error: 1.8717
# Epoch 45/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8825 - mean_absolute_error: 1.8825
# Epoch 45: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8825 - mean_absolute_error: 1.8825 - val_loss: 1.8874 - val_mean_absolute_error: 1.8874
# Epoch 46/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.8830 - mean_absolute_error: 1.8830
# Epoch 46: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8830 - mean_absolute_error: 1.8830 - val_loss: 1.8728 - val_mean_absolute_error: 1.8728
# Epoch 47/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8804 - mean_absolute_error: 1.8804
# Epoch 47: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8804 - mean_absolute_error: 1.8804 - val_loss: 1.8740 - val_mean_absolute_error: 1.8740
# Epoch 48/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8790 - mean_absolute_error: 1.8790
# Epoch 48: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8788 - mean_absolute_error: 1.8788 - val_loss: 1.8803 - val_mean_absolute_error: 1.8803
# Epoch 49/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8792 - mean_absolute_error: 1.8792
# Epoch 49: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8790 - mean_absolute_error: 1.8790 - val_loss: 1.8788 - val_mean_absolute_error: 1.8788
# Epoch 50/500
# 8802/8816 [============================>.] - ETA: 0s - loss: 1.8770 - mean_absolute_error: 1.8770
# Epoch 50: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8771 - mean_absolute_error: 1.8771 - val_loss: 1.8818 - val_mean_absolute_error: 1.8818
# Epoch 51/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8777 - mean_absolute_error: 1.8777
# Epoch 51: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8778 - mean_absolute_error: 1.8778 - val_loss: 1.9230 - val_mean_absolute_error: 1.9230
# Epoch 52/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8758 - mean_absolute_error: 1.8758
# Epoch 52: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8759 - mean_absolute_error: 1.8759 - val_loss: 1.9246 - val_mean_absolute_error: 1.9246
# Epoch 53/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8761 - mean_absolute_error: 1.8761
# Epoch 53: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 34s 4ms/step - loss: 1.8762 - mean_absolute_error: 1.8762 - val_loss: 1.9032 - val_mean_absolute_error: 1.9032
# Epoch 54/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8751 - mean_absolute_error: 1.8751
# Epoch 54: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8751 - mean_absolute_error: 1.8751 - val_loss: 1.8713 - val_mean_absolute_error: 1.8713
# Epoch 55/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8744 - mean_absolute_error: 1.8744
# Epoch 55: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 34s 4ms/step - loss: 1.8743 - mean_absolute_error: 1.8743 - val_loss: 1.8698 - val_mean_absolute_error: 1.8698
# Epoch 56/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8736 - mean_absolute_error: 1.8736
# Epoch 56: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8738 - mean_absolute_error: 1.8738 - val_loss: 1.8750 - val_mean_absolute_error: 1.8750
# Epoch 57/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.8722 - mean_absolute_error: 1.8722
# Epoch 57: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 34s 4ms/step - loss: 1.8722 - mean_absolute_error: 1.8722 - val_loss: 1.8793 - val_mean_absolute_error: 1.8793
# Epoch 58/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8705 - mean_absolute_error: 1.8705
# Epoch 58: val_loss did not improve from 1.86928
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8705 - mean_absolute_error: 1.8705 - val_loss: 1.8741 - val_mean_absolute_error: 1.8741
# Epoch 59/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8723 - mean_absolute_error: 1.8723
# Epoch 59: val_loss improved from 1.86928 to 1.86667, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8723 - mean_absolute_error: 1.8723 - val_loss: 1.8667 - val_mean_absolute_error: 1.8667
# Epoch 60/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.8712 - mean_absolute_error: 1.8712
# Epoch 60: val_loss did not improve from 1.86667
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8714 - mean_absolute_error: 1.8714 - val_loss: 1.8880 - val_mean_absolute_error: 1.8880
# Epoch 61/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8694 - mean_absolute_error: 1.8694
# Epoch 61: val_loss did not improve from 1.86667
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8694 - mean_absolute_error: 1.8694 - val_loss: 1.8763 - val_mean_absolute_error: 1.8763
# Epoch 62/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8693 - mean_absolute_error: 1.8693
# Epoch 62: val_loss did not improve from 1.86667
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8693 - mean_absolute_error: 1.8693 - val_loss: 1.8720 - val_mean_absolute_error: 1.8720
# Epoch 63/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8699 - mean_absolute_error: 1.8699
# Epoch 63: val_loss improved from 1.86667 to 1.85560, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8699 - mean_absolute_error: 1.8699 - val_loss: 1.8556 - val_mean_absolute_error: 1.8556
# Epoch 64/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8697 - mean_absolute_error: 1.8697
# Epoch 64: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8697 - mean_absolute_error: 1.8697 - val_loss: 1.8593 - val_mean_absolute_error: 1.8593
# Epoch 65/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8678 - mean_absolute_error: 1.8678
# Epoch 65: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8677 - mean_absolute_error: 1.8677 - val_loss: 1.9457 - val_mean_absolute_error: 1.9457
# Epoch 66/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8673 - mean_absolute_error: 1.8673
# Epoch 66: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8673 - mean_absolute_error: 1.8673 - val_loss: 1.8906 - val_mean_absolute_error: 1.8906
# Epoch 67/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8663 - mean_absolute_error: 1.8663
# Epoch 67: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8664 - mean_absolute_error: 1.8664 - val_loss: 1.8629 - val_mean_absolute_error: 1.8629
# Epoch 68/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8670 - mean_absolute_error: 1.8670
# Epoch 68: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8670 - mean_absolute_error: 1.8670 - val_loss: 1.8616 - val_mean_absolute_error: 1.8616
# Epoch 69/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.8657 - mean_absolute_error: 1.8657
# Epoch 69: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8657 - mean_absolute_error: 1.8657 - val_loss: 1.8756 - val_mean_absolute_error: 1.8756
# Epoch 70/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8655 - mean_absolute_error: 1.8655
# Epoch 70: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8656 - mean_absolute_error: 1.8656 - val_loss: 1.8754 - val_mean_absolute_error: 1.8754
# Epoch 71/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8652 - mean_absolute_error: 1.8652
# Epoch 71: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8653 - mean_absolute_error: 1.8653 - val_loss: 1.8876 - val_mean_absolute_error: 1.8876
# Epoch 72/500
# 8802/8816 [============================>.] - ETA: 0s - loss: 1.8639 - mean_absolute_error: 1.8639
# Epoch 72: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8637 - mean_absolute_error: 1.8637 - val_loss: 1.8681 - val_mean_absolute_error: 1.8681
# Epoch 73/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8634 - mean_absolute_error: 1.8634
# Epoch 73: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8634 - mean_absolute_error: 1.8634 - val_loss: 1.8649 - val_mean_absolute_error: 1.8649
# Epoch 74/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8629 - mean_absolute_error: 1.8629
# Epoch 74: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8630 - mean_absolute_error: 1.8630 - val_loss: 1.8702 - val_mean_absolute_error: 1.8702
# Epoch 75/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.8623 - mean_absolute_error: 1.8623
# Epoch 75: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8622 - mean_absolute_error: 1.8622 - val_loss: 1.9172 - val_mean_absolute_error: 1.9172
# Epoch 76/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8624 - mean_absolute_error: 1.8624
# Epoch 76: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8622 - mean_absolute_error: 1.8622 - val_loss: 1.8689 - val_mean_absolute_error: 1.8689
# Epoch 77/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8608 - mean_absolute_error: 1.8608
# Epoch 77: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8609 - mean_absolute_error: 1.8609 - val_loss: 1.8852 - val_mean_absolute_error: 1.8852
# Epoch 78/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8607 - mean_absolute_error: 1.8607
# Epoch 78: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8608 - mean_absolute_error: 1.8608 - val_loss: 1.8675 - val_mean_absolute_error: 1.8675
# Epoch 79/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8607 - mean_absolute_error: 1.8607
# Epoch 79: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8606 - mean_absolute_error: 1.8606 - val_loss: 1.8845 - val_mean_absolute_error: 1.8845
# Epoch 80/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8604 - mean_absolute_error: 1.8604
# Epoch 80: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8604 - mean_absolute_error: 1.8604 - val_loss: 1.8673 - val_mean_absolute_error: 1.8673
# Epoch 81/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8591 - mean_absolute_error: 1.8591
# Epoch 81: val_loss did not improve from 1.85560
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8590 - mean_absolute_error: 1.8590 - val_loss: 1.8597 - val_mean_absolute_error: 1.8597
# Epoch 82/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8600 - mean_absolute_error: 1.8600
# Epoch 82: val_loss improved from 1.85560 to 1.85478, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8600 - mean_absolute_error: 1.8600 - val_loss: 1.8548 - val_mean_absolute_error: 1.8548
# Epoch 83/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8603 - mean_absolute_error: 1.8603
# Epoch 83: val_loss did not improve from 1.85478
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8603 - mean_absolute_error: 1.8603 - val_loss: 1.8631 - val_mean_absolute_error: 1.8631
# Epoch 84/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.8597 - mean_absolute_error: 1.8597
# Epoch 84: val_loss did not improve from 1.85478
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8597 - mean_absolute_error: 1.8597 - val_loss: 1.8562 - val_mean_absolute_error: 1.8562
# Epoch 85/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8590 - mean_absolute_error: 1.8590
# Epoch 85: val_loss did not improve from 1.85478
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8591 - mean_absolute_error: 1.8591 - val_loss: 1.8740 - val_mean_absolute_error: 1.8740
# Epoch 86/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8582 - mean_absolute_error: 1.8582
# Epoch 86: val_loss improved from 1.85478 to 1.85176, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8582 - mean_absolute_error: 1.8582 - val_loss: 1.8518 - val_mean_absolute_error: 1.8518
# Epoch 87/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8583 - mean_absolute_error: 1.8583
# Epoch 87: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8583 - mean_absolute_error: 1.8583 - val_loss: 1.8806 - val_mean_absolute_error: 1.8806
# Epoch 88/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8574 - mean_absolute_error: 1.8574
# Epoch 88: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8574 - mean_absolute_error: 1.8574 - val_loss: 1.8805 - val_mean_absolute_error: 1.8805
# Epoch 89/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8568 - mean_absolute_error: 1.8568
# Epoch 89: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8567 - mean_absolute_error: 1.8567 - val_loss: 1.8670 - val_mean_absolute_error: 1.8670
# Epoch 90/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8565 - mean_absolute_error: 1.8565
# Epoch 90: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8565 - mean_absolute_error: 1.8565 - val_loss: 1.8752 - val_mean_absolute_error: 1.8752
# Epoch 91/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8571 - mean_absolute_error: 1.8571
# Epoch 91: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8572 - mean_absolute_error: 1.8572 - val_loss: 1.9084 - val_mean_absolute_error: 1.9084
# Epoch 92/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8553 - mean_absolute_error: 1.8553
# Epoch 92: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8552 - mean_absolute_error: 1.8552 - val_loss: 1.8607 - val_mean_absolute_error: 1.8607
# Epoch 93/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8563 - mean_absolute_error: 1.8563
# Epoch 93: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8563 - mean_absolute_error: 1.8563 - val_loss: 1.8690 - val_mean_absolute_error: 1.8690
# Epoch 94/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8551 - mean_absolute_error: 1.8551
# Epoch 94: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8551 - mean_absolute_error: 1.8551 - val_loss: 1.8605 - val_mean_absolute_error: 1.8605
# Epoch 95/500
# 8805/8816 [============================>.] - ETA: 0s - loss: 1.8550 - mean_absolute_error: 1.8550
# Epoch 95: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8549 - mean_absolute_error: 1.8549 - val_loss: 1.8674 - val_mean_absolute_error: 1.8674
# Epoch 96/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8560 - mean_absolute_error: 1.8560
# Epoch 96: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8559 - mean_absolute_error: 1.8559 - val_loss: 1.8826 - val_mean_absolute_error: 1.8826
# Epoch 97/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8550 - mean_absolute_error: 1.8550
# Epoch 97: val_loss did not improve from 1.85176
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8550 - mean_absolute_error: 1.8550 - val_loss: 1.8552 - val_mean_absolute_error: 1.8552
# Epoch 98/500
# 8801/8816 [============================>.] - ETA: 0s - loss: 1.8557 - mean_absolute_error: 1.8557
# Epoch 98: val_loss improved from 1.85176 to 1.84451, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8555 - mean_absolute_error: 1.8555 - val_loss: 1.8445 - val_mean_absolute_error: 1.8445
# Epoch 99/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8549 - mean_absolute_error: 1.8549
# Epoch 99: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8549 - mean_absolute_error: 1.8549 - val_loss: 1.8586 - val_mean_absolute_error: 1.8586
# Epoch 100/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8531 - mean_absolute_error: 1.8531
# Epoch 100: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8532 - mean_absolute_error: 1.8532 - val_loss: 1.8650 - val_mean_absolute_error: 1.8650
# Epoch 101/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.8537 - mean_absolute_error: 1.8537
# Epoch 101: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8538 - mean_absolute_error: 1.8538 - val_loss: 1.8507 - val_mean_absolute_error: 1.8507
# Epoch 102/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8533 - mean_absolute_error: 1.8533
# Epoch 102: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8533 - mean_absolute_error: 1.8533 - val_loss: 1.8695 - val_mean_absolute_error: 1.8695
# Epoch 103/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8527 - mean_absolute_error: 1.8527
# Epoch 103: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8527 - mean_absolute_error: 1.8527 - val_loss: 1.8714 - val_mean_absolute_error: 1.8714
# Epoch 104/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8529 - mean_absolute_error: 1.8529
# Epoch 104: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8529 - mean_absolute_error: 1.8529 - val_loss: 1.8637 - val_mean_absolute_error: 1.8637
# Epoch 105/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8526 - mean_absolute_error: 1.8526
# Epoch 105: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8526 - mean_absolute_error: 1.8526 - val_loss: 1.8574 - val_mean_absolute_error: 1.8574
# Epoch 106/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8520 - mean_absolute_error: 1.8520
# Epoch 106: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8519 - mean_absolute_error: 1.8519 - val_loss: 1.8569 - val_mean_absolute_error: 1.8569
# Epoch 107/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8526 - mean_absolute_error: 1.8526
# Epoch 107: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8526 - mean_absolute_error: 1.8526 - val_loss: 1.8661 - val_mean_absolute_error: 1.8661
# Epoch 108/500
# 8802/8816 [============================>.] - ETA: 0s - loss: 1.8516 - mean_absolute_error: 1.8516
# Epoch 108: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8518 - mean_absolute_error: 1.8518 - val_loss: 1.8529 - val_mean_absolute_error: 1.8529
# Epoch 109/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8514 - mean_absolute_error: 1.8514
# Epoch 109: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8514 - mean_absolute_error: 1.8514 - val_loss: 1.8539 - val_mean_absolute_error: 1.8539
# Epoch 110/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8512 - mean_absolute_error: 1.8512
# Epoch 110: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8512 - mean_absolute_error: 1.8512 - val_loss: 1.8543 - val_mean_absolute_error: 1.8543
# Epoch 111/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8518 - mean_absolute_error: 1.8518
# Epoch 111: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8518 - mean_absolute_error: 1.8518 - val_loss: 1.8561 - val_mean_absolute_error: 1.8561
# Epoch 112/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8513 - mean_absolute_error: 1.8513
# Epoch 112: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8513 - mean_absolute_error: 1.8513 - val_loss: 1.8645 - val_mean_absolute_error: 1.8645
# Epoch 113/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8497 - mean_absolute_error: 1.8497
# Epoch 113: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8498 - mean_absolute_error: 1.8498 - val_loss: 1.8518 - val_mean_absolute_error: 1.8518
# Epoch 114/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8499 - mean_absolute_error: 1.8499
# Epoch 114: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 34s 4ms/step - loss: 1.8500 - mean_absolute_error: 1.8500 - val_loss: 1.8565 - val_mean_absolute_error: 1.8565
# Epoch 115/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8502 - mean_absolute_error: 1.8502
# Epoch 115: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8503 - mean_absolute_error: 1.8503 - val_loss: 1.8482 - val_mean_absolute_error: 1.8482
# Epoch 116/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8497 - mean_absolute_error: 1.8497
# Epoch 116: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8498 - mean_absolute_error: 1.8498 - val_loss: 1.8557 - val_mean_absolute_error: 1.8557
# Epoch 117/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.8486 - mean_absolute_error: 1.8486
# Epoch 117: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8487 - mean_absolute_error: 1.8487 - val_loss: 1.8792 - val_mean_absolute_error: 1.8792
# Epoch 118/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.8494 - mean_absolute_error: 1.8494
# Epoch 118: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8494 - mean_absolute_error: 1.8494 - val_loss: 1.8507 - val_mean_absolute_error: 1.8507
# Epoch 119/500
# 8800/8816 [============================>.] - ETA: 0s - loss: 1.8499 - mean_absolute_error: 1.8499
# Epoch 119: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8501 - mean_absolute_error: 1.8501 - val_loss: 1.8483 - val_mean_absolute_error: 1.8483
# Epoch 120/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8491 - mean_absolute_error: 1.8491
# Epoch 120: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8492 - mean_absolute_error: 1.8492 - val_loss: 1.8547 - val_mean_absolute_error: 1.8547
# Epoch 121/500
# 8802/8816 [============================>.] - ETA: 0s - loss: 1.8489 - mean_absolute_error: 1.8489
# Epoch 121: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8490 - mean_absolute_error: 1.8490 - val_loss: 1.8554 - val_mean_absolute_error: 1.8554
# Epoch 122/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8487 - mean_absolute_error: 1.8487
# Epoch 122: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8488 - mean_absolute_error: 1.8488 - val_loss: 1.8500 - val_mean_absolute_error: 1.8500
# Epoch 123/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8483 - mean_absolute_error: 1.8483
# Epoch 123: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8483 - mean_absolute_error: 1.8483 - val_loss: 1.8509 - val_mean_absolute_error: 1.8509
# Epoch 124/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8478 - mean_absolute_error: 1.8478
# Epoch 124: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8478 - mean_absolute_error: 1.8478 - val_loss: 1.8574 - val_mean_absolute_error: 1.8574
# Epoch 125/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8488 - mean_absolute_error: 1.8488
# Epoch 125: val_loss did not improve from 1.84451
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8490 - mean_absolute_error: 1.8490 - val_loss: 1.8460 - val_mean_absolute_error: 1.8460
# Epoch 126/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8484 - mean_absolute_error: 1.8484
# Epoch 126: val_loss improved from 1.84451 to 1.84289, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8484 - mean_absolute_error: 1.8484 - val_loss: 1.8429 - val_mean_absolute_error: 1.8429
# Epoch 127/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8469 - mean_absolute_error: 1.8469
# Epoch 127: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8469 - mean_absolute_error: 1.8469 - val_loss: 1.8498 - val_mean_absolute_error: 1.8498
# Epoch 128/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8477 - mean_absolute_error: 1.8477
# Epoch 128: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8476 - mean_absolute_error: 1.8476 - val_loss: 1.8448 - val_mean_absolute_error: 1.8448
# Epoch 129/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8466 - mean_absolute_error: 1.8466
# Epoch 129: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8466 - mean_absolute_error: 1.8466 - val_loss: 1.8554 - val_mean_absolute_error: 1.8554
# Epoch 130/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8470 - mean_absolute_error: 1.8470
# Epoch 130: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8470 - mean_absolute_error: 1.8470 - val_loss: 1.8527 - val_mean_absolute_error: 1.8527
# Epoch 131/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8477 - mean_absolute_error: 1.8477
# Epoch 131: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8478 - mean_absolute_error: 1.8478 - val_loss: 1.8679 - val_mean_absolute_error: 1.8679
# Epoch 132/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8469 - mean_absolute_error: 1.8469
# Epoch 132: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8469 - mean_absolute_error: 1.8469 - val_loss: 1.8476 - val_mean_absolute_error: 1.8476
# Epoch 133/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8455 - mean_absolute_error: 1.8455
# Epoch 133: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8455 - mean_absolute_error: 1.8455 - val_loss: 1.8622 - val_mean_absolute_error: 1.8622
# Epoch 134/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8457 - mean_absolute_error: 1.8457
# Epoch 134: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8456 - mean_absolute_error: 1.8456 - val_loss: 1.8558 - val_mean_absolute_error: 1.8558
# Epoch 135/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8463 - mean_absolute_error: 1.8463
# Epoch 135: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8463 - mean_absolute_error: 1.8463 - val_loss: 1.8512 - val_mean_absolute_error: 1.8512
# Epoch 136/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8460 - mean_absolute_error: 1.8460
# Epoch 136: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 34s 4ms/step - loss: 1.8459 - mean_absolute_error: 1.8459 - val_loss: 1.8500 - val_mean_absolute_error: 1.8500
# Epoch 137/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8453 - mean_absolute_error: 1.8453
# Epoch 137: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 34s 4ms/step - loss: 1.8453 - mean_absolute_error: 1.8453 - val_loss: 1.8503 - val_mean_absolute_error: 1.8503
# Epoch 138/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8469 - mean_absolute_error: 1.8469
# Epoch 138: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8469 - mean_absolute_error: 1.8469 - val_loss: 1.8521 - val_mean_absolute_error: 1.8521
# Epoch 139/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8452 - mean_absolute_error: 1.8452
# Epoch 139: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8451 - mean_absolute_error: 1.8451 - val_loss: 1.8619 - val_mean_absolute_error: 1.8619
# Epoch 140/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8458 - mean_absolute_error: 1.8458
# Epoch 140: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8459 - mean_absolute_error: 1.8459 - val_loss: 1.8504 - val_mean_absolute_error: 1.8504
# Epoch 141/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8440 - mean_absolute_error: 1.8440
# Epoch 141: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8441 - mean_absolute_error: 1.8441 - val_loss: 1.8766 - val_mean_absolute_error: 1.8766
# Epoch 142/500
# 8802/8816 [============================>.] - ETA: 0s - loss: 1.8447 - mean_absolute_error: 1.8447
# Epoch 142: val_loss did not improve from 1.84289
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8447 - mean_absolute_error: 1.8447 - val_loss: 1.8646 - val_mean_absolute_error: 1.8646
# Epoch 143/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8448 - mean_absolute_error: 1.8448
# Epoch 143: val_loss improved from 1.84289 to 1.84240, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8448 - mean_absolute_error: 1.8448 - val_loss: 1.8424 - val_mean_absolute_error: 1.8424
# Epoch 144/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8438 - mean_absolute_error: 1.8438
# Epoch 144: val_loss did not improve from 1.84240
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8438 - mean_absolute_error: 1.8438 - val_loss: 1.8830 - val_mean_absolute_error: 1.8830
# Epoch 145/500
# 8805/8816 [============================>.] - ETA: 0s - loss: 1.8444 - mean_absolute_error: 1.8444
# Epoch 145: val_loss did not improve from 1.84240
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8446 - mean_absolute_error: 1.8446 - val_loss: 1.8654 - val_mean_absolute_error: 1.8654
# Epoch 146/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8445 - mean_absolute_error: 1.8445
# Epoch 146: val_loss did not improve from 1.84240
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8444 - mean_absolute_error: 1.8444 - val_loss: 1.8459 - val_mean_absolute_error: 1.8459
# Epoch 147/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8441 - mean_absolute_error: 1.8441
# Epoch 147: val_loss did not improve from 1.84240
# 8816/8816 [==============================] - 34s 4ms/step - loss: 1.8441 - mean_absolute_error: 1.8441 - val_loss: 1.8482 - val_mean_absolute_error: 1.8482
# Epoch 148/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8440 - mean_absolute_error: 1.8440
# Epoch 148: val_loss did not improve from 1.84240
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8439 - mean_absolute_error: 1.8439 - val_loss: 1.8515 - val_mean_absolute_error: 1.8515
# Epoch 149/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.8441 - mean_absolute_error: 1.8441
# Epoch 149: val_loss did not improve from 1.84240
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8442 - mean_absolute_error: 1.8442 - val_loss: 1.8510 - val_mean_absolute_error: 1.8510
# Epoch 150/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.8441 - mean_absolute_error: 1.8441
# ...
# Epoch 451/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8286 - mean_absolute_error: 1.8286
# Epoch 451: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8287 - mean_absolute_error: 1.8287 - val_loss: 1.8437 - val_mean_absolute_error: 1.8437
# Epoch 452/500
# 8800/8816 [============================>.] - ETA: 0s - loss: 1.8284 - mean_absolute_error: 1.8284
# Epoch 452: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 28s 3ms/step - loss: 1.8284 - mean_absolute_error: 1.8284 - val_loss: 1.8371 - val_mean_absolute_error: 1.8371
# Epoch 453/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8287 - mean_absolute_error: 1.8287
# Epoch 453: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8288 - mean_absolute_error: 1.8288 - val_loss: 1.8617 - val_mean_absolute_error: 1.8617
# Epoch 454/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8279 - mean_absolute_error: 1.8279
# Epoch 454: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8279 - mean_absolute_error: 1.8279 - val_loss: 1.8531 - val_mean_absolute_error: 1.8531
# Epoch 455/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8274 - mean_absolute_error: 1.8274
# Epoch 455: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8275 - mean_absolute_error: 1.8275 - val_loss: 1.8425 - val_mean_absolute_error: 1.8425
# Epoch 456/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.8291 - mean_absolute_error: 1.8291
# Epoch 456: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8290 - mean_absolute_error: 1.8290 - val_loss: 1.8545 - val_mean_absolute_error: 1.8545
# Epoch 457/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8285 - mean_absolute_error: 1.8285
# Epoch 457: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8288 - mean_absolute_error: 1.8288 - val_loss: 1.8488 - val_mean_absolute_error: 1.8488
# Epoch 458/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8291 - mean_absolute_error: 1.8291
# Epoch 458: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 28s 3ms/step - loss: 1.8291 - mean_absolute_error: 1.8291 - val_loss: 1.8527 - val_mean_absolute_error: 1.8527
# Epoch 459/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8286 - mean_absolute_error: 1.8286
# Epoch 459: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 28s 3ms/step - loss: 1.8287 - mean_absolute_error: 1.8287 - val_loss: 1.8406 - val_mean_absolute_error: 1.8406
# Epoch 460/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8274 - mean_absolute_error: 1.8274
# Epoch 460: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8275 - mean_absolute_error: 1.8275 - val_loss: 1.8454 - val_mean_absolute_error: 1.8454
# Epoch 461/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8275 - mean_absolute_error: 1.8275
# Epoch 461: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 28s 3ms/step - loss: 1.8275 - mean_absolute_error: 1.8275 - val_loss: 1.8445 - val_mean_absolute_error: 1.8445
# Epoch 462/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8275 - mean_absolute_error: 1.8275
# Epoch 462: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 28s 3ms/step - loss: 1.8275 - mean_absolute_error: 1.8275 - val_loss: 1.8494 - val_mean_absolute_error: 1.8494
# Epoch 463/500
# 8805/8816 [============================>.] - ETA: 0s - loss: 1.8277 - mean_absolute_error: 1.8277
# Epoch 463: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8276 - mean_absolute_error: 1.8276 - val_loss: 1.8399 - val_mean_absolute_error: 1.8399
# Epoch 464/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8289 - mean_absolute_error: 1.8289
# Epoch 464: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8289 - mean_absolute_error: 1.8289 - val_loss: 1.8453 - val_mean_absolute_error: 1.8453
# Epoch 465/500
# 8800/8816 [============================>.] - ETA: 0s - loss: 1.8276 - mean_absolute_error: 1.8276
# Epoch 465: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8275 - mean_absolute_error: 1.8275 - val_loss: 1.8410 - val_mean_absolute_error: 1.8410
# Epoch 466/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8276 - mean_absolute_error: 1.8276
# Epoch 466: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8276 - mean_absolute_error: 1.8276 - val_loss: 1.8343 - val_mean_absolute_error: 1.8343
# Epoch 467/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8283 - mean_absolute_error: 1.8283
# Epoch 467: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8283 - mean_absolute_error: 1.8283 - val_loss: 1.8461 - val_mean_absolute_error: 1.8461
# Epoch 468/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8277 - mean_absolute_error: 1.8277
# Epoch 468: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8276 - mean_absolute_error: 1.8276 - val_loss: 1.8467 - val_mean_absolute_error: 1.8467
# Epoch 469/500
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.8284 - mean_absolute_error: 1.8284
# Epoch 469: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8284 - mean_absolute_error: 1.8284 - val_loss: 1.8450 - val_mean_absolute_error: 1.8450
# Epoch 470/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8283 - mean_absolute_error: 1.8283
# Epoch 470: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8283 - mean_absolute_error: 1.8283 - val_loss: 1.8424 - val_mean_absolute_error: 1.8424
# Epoch 471/500
# 8801/8816 [============================>.] - ETA: 0s - loss: 1.8276 - mean_absolute_error: 1.8276
# Epoch 471: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8275 - mean_absolute_error: 1.8275 - val_loss: 1.8340 - val_mean_absolute_error: 1.8340
# Epoch 472/500
# 8801/8816 [============================>.] - ETA: 0s - loss: 1.8285 - mean_absolute_error: 1.8285
# Epoch 472: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8285 - mean_absolute_error: 1.8285 - val_loss: 1.8483 - val_mean_absolute_error: 1.8483
# Epoch 473/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8287 - mean_absolute_error: 1.8287
# Epoch 473: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8287 - mean_absolute_error: 1.8287 - val_loss: 1.8343 - val_mean_absolute_error: 1.8343
# Epoch 474/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8280 - mean_absolute_error: 1.8280
# Epoch 474: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8280 - mean_absolute_error: 1.8280 - val_loss: 1.8475 - val_mean_absolute_error: 1.8475
# Epoch 475/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8277 - mean_absolute_error: 1.8277
# Epoch 475: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8276 - mean_absolute_error: 1.8276 - val_loss: 1.8412 - val_mean_absolute_error: 1.8412
# Epoch 476/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8286 - mean_absolute_error: 1.8286
# Epoch 476: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8286 - mean_absolute_error: 1.8286 - val_loss: 1.8565 - val_mean_absolute_error: 1.8565
# Epoch 477/500
# 8804/8816 [============================>.] - ETA: 0s - loss: 1.8278 - mean_absolute_error: 1.8278
# Epoch 477: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 33s 4ms/step - loss: 1.8279 - mean_absolute_error: 1.8279 - val_loss: 1.8480 - val_mean_absolute_error: 1.8480
# Epoch 478/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8277 - mean_absolute_error: 1.8277
# Epoch 478: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8278 - mean_absolute_error: 1.8278 - val_loss: 1.8369 - val_mean_absolute_error: 1.8369
# Epoch 479/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8285 - mean_absolute_error: 1.8285
# Epoch 479: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8285 - mean_absolute_error: 1.8285 - val_loss: 1.8407 - val_mean_absolute_error: 1.8407
# Epoch 480/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8278 - mean_absolute_error: 1.8278
# Epoch 480: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8278 - mean_absolute_error: 1.8278 - val_loss: 1.8384 - val_mean_absolute_error: 1.8384
# Epoch 481/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8281 - mean_absolute_error: 1.8281
# Epoch 481: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 28s 3ms/step - loss: 1.8280 - mean_absolute_error: 1.8280 - val_loss: 1.8398 - val_mean_absolute_error: 1.8398
# Epoch 482/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8287 - mean_absolute_error: 1.8287
# Epoch 482: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 28s 3ms/step - loss: 1.8287 - mean_absolute_error: 1.8287 - val_loss: 1.8445 - val_mean_absolute_error: 1.8445
# Epoch 483/500
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.8274 - mean_absolute_error: 1.8274
# Epoch 483: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8274 - mean_absolute_error: 1.8274 - val_loss: 1.8375 - val_mean_absolute_error: 1.8375
# Epoch 484/500
# 8802/8816 [============================>.] - ETA: 0s - loss: 1.8273 - mean_absolute_error: 1.8273
# Epoch 484: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8274 - mean_absolute_error: 1.8274 - val_loss: 1.8498 - val_mean_absolute_error: 1.8498
# Epoch 485/500
# 8809/8816 [============================>.] - ETA: 0s - loss: 1.8277 - mean_absolute_error: 1.8277
# Epoch 485: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 28s 3ms/step - loss: 1.8277 - mean_absolute_error: 1.8277 - val_loss: 1.8474 - val_mean_absolute_error: 1.8474
# Epoch 486/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8275 - mean_absolute_error: 1.8275
# Epoch 486: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8275 - mean_absolute_error: 1.8275 - val_loss: 1.8524 - val_mean_absolute_error: 1.8524
# Epoch 487/500
# 8805/8816 [============================>.] - ETA: 0s - loss: 1.8282 - mean_absolute_error: 1.8282
# Epoch 487: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8284 - mean_absolute_error: 1.8284 - val_loss: 1.8571 - val_mean_absolute_error: 1.8571
# Epoch 488/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8278 - mean_absolute_error: 1.8278
# Epoch 488: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8279 - mean_absolute_error: 1.8279 - val_loss: 1.8365 - val_mean_absolute_error: 1.8365
# Epoch 489/500
# 8808/8816 [============================>.] - ETA: 0s - loss: 1.8280 - mean_absolute_error: 1.8280
# Epoch 489: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8279 - mean_absolute_error: 1.8279 - val_loss: 1.8477 - val_mean_absolute_error: 1.8477
# Epoch 490/500
# 8800/8816 [============================>.] - ETA: 0s - loss: 1.8278 - mean_absolute_error: 1.8278
# Epoch 490: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8278 - mean_absolute_error: 1.8278 - val_loss: 1.8469 - val_mean_absolute_error: 1.8469
# Epoch 491/500
# 8812/8816 [============================>.] - ETA: 0s - loss: 1.8269 - mean_absolute_error: 1.8269
# Epoch 491: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8271 - mean_absolute_error: 1.8271 - val_loss: 1.8401 - val_mean_absolute_error: 1.8401
# Epoch 492/500
# 8813/8816 [============================>.] - ETA: 0s - loss: 1.8275 - mean_absolute_error: 1.8275
# Epoch 492: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8276 - mean_absolute_error: 1.8276 - val_loss: 1.8490 - val_mean_absolute_error: 1.8490
# Epoch 493/500
# 8806/8816 [============================>.] - ETA: 0s - loss: 1.8270 - mean_absolute_error: 1.8270
# Epoch 493: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8271 - mean_absolute_error: 1.8271 - val_loss: 1.8366 - val_mean_absolute_error: 1.8366
# Epoch 494/500
# 8805/8816 [============================>.] - ETA: 0s - loss: 1.8275 - mean_absolute_error: 1.8275
# Epoch 494: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8276 - mean_absolute_error: 1.8276 - val_loss: 1.8424 - val_mean_absolute_error: 1.8424
# Epoch 495/500
# 8810/8816 [============================>.] - ETA: 0s - loss: 1.8276 - mean_absolute_error: 1.8276
# Epoch 495: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 30s 3ms/step - loss: 1.8277 - mean_absolute_error: 1.8277 - val_loss: 1.8386 - val_mean_absolute_error: 1.8386
# Epoch 496/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8275 - mean_absolute_error: 1.8275
# Epoch 496: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8275 - mean_absolute_error: 1.8275 - val_loss: 1.8469 - val_mean_absolute_error: 1.8469
# Epoch 497/500
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.8276 - mean_absolute_error: 1.8276
# Epoch 497: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 4ms/step - loss: 1.8276 - mean_absolute_error: 1.8276 - val_loss: 1.8619 - val_mean_absolute_error: 1.8619
# Epoch 498/500
# 8816/8816 [==============================] - ETA: 0s - loss: 1.8279 - mean_absolute_error: 1.8279
# Epoch 498: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 32s 4ms/step - loss: 1.8279 - mean_absolute_error: 1.8279 - val_loss: 1.8371 - val_mean_absolute_error: 1.8371
# Epoch 499/500
# 8814/8816 [============================>.] - ETA: 0s - loss: 1.8276 - mean_absolute_error: 1.8276
# Epoch 499: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 31s 3ms/step - loss: 1.8276 - mean_absolute_error: 1.8276 - val_loss: 1.8384 - val_mean_absolute_error: 1.8384
# Epoch 500/500
# 8803/8816 [============================>.] - ETA: 0s - loss: 1.8266 - mean_absolute_error: 1.8266
# Epoch 500: val_loss did not improve from 1.83324
# 8816/8816 [==============================] - 29s 3ms/step - loss: 1.8266 - mean_absolute_error: 1.8266 - val_loss: 1.8522 - val_mean_absolute_error: 1.8522

# %%
# Load wights file of the best model :
wights_file = f'Weights--.hdf5'  # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(test_df)
# Out:
# 980/980 [==============================] - 2s 1ms/step

# %% [markdown]
# # Saving Dataset in correct format

# %%
predictions
# Out:
# array([[ 17.091112],
#        [ 17.091112],
#        [ 17.091112],
#        ...,
#        [-12.099157],
#        [-12.099159],
#        [-12.099159]], dtype=float32)

# %%
final=pd.DataFrame(predictions,columns=['contest-tmp2m-14d__tmp2m'])

# %%
i=375734
final['index']=0
while i<407088:
    final['index'][i-375734]=i
    i+=1
final
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     17.091112  375734
# 1                     17.091112  375735
# 2                     17.091112  375736
# 3                     17.091112  375737
# 4                     17.091112  375738
# ...                         ...     ...
# 31349                -12.099157  407083
# 31350                -12.099157  407084
# 31351                -12.099157  407085
# 31352                -12.099159  407086
# 31353                -12.099159  407087
#
# [31354 rows x 2 columns]

# %%
final.to_csv('/kaggle/working/wetherprediction.csv',index=False)
