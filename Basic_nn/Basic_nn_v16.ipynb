# %% [markdown]
# Link to another tutorial site that I was using to figure this out:
# https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing #Convert categorical data to neumeric values

from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/widsdatathon2023/train_data.csv
# /kaggle/input/widsdatathon2023/test_data.csv
# /kaggle/input/widsdatathon2023/sample_solution.csv

# %%
keep_columns=['lat','month','contest-tmp2m-14d__tmp2m',
              'climateregions__climateregion','lon']
X_columns=[['lat','month',
              'climateregions__climateregion','lon']]

# %%
def seperate_monthly(df):
    df[['month','day','year']]=df.startdate.str.split('/',expand=True)
    df=df.drop('day', axis=1)
    df=df.drop('startdate',axis=1)
    return df

# %%
def eliminate_columns(df):
    for col in df.columns:
        if col in keep_columns:
            print(col)
        else: 
            df=df.drop(col, axis=1)
    return df

# %%
#need to come up with a different way to do this, because it is not working
def seperate_y(df):
    y_df=df['contest-tmp2m-14d__tmp2m']
    X_df=df.drop('contest-tmp2m-14d__tmp2m',axis=1)
    return y_df,X_df

# %%
def normanlize_data(df,train_df):
    for column in df.columns:
        df[column] = df[column]  /  train_df[column].abs().max()
    return df

# %%
train_df=pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
train_df=train_df.dropna(axis=0)
test_df=pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
test_df=test_df.dropna(axis=0)
train_df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                          29.02                     31.64
# 1                          29.02                     31.64
# 2                          29.02                     31.64
# 3                          29.02                     31.64
# 4                          29.02                     31.64
# ...                          ...                       ...
# 375729                     23.13                     27.20
# 375730                     23.13                     27.20
# 375731                     23.13                     27.20
# 375732                     23.13                     27.20
# 375733                     23.13                     27.20
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                         29.57                    30.73
# 1                         29.57                    30.73
# 2                         29.57                    30.73
# 3                         29.57                    30.73
# 4                         29.57                    30.73
# ...                         ...                      ...
# 375729                    20.25                    24.43
# 375730                    20.25                    24.43
# 375731                    20.25                    24.43
# 375732                    20.25                    24.43
# 375733                    20.25                    24.43
#
#         nmme0-tmp2m-34w__cfsv20  ...  wind-vwnd-925-2010-11  \
# 0                         29.71  ...                 -27.68
# 1                         29.71  ...                 -21.13
# 2                         29.71  ...                 -10.72
# 3                         29.71  ...                   0.33
# 4                         29.71  ...                   9.83
# ...                         ...  ...                    ...
# 375729                    18.35  ...                 -15.64
# 375730                    18.35  ...                  -7.59
# 375731                    18.35  ...                  -6.25
# 375732                    18.35  ...                  -7.16
# 375733                    18.35  ...                 -12.36
#
#         wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  \
# 0                      -37.21                   8.32                   9.56
# 1                      -36.57                   8.77                  21.17
# 2                      -34.16                   6.99                  32.16
# 3                      -31.04                   6.17                  39.66
# 4                      -31.80                   7.47                  38.62
# ...                       ...                    ...                    ...
# 375729                 -75.68                  -3.09                   6.93
# 375730                 -76.42                 -13.55                  13.36
# 375731                 -70.65                 -23.93                  22.62
# 375732                 -57.67                 -33.55                  32.06
# 375733                 -44.67                 -32.46                  36.25
#
#         wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  \
# 0                       -2.03                  48.13                  28.09
# 1                        4.44                  48.60                  27.41
# 2                        5.01                  48.53                  19.21
# 3                       -1.41                  50.59                   8.29
# 4                       -5.21                  54.73                  -2.58
# ...                       ...                    ...                    ...
# 375729                 -16.69                  16.98                 -13.85
# 375730                 -15.96                  20.45                 -16.36
# 375731                 -16.71                  20.28                 -15.48
# 375732                 -16.07                  16.60                 -20.61
# 375733                 -12.72                  15.98                 -22.56
#
#         wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  wind-vwnd-925-2010-20
# 0                      -13.50                  11.90                   4.58
# 1                      -23.77                  15.44                   3.42
# 2                      -33.16                  15.11                   4.82
# 3                      -37.22                  18.24                   9.74
# 4                      -42.30                  21.91                  10.95
# ...                       ...                    ...                    ...
# 375729                  50.25                 -31.33                   0.77
# 375730                  51.65                 -30.73                  10.10
# 375731                  48.58                 -18.74                   9.28
# 375732                  39.23                 -16.26                  -0.22
# 375733                  32.53                 -21.89                  -1.20
#
# [352604 rows x 246 columns]

# %%
#Shuffeling the data
train_df = train_df.sample(frac = 1)

# %%
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
train_df['climateregions__climateregion']=le.fit_transform(train_df['climateregions__climateregion'])
test_df['climateregions__climateregion']=le.fit_transform(test_df['climateregions__climateregion'])

# %%
print('training set prep')
train_df=seperate_monthly(train_df)
#train_df=eliminate_columns(train_df)
print('test set prep')
test_df=seperate_monthly(test_df)
#test_df=eliminate_columns(test_df)
# Out:
# training set prep
# test set prep

# %%
train_df
# Out:
#          index       lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 240466  240466  0.727273  0.166667                              534.82
# 230452  230452  0.681818  0.666667                              126.64
# 292613  292613  0.818182  0.700000                              271.68
# 277814  277814  0.818182  0.033333                              281.48
# 183019  183019  0.590909  0.433333                              409.64
# ...        ...       ...       ...                                 ...
# 172860  172860  0.545455  0.966667                              465.01
# 175432  175432  0.590909  0.066667                              558.48
# 306444  306444  0.863636  0.433333                               63.95
# 68656    68656  0.318182  0.800000                              924.61
# 327438  327438  0.909091  0.433333                              471.55
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 240466                     20.59                     21.67
# 230452                     -2.04                     -0.09
# 292613                     -0.66                      0.27
# 277814                     14.25                     15.07
# 183019                     12.40                     15.30
# ...                          ...                       ...
# 172860                     29.28                     32.18
# 175432                     23.66                     23.68
# 306444                     -7.73                     -7.60
# 68656                      27.17                     31.02
# 327438                     13.78                     16.83
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 240466                    20.62                    22.60
# 230452                    -2.27                    -2.65
# 292613                     2.72                     0.31
# 277814                    13.79                    13.82
# 183019                    12.48                    12.30
# ...                         ...                      ...
# 172860                    29.28                    28.16
# 175432                    21.88                    22.75
# 306444                    -6.75                    -7.41
# 68656                     24.46                    27.03
# 327438                    15.04                    15.25
#
#         nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 240466                    19.77                        22.08  ...
# 230452                     0.20                         0.58  ...
# 292613                     0.33                         3.25  ...
# 277814                    14.68                        16.76  ...
# 183019                    12.07                         8.94  ...
# ...                         ...                          ...  ...
# 172860                    23.60                        30.32  ...
# 175432                    20.29                        28.08  ...
# 306444                    -4.67                        -6.26  ...
# 68656                     26.04                        28.60  ...
# 327438                    15.05                        13.93  ...
#
#         wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 240466                   0.08                  19.96                 -27.29
# 230452                  -2.56                   0.43                 -32.57
# 292613                  36.59                  30.90                 -48.66
# 277814                  -5.76                  31.74                   8.57
# 183019                  -9.42                  27.02                 -22.64
# ...                       ...                    ...                    ...
# 172860                 -45.78                  37.53                   1.11
# 175432                   6.68                   7.30                 -33.97
# 306444                  56.04                 -30.92                   3.37
# 68656                   27.87                 -10.57                  -8.98
# 327438                  13.03                  -3.51                  20.03
#
#         wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 240466                  49.88                   5.67                  51.13
# 230452                 -26.38                  -5.52                  38.63
# 292613                 -13.36                 -18.88                 -26.21
# 277814                   1.06                 -11.40                  18.00
# 183019                 -24.17                 -14.16                   1.39
# ...                       ...                    ...                    ...
# 172860                 -10.35                 -34.99                  73.90
# 175432                  10.50                   3.91                  30.85
# 306444                  -8.56                 -21.02                  15.27
# 68656                  -61.14                  15.33                  37.83
# 327438                 -23.89                  -7.18                  19.61
#
#         wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 240466                  35.61                 -18.27      7    16
# 230452                   6.70                   7.44      3    15
# 292613                   3.04                  55.78      4    15
# 277814                   0.58                  16.50     10    14
# 183019                  10.58                 -30.92      5    15
# ...                       ...                    ...    ...   ...
# 172860                 -10.12                 -28.64      8    15
# 175432                   0.28                 -14.04      8    16
# 306444                  -8.82                 -28.05      2    15
# 68656                    4.63                  33.71      7    16
# 327438                 -17.87                  14.23      7    16
#
# [352604 rows x 247 columns]

# %%
test_df
# Out:
#         index  lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333                              339.88
# 1      375735  0.0  0.833333                              334.63
# 2      375736  0.0  0.833333                              337.83
# 3      375737  0.0  0.833333                              345.81
# 4      375738  0.0  0.833333                              357.39
# ...       ...  ...       ...                                 ...
# 31349  407083  1.0  0.866667                               62.72
# 31350  407084  1.0  0.866667                               73.41
# 31351  407085  1.0  0.866667                               70.00
# 31352  407086  1.0  0.866667                               79.81
# 31353  407087  1.0  0.866667                               86.17
#
#        nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                         30.88                     30.92
# 1                         30.88                     30.92
# 2                         30.88                     30.92
# 3                         30.88                     30.92
# 4                         30.88                     30.92
# ...                         ...                       ...
# 31349                      4.60                      8.71
# 31350                      4.60                      8.71
# 31351                      4.60                      8.71
# 31352                      4.60                      8.71
# 31353                      4.60                      8.71
#
#        nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                        29.17                    31.02
# 1                        29.17                    31.02
# 2                        29.17                    31.02
# 3                        29.17                    31.02
# 4                        29.17                    31.02
# ...                        ...                      ...
# 31349                     6.05                    10.08
# 31350                     6.05                    10.08
# 31351                     6.05                    10.08
# 31352                     6.05                    10.08
# 31353                     6.05                    10.08
#
#        nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 0                        29.47                        30.93  ...
# 1                        29.47                        30.93  ...
# 2                        29.47                        30.93  ...
# 3                        29.47                        30.93  ...
# 4                        29.47                        30.93  ...
# ...                        ...                          ...  ...
# 31349                     6.39                         8.42  ...
# 31350                     6.39                         8.42  ...
# 31351                     6.39                         8.42  ...
# 31352                     6.39                         8.42  ...
# 31353                     6.39                         8.42  ...
#
#        wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 0                     -29.25                  40.88                  -8.31
# 1                     -28.62                  45.37                  -5.42
# 2                     -27.67                  49.76                  -1.31
# 3                     -19.32                  52.62                  -0.44
# 4                      -9.89                  51.23                  -7.57
# ...                      ...                    ...                    ...
# 31349                  32.39                  38.82                   7.42
# 31350                  26.23                  37.64                  13.01
# 31351                  21.06                  36.53                  14.15
# 31352                  20.42                  36.05                   6.38
# 31353                  26.17                  30.68                  -3.24
#
#        wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 0                      14.91                 -24.62                  31.05
# 1                      16.97                 -23.94                  28.84
# 2                      21.44                 -19.06                  26.85
# 3                      21.65                 -23.12                  23.70
# 4                      19.86                 -30.56                  20.66
# ...                      ...                    ...                    ...
# 31349                  11.75                 -23.62                  -0.24
# 31350                  17.84                 -22.05                  -3.03
# 31351                  23.12                 -25.60                  -5.88
# 31352                  29.00                 -27.06                  -1.42
# 31353                  27.70                 -28.75                   0.15
#
#        wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 0                     -23.69                   6.27     11    22
# 1                     -20.61                  14.16     11    22
# 2                     -16.78                  13.42     11    22
# 3                     -18.62                  10.69     11    22
# 4                     -25.08                  19.64     11    22
# ...                      ...                    ...    ...   ...
# 31349                  -5.94                  51.23     12    22
# 31350                   1.31                  51.45     12    22
# 31351                   9.32                  45.32     12    22
# 31352                  16.06                  31.88     12    22
# 31353                  16.64                  19.27     12    22
#
# [31354 rows x 246 columns]

# %%
train_df=train_df.astype('float')
test_df=test_df.astype('float')

# %%
y_train_df=train_df['contest-tmp2m-14d__tmp2m']
X_train_df=train_df.drop('contest-tmp2m-14d__tmp2m', axis=1)
type(y_train_df)
y_train_df=y_train_df.to_frame()
type(y_train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_df=normanlize_data(X_train_df,train_df)
test_df=normanlize_data(test_df,train_df)

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352604 entries, 240466 to 327438
# Columns: 246 entries, index to year
# dtypes: float64(246)
# memory usage: 664.5 MB

# %% [markdown]
# # Model

# %%
NN_model = Sequential()

#I might need to change the input_dim to give the actual dimentions
#Instead of being just 1
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = 246, activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               31616
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 256)               65792
#
#  dense_6 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 328,065
# Trainable params: 328,065
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-22 16:55:21.255586: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-02-22 16:55:21.255649: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
checkpoint_name = 'Weights--.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train_df, y_train_df, epochs=20, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 8807/8816 [============================>.] - ETA: 0s - loss: 1.1111 - mean_absolute_error: 1.1111
# Epoch 1: val_loss improved from inf to 0.80170, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 50s 6ms/step - loss: 1.1109 - mean_absolute_error: 1.1109 - val_loss: 0.8017 - val_mean_absolute_error: 0.8017
# Epoch 2/20
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.8272 - mean_absolute_error: 0.8272
# Epoch 2: val_loss did not improve from 0.80170
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.8271 - mean_absolute_error: 0.8271 - val_loss: 0.8445 - val_mean_absolute_error: 0.8445
# Epoch 3/20
# 8816/8816 [==============================] - ETA: 0s - loss: 0.7458 - mean_absolute_error: 0.7458
# Epoch 3: val_loss improved from 0.80170 to 0.68177, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.7458 - mean_absolute_error: 0.7458 - val_loss: 0.6818 - val_mean_absolute_error: 0.6818
# Epoch 4/20
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.6909 - mean_absolute_error: 0.6909
# Epoch 4: val_loss did not improve from 0.68177
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.6910 - mean_absolute_error: 0.6910 - val_loss: 0.6948 - val_mean_absolute_error: 0.6948
# Epoch 5/20
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.6619 - mean_absolute_error: 0.6619
# Epoch 5: val_loss did not improve from 0.68177
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.6619 - mean_absolute_error: 0.6619 - val_loss: 0.6976 - val_mean_absolute_error: 0.6976
# Epoch 6/20
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.6340 - mean_absolute_error: 0.6340
# Epoch 6: val_loss did not improve from 0.68177
# 8816/8816 [==============================] - 49s 6ms/step - loss: 0.6340 - mean_absolute_error: 0.6340 - val_loss: 0.7427 - val_mean_absolute_error: 0.7427
# Epoch 7/20
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.6127 - mean_absolute_error: 0.6127
# Epoch 7: val_loss improved from 0.68177 to 0.57077, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.6127 - mean_absolute_error: 0.6127 - val_loss: 0.5708 - val_mean_absolute_error: 0.5708
# Epoch 8/20
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.5939 - mean_absolute_error: 0.5939
# Epoch 8: val_loss did not improve from 0.57077
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.5939 - mean_absolute_error: 0.5939 - val_loss: 0.6987 - val_mean_absolute_error: 0.6987
# Epoch 9/20
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.5766 - mean_absolute_error: 0.5766
# Epoch 9: val_loss did not improve from 0.57077
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.5766 - mean_absolute_error: 0.5766 - val_loss: 0.5985 - val_mean_absolute_error: 0.5985
# Epoch 10/20
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.5659 - mean_absolute_error: 0.5659
# Epoch 10: val_loss did not improve from 0.57077
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.5659 - mean_absolute_error: 0.5659 - val_loss: 0.6001 - val_mean_absolute_error: 0.6001
# Epoch 11/20
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.5521 - mean_absolute_error: 0.5521
# Epoch 11: val_loss improved from 0.57077 to 0.51765, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.5522 - mean_absolute_error: 0.5522 - val_loss: 0.5176 - val_mean_absolute_error: 0.5176
# Epoch 12/20
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5423 - mean_absolute_error: 0.5423
# Epoch 12: val_loss did not improve from 0.51765
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.5423 - mean_absolute_error: 0.5423 - val_loss: 0.5485 - val_mean_absolute_error: 0.5485
# Epoch 13/20
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5316 - mean_absolute_error: 0.5316
# Epoch 13: val_loss did not improve from 0.51765
# 8816/8816 [==============================] - 48s 5ms/step - loss: 0.5316 - mean_absolute_error: 0.5316 - val_loss: 0.5189 - val_mean_absolute_error: 0.5189
# Epoch 14/20
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.5219 - mean_absolute_error: 0.5219
# Epoch 14: val_loss improved from 0.51765 to 0.51618, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.5219 - mean_absolute_error: 0.5219 - val_loss: 0.5162 - val_mean_absolute_error: 0.5162
# Epoch 15/20
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5167 - mean_absolute_error: 0.5167
# Epoch 15: val_loss did not improve from 0.51618
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.5167 - mean_absolute_error: 0.5167 - val_loss: 0.6116 - val_mean_absolute_error: 0.6116
# Epoch 16/20
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.5082 - mean_absolute_error: 0.5082
# Epoch 16: val_loss improved from 0.51618 to 0.50351, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 47s 5ms/step - loss: 0.5082 - mean_absolute_error: 0.5082 - val_loss: 0.5035 - val_mean_absolute_error: 0.5035
# Epoch 17/20
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.5024 - mean_absolute_error: 0.5024
# Epoch 17: val_loss did not improve from 0.50351
# 8816/8816 [==============================] - 46s 5ms/step - loss: 0.5024 - mean_absolute_error: 0.5024 - val_loss: 0.5214 - val_mean_absolute_error: 0.5214
# Epoch 18/20
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.4965 - mean_absolute_error: 0.4965
# Epoch 18: val_loss improved from 0.50351 to 0.48897, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 46s 5ms/step - loss: 0.4965 - mean_absolute_error: 0.4965 - val_loss: 0.4890 - val_mean_absolute_error: 0.4890
# Epoch 19/20
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.4901 - mean_absolute_error: 0.4901
# Epoch 19: val_loss did not improve from 0.48897
# 8816/8816 [==============================] - 46s 5ms/step - loss: 0.4901 - mean_absolute_error: 0.4901 - val_loss: 0.5620 - val_mean_absolute_error: 0.5620
# Epoch 20/20
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4861 - mean_absolute_error: 0.4861
# Epoch 20: val_loss did not improve from 0.48897
# 8816/8816 [==============================] - 46s 5ms/step - loss: 0.4861 - mean_absolute_error: 0.4861 - val_loss: 0.5522 - val_mean_absolute_error: 0.5522

# %%
# Load wights file of the best model :
wights_file = f'Weights--.hdf5'  # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(test_df)
# Out:
# 980/980 [==============================] - 2s 2ms/step

# %% [markdown]
# # Saving Dataset in correct format

# %%
predictions
# Out:
# array([[25.495958 ],
#        [25.457151 ],
#        [25.290993 ],
#        ...,
#        [ 3.1250105],
#        [ 3.0506759],
#        [ 2.055704 ]], dtype=float32)

# %%
final=pd.DataFrame(predictions,columns=['contest-tmp2m-14d__tmp2m'])

# %%
i=375734
final['index']=0
while i<407088:
    final['index'][i-375734]=i
    i+=1
final
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     25.495958  375734
# 1                     25.457151  375735
# 2                     25.290993  375736
# 3                     25.367826  375737
# 4                     25.449102  375738
# ...                         ...     ...
# 31349                  5.024222  407083
# 31350                  4.517629  407084
# 31351                  3.125010  407085
# 31352                  3.050676  407086
# 31353                  2.055704  407087
#
# [31354 rows x 2 columns]

# %%
final.to_csv('/kaggle/working/wetherprediction.csv',index=False)
