# %% [markdown]
# Link to another tutorial site that I was using to figure this out:
# https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing #Convert categorical data to neumeric values

from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/widsdatathon2023/train_data.csv
# /kaggle/input/widsdatathon2023/test_data.csv
# /kaggle/input/widsdatathon2023/sample_solution.csv

# %%
keep_columns=['lat','month','contest-tmp2m-14d__tmp2m',
              'climateregions__climateregion','lon']
X_columns=[['lat','month',
              'climateregions__climateregion','lon']]

# %%
def seperate_monthly(df):
    df[['month','day','year']]=df.startdate.str.split('/',expand=True)
    df=df.drop('day', axis=1)
    df=df.drop('startdate',axis=1)
    return df

# %%
def eliminate_columns(df):
    for col in df.columns:
        if col in keep_columns:
            print(col)
        else: 
            df=df.drop(col, axis=1)
    return df

# %%
#need to come up with a different way to do this, because it is not working
def seperate_y(df):
    y_df=df['contest-tmp2m-14d__tmp2m']
    X_df=df.drop('contest-tmp2m-14d__tmp2m',axis=1)
    return y_df,X_df

# %%
def normanlize_data(df,train_df):
    for column in df.columns:
        df[column] = df[column]  /  train_df[column].abs().max()
    return df

# %%
train_df=pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
train_df=train_df.dropna(axis=0)
test_df=pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
test_df=test_df.dropna(axis=0)
train_df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                          29.02                     31.64
# 1                          29.02                     31.64
# 2                          29.02                     31.64
# 3                          29.02                     31.64
# 4                          29.02                     31.64
# ...                          ...                       ...
# 375729                     23.13                     27.20
# 375730                     23.13                     27.20
# 375731                     23.13                     27.20
# 375732                     23.13                     27.20
# 375733                     23.13                     27.20
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                         29.57                    30.73
# 1                         29.57                    30.73
# 2                         29.57                    30.73
# 3                         29.57                    30.73
# 4                         29.57                    30.73
# ...                         ...                      ...
# 375729                    20.25                    24.43
# 375730                    20.25                    24.43
# 375731                    20.25                    24.43
# 375732                    20.25                    24.43
# 375733                    20.25                    24.43
#
#         nmme0-tmp2m-34w__cfsv20  ...  wind-vwnd-925-2010-11  \
# 0                         29.71  ...                 -27.68
# 1                         29.71  ...                 -21.13
# 2                         29.71  ...                 -10.72
# 3                         29.71  ...                   0.33
# 4                         29.71  ...                   9.83
# ...                         ...  ...                    ...
# 375729                    18.35  ...                 -15.64
# 375730                    18.35  ...                  -7.59
# 375731                    18.35  ...                  -6.25
# 375732                    18.35  ...                  -7.16
# 375733                    18.35  ...                 -12.36
#
#         wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  \
# 0                      -37.21                   8.32                   9.56
# 1                      -36.57                   8.77                  21.17
# 2                      -34.16                   6.99                  32.16
# 3                      -31.04                   6.17                  39.66
# 4                      -31.80                   7.47                  38.62
# ...                       ...                    ...                    ...
# 375729                 -75.68                  -3.09                   6.93
# 375730                 -76.42                 -13.55                  13.36
# 375731                 -70.65                 -23.93                  22.62
# 375732                 -57.67                 -33.55                  32.06
# 375733                 -44.67                 -32.46                  36.25
#
#         wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  \
# 0                       -2.03                  48.13                  28.09
# 1                        4.44                  48.60                  27.41
# 2                        5.01                  48.53                  19.21
# 3                       -1.41                  50.59                   8.29
# 4                       -5.21                  54.73                  -2.58
# ...                       ...                    ...                    ...
# 375729                 -16.69                  16.98                 -13.85
# 375730                 -15.96                  20.45                 -16.36
# 375731                 -16.71                  20.28                 -15.48
# 375732                 -16.07                  16.60                 -20.61
# 375733                 -12.72                  15.98                 -22.56
#
#         wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  wind-vwnd-925-2010-20
# 0                      -13.50                  11.90                   4.58
# 1                      -23.77                  15.44                   3.42
# 2                      -33.16                  15.11                   4.82
# 3                      -37.22                  18.24                   9.74
# 4                      -42.30                  21.91                  10.95
# ...                       ...                    ...                    ...
# 375729                  50.25                 -31.33                   0.77
# 375730                  51.65                 -30.73                  10.10
# 375731                  48.58                 -18.74                   9.28
# 375732                  39.23                 -16.26                  -0.22
# 375733                  32.53                 -21.89                  -1.20
#
# [352604 rows x 246 columns]

# %%
#Shuffeling the data
train_df = train_df.sample(frac = 1)

# %%
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
train_df['climateregions__climateregion']=le.fit_transform(train_df['climateregions__climateregion'])
test_df['climateregions__climateregion']=le.fit_transform(test_df['climateregions__climateregion'])

# %%
print('training set prep')
train_df=seperate_monthly(train_df)
#train_df=eliminate_columns(train_df)
print('test set prep')
test_df=seperate_monthly(test_df)
#test_df=eliminate_columns(test_df)
# Out:
# training set prep
# test set prep

# %%
train_df
# Out:
#          index       lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 308668  308668  0.863636  0.533333                               87.38
# 170551  170551  0.545455  0.866667                              275.81
# 249101  249101  0.727273  0.566667                               59.81
# 129853  129853  0.454545  0.900000                              118.62
# 112558  112558  0.454545  0.100000                              711.58
# ...        ...       ...       ...                                 ...
# 144895  144895  0.500000  0.666667                               80.77
# 80873    80873  0.363636  0.500000                              146.89
# 146722  146722  0.500000  0.733333                              101.90
# 181403  181403  0.590909  0.366667                               17.84
# 182858  182858  0.590909  0.433333                               36.10
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 308668                     -4.64                     -2.96
# 170551                      3.61                      7.06
# 249101                     -4.01                     -2.81
# 129853                      6.87                      8.82
# 112558                     25.28                     24.68
# ...                          ...                       ...
# 144895                     -3.35                     -1.28
# 80873                       2.13                      3.86
# 146722                     -4.53                     -0.68
# 181403                     -3.96                     -0.16
# 182858                     -1.83                      0.37
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 308668                    -5.01                    -4.33
# 170551                     7.13                     5.87
# 249101                    -5.77                    -5.74
# 129853                     8.05                    10.81
# 112558                    25.25                    22.59
# ...                         ...                      ...
# 144895                    -3.37                    -1.98
# 80873                      3.13                     4.39
# 146722                     0.05                    -0.72
# 181403                    -6.36                     0.07
# 182858                    -3.68                     1.49
#
#         nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 308668                    -2.34                         0.22  ...
# 170551                     4.86                         7.87  ...
# 249101                    -1.79                        -1.96  ...
# 129853                     8.70                         9.54  ...
# 112558                    21.57                        25.57  ...
# ...                         ...                          ...  ...
# 144895                    -0.60                         1.18  ...
# 80873                      3.02                         3.06  ...
# 146722                    -1.35                         0.27  ...
# 181403                    -0.71                         0.21  ...
# 182858                     0.83                        -3.73  ...
#
#         wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 308668                   7.07                  -4.76                 -42.59
# 170551                  11.57                  21.19                 -20.04
# 249101                 -10.67                  42.33                   8.61
# 129853                 -34.31                   9.82                 -35.19
# 112558                   9.03                  18.10                 -33.30
# ...                       ...                    ...                    ...
# 144895                  16.76                 -27.97                 -14.79
# 80873                  -33.54                   1.65                 -20.84
# 146722                   4.55                   6.51                 -39.73
# 181403                  37.60                  51.95                 -10.97
# 182858                 -41.98                  50.06                   2.90
#
#         wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 308668                 -33.10                 -10.10                  34.89
# 170551                   8.28                  -4.64                  20.54
# 249101                 -35.43                  -1.16                 -10.14
# 129853                   5.12                   0.67                  10.16
# 112558                 -11.91                  33.07                  35.34
# ...                       ...                    ...                    ...
# 144895                 -13.85                 -27.72                   5.55
# 80873                    6.47                  -4.92                  16.85
# 146722                 -24.75                 -48.11                  -3.93
# 181403                 -85.80                  36.02                  -3.77
# 182858                 -28.77                  31.75                   6.15
#
#         wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 308668                   6.72                   5.17      3    15
# 170551                  35.32                  36.83      4    15
# 249101                  45.90                   8.44      3    16
# 129853                   1.05                  27.85     12    15
# 112558                   7.06                  -4.17      8    16
# ...                       ...                    ...    ...   ...
# 144895                  -3.12                 -25.84      2    15
# 80873                   11.94                  22.47     12    15
# 146722                  68.92                  16.68      2    16
# 181403                   3.64                  -1.06     12    14
# 182858                  12.90                  14.58     12    14
#
# [352604 rows x 247 columns]

# %%
test_df
# Out:
#         index  lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333                              339.88
# 1      375735  0.0  0.833333                              334.63
# 2      375736  0.0  0.833333                              337.83
# 3      375737  0.0  0.833333                              345.81
# 4      375738  0.0  0.833333                              357.39
# ...       ...  ...       ...                                 ...
# 31349  407083  1.0  0.866667                               62.72
# 31350  407084  1.0  0.866667                               73.41
# 31351  407085  1.0  0.866667                               70.00
# 31352  407086  1.0  0.866667                               79.81
# 31353  407087  1.0  0.866667                               86.17
#
#        nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                         30.88                     30.92
# 1                         30.88                     30.92
# 2                         30.88                     30.92
# 3                         30.88                     30.92
# 4                         30.88                     30.92
# ...                         ...                       ...
# 31349                      4.60                      8.71
# 31350                      4.60                      8.71
# 31351                      4.60                      8.71
# 31352                      4.60                      8.71
# 31353                      4.60                      8.71
#
#        nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                        29.17                    31.02
# 1                        29.17                    31.02
# 2                        29.17                    31.02
# 3                        29.17                    31.02
# 4                        29.17                    31.02
# ...                        ...                      ...
# 31349                     6.05                    10.08
# 31350                     6.05                    10.08
# 31351                     6.05                    10.08
# 31352                     6.05                    10.08
# 31353                     6.05                    10.08
#
#        nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 0                        29.47                        30.93  ...
# 1                        29.47                        30.93  ...
# 2                        29.47                        30.93  ...
# 3                        29.47                        30.93  ...
# 4                        29.47                        30.93  ...
# ...                        ...                          ...  ...
# 31349                     6.39                         8.42  ...
# 31350                     6.39                         8.42  ...
# 31351                     6.39                         8.42  ...
# 31352                     6.39                         8.42  ...
# 31353                     6.39                         8.42  ...
#
#        wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 0                     -29.25                  40.88                  -8.31
# 1                     -28.62                  45.37                  -5.42
# 2                     -27.67                  49.76                  -1.31
# 3                     -19.32                  52.62                  -0.44
# 4                      -9.89                  51.23                  -7.57
# ...                      ...                    ...                    ...
# 31349                  32.39                  38.82                   7.42
# 31350                  26.23                  37.64                  13.01
# 31351                  21.06                  36.53                  14.15
# 31352                  20.42                  36.05                   6.38
# 31353                  26.17                  30.68                  -3.24
#
#        wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 0                      14.91                 -24.62                  31.05
# 1                      16.97                 -23.94                  28.84
# 2                      21.44                 -19.06                  26.85
# 3                      21.65                 -23.12                  23.70
# 4                      19.86                 -30.56                  20.66
# ...                      ...                    ...                    ...
# 31349                  11.75                 -23.62                  -0.24
# 31350                  17.84                 -22.05                  -3.03
# 31351                  23.12                 -25.60                  -5.88
# 31352                  29.00                 -27.06                  -1.42
# 31353                  27.70                 -28.75                   0.15
#
#        wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 0                     -23.69                   6.27     11    22
# 1                     -20.61                  14.16     11    22
# 2                     -16.78                  13.42     11    22
# 3                     -18.62                  10.69     11    22
# 4                     -25.08                  19.64     11    22
# ...                      ...                    ...    ...   ...
# 31349                  -5.94                  51.23     12    22
# 31350                   1.31                  51.45     12    22
# 31351                   9.32                  45.32     12    22
# 31352                  16.06                  31.88     12    22
# 31353                  16.64                  19.27     12    22
#
# [31354 rows x 246 columns]

# %%
train_df=train_df.astype('float')
test_df=test_df.astype('float')

# %%
y_train_df=train_df['contest-tmp2m-14d__tmp2m']
X_train_df=train_df.drop('contest-tmp2m-14d__tmp2m', axis=1)
type(y_train_df)
y_train_df=y_train_df.to_frame()
type(y_train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_df=normanlize_data(X_train_df,train_df)
test_df=normanlize_data(test_df,train_df)

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352604 entries, 308668 to 182858
# Columns: 246 entries, index to year
# dtypes: float64(246)
# memory usage: 664.5 MB

# %% [markdown]
# # Model

# %%
NN_model = Sequential()

#I might need to change the input_dim to give the actual dimentions
#Instead of being just 1
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = 246, activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               31616
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 256)               65792
#
#  dense_6 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 328,065
# Trainable params: 328,065
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-22 16:13:52.237139: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-02-22 16:13:52.237196: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
checkpoint_name = 'Weights--.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train_df, y_train_df, epochs=50, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 1.1177 - mean_absolute_error: 1.1177
# Epoch 1: val_loss improved from inf to 0.86098, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 40s 4ms/step - loss: 1.1178 - mean_absolute_error: 1.1178 - val_loss: 0.8610 - val_mean_absolute_error: 0.8610
# Epoch 2/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.8381 - mean_absolute_error: 0.8381
# Epoch 2: val_loss improved from 0.86098 to 0.77272, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.8380 - mean_absolute_error: 0.8380 - val_loss: 0.7727 - val_mean_absolute_error: 0.7727
# Epoch 3/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.7632 - mean_absolute_error: 0.7632
# Epoch 3: val_loss did not improve from 0.77272
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.7632 - mean_absolute_error: 0.7632 - val_loss: 0.8114 - val_mean_absolute_error: 0.8114
# Epoch 4/50
# 8816/8816 [==============================] - ETA: 0s - loss: 0.7084 - mean_absolute_error: 0.7084
# Epoch 4: val_loss did not improve from 0.77272
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.7084 - mean_absolute_error: 0.7084 - val_loss: 0.8351 - val_mean_absolute_error: 0.8351
# Epoch 5/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.6677 - mean_absolute_error: 0.6677
# Epoch 5: val_loss improved from 0.77272 to 0.61778, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.6677 - mean_absolute_error: 0.6677 - val_loss: 0.6178 - val_mean_absolute_error: 0.6178
# Epoch 6/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.6404 - mean_absolute_error: 0.6404
# Epoch 6: val_loss did not improve from 0.61778
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.6404 - mean_absolute_error: 0.6404 - val_loss: 0.6435 - val_mean_absolute_error: 0.6435
# Epoch 7/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.6183 - mean_absolute_error: 0.6183
# Epoch 7: val_loss improved from 0.61778 to 0.59715, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.6183 - mean_absolute_error: 0.6183 - val_loss: 0.5971 - val_mean_absolute_error: 0.5971
# Epoch 8/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.5980 - mean_absolute_error: 0.5980
# Epoch 8: val_loss did not improve from 0.59715
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5980 - mean_absolute_error: 0.5980 - val_loss: 0.6185 - val_mean_absolute_error: 0.6185
# Epoch 9/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5829 - mean_absolute_error: 0.5829
# Epoch 9: val_loss improved from 0.59715 to 0.59592, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.5829 - mean_absolute_error: 0.5829 - val_loss: 0.5959 - val_mean_absolute_error: 0.5959
# Epoch 10/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.5704 - mean_absolute_error: 0.5704
# Epoch 10: val_loss improved from 0.59592 to 0.54209, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.5704 - mean_absolute_error: 0.5704 - val_loss: 0.5421 - val_mean_absolute_error: 0.5421
# Epoch 11/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5600 - mean_absolute_error: 0.5600
# Epoch 11: val_loss improved from 0.54209 to 0.54059, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5600 - mean_absolute_error: 0.5600 - val_loss: 0.5406 - val_mean_absolute_error: 0.5406
# Epoch 12/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.5500 - mean_absolute_error: 0.5500
# Epoch 12: val_loss improved from 0.54059 to 0.52798, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5500 - mean_absolute_error: 0.5500 - val_loss: 0.5280 - val_mean_absolute_error: 0.5280
# Epoch 13/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.5398 - mean_absolute_error: 0.5398
# Epoch 13: val_loss improved from 0.52798 to 0.52236, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5398 - mean_absolute_error: 0.5398 - val_loss: 0.5224 - val_mean_absolute_error: 0.5224
# Epoch 14/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.5309 - mean_absolute_error: 0.5309
# Epoch 14: val_loss improved from 0.52236 to 0.49667, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5310 - mean_absolute_error: 0.5310 - val_loss: 0.4967 - val_mean_absolute_error: 0.4967
# Epoch 15/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.5237 - mean_absolute_error: 0.5237
# Epoch 15: val_loss did not improve from 0.49667
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5236 - mean_absolute_error: 0.5236 - val_loss: 0.5835 - val_mean_absolute_error: 0.5835
# Epoch 16/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5152 - mean_absolute_error: 0.5152
# Epoch 16: val_loss did not improve from 0.49667
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.5152 - mean_absolute_error: 0.5152 - val_loss: 0.5273 - val_mean_absolute_error: 0.5273
# Epoch 17/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.5093 - mean_absolute_error: 0.5093
# Epoch 17: val_loss did not improve from 0.49667
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.5093 - mean_absolute_error: 0.5093 - val_loss: 0.5635 - val_mean_absolute_error: 0.5635
# Epoch 18/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5045 - mean_absolute_error: 0.5045
# Epoch 18: val_loss did not improve from 0.49667
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5045 - mean_absolute_error: 0.5045 - val_loss: 0.5594 - val_mean_absolute_error: 0.5594
# Epoch 19/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4966 - mean_absolute_error: 0.4966
# Epoch 19: val_loss did not improve from 0.49667
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4967 - mean_absolute_error: 0.4967 - val_loss: 0.5558 - val_mean_absolute_error: 0.5558
# Epoch 20/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.4925 - mean_absolute_error: 0.4925
# Epoch 20: val_loss did not improve from 0.49667
# 8816/8816 [==============================] - 40s 4ms/step - loss: 0.4925 - mean_absolute_error: 0.4925 - val_loss: 0.5203 - val_mean_absolute_error: 0.5203
# Epoch 21/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4873 - mean_absolute_error: 0.4873
# Epoch 21: val_loss improved from 0.49667 to 0.48917, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4873 - mean_absolute_error: 0.4873 - val_loss: 0.4892 - val_mean_absolute_error: 0.4892
# Epoch 22/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4810 - mean_absolute_error: 0.4810
# Epoch 22: val_loss did not improve from 0.48917
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4810 - mean_absolute_error: 0.4810 - val_loss: 0.5205 - val_mean_absolute_error: 0.5205
# Epoch 23/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4770 - mean_absolute_error: 0.4770
# Epoch 23: val_loss did not improve from 0.48917
# 8816/8816 [==============================] - 40s 4ms/step - loss: 0.4770 - mean_absolute_error: 0.4770 - val_loss: 0.5614 - val_mean_absolute_error: 0.5614
# Epoch 24/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4739 - mean_absolute_error: 0.4739
# Epoch 24: val_loss did not improve from 0.48917
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4739 - mean_absolute_error: 0.4739 - val_loss: 0.5024 - val_mean_absolute_error: 0.5024
# Epoch 25/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4681 - mean_absolute_error: 0.4681
# Epoch 25: val_loss did not improve from 0.48917
# 8816/8816 [==============================] - 40s 4ms/step - loss: 0.4681 - mean_absolute_error: 0.4681 - val_loss: 0.5273 - val_mean_absolute_error: 0.5273
# Epoch 26/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.4641 - mean_absolute_error: 0.4641
# Epoch 26: val_loss did not improve from 0.48917
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.4640 - mean_absolute_error: 0.4640 - val_loss: 0.5058 - val_mean_absolute_error: 0.5058
# Epoch 27/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4602 - mean_absolute_error: 0.4602
# Epoch 27: val_loss did not improve from 0.48917
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4602 - mean_absolute_error: 0.4602 - val_loss: 0.5372 - val_mean_absolute_error: 0.5372
# Epoch 28/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4574 - mean_absolute_error: 0.4574
# Epoch 28: val_loss did not improve from 0.48917
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4575 - mean_absolute_error: 0.4575 - val_loss: 0.5424 - val_mean_absolute_error: 0.5424
# Epoch 29/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4528 - mean_absolute_error: 0.4528
# Epoch 29: val_loss did not improve from 0.48917
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4527 - mean_absolute_error: 0.4527 - val_loss: 0.6013 - val_mean_absolute_error: 0.6013
# Epoch 30/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.4503 - mean_absolute_error: 0.4503
# Epoch 30: val_loss improved from 0.48917 to 0.45949, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4503 - mean_absolute_error: 0.4503 - val_loss: 0.4595 - val_mean_absolute_error: 0.4595
# Epoch 31/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.4479 - mean_absolute_error: 0.4479
# Epoch 31: val_loss did not improve from 0.45949
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4479 - mean_absolute_error: 0.4479 - val_loss: 0.5270 - val_mean_absolute_error: 0.5270
# Epoch 32/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4453 - mean_absolute_error: 0.4453
# Epoch 32: val_loss improved from 0.45949 to 0.44568, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 41s 5ms/step - loss: 0.4453 - mean_absolute_error: 0.4453 - val_loss: 0.4457 - val_mean_absolute_error: 0.4457
# Epoch 33/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4404 - mean_absolute_error: 0.4404
# Epoch 33: val_loss improved from 0.44568 to 0.44339, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 42s 5ms/step - loss: 0.4404 - mean_absolute_error: 0.4404 - val_loss: 0.4434 - val_mean_absolute_error: 0.4434
# Epoch 34/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.4386 - mean_absolute_error: 0.4386
# Epoch 34: val_loss improved from 0.44339 to 0.43556, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 42s 5ms/step - loss: 0.4386 - mean_absolute_error: 0.4386 - val_loss: 0.4356 - val_mean_absolute_error: 0.4356
# Epoch 35/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.4364 - mean_absolute_error: 0.4364
# Epoch 35: val_loss improved from 0.43556 to 0.42900, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 42s 5ms/step - loss: 0.4364 - mean_absolute_error: 0.4364 - val_loss: 0.4290 - val_mean_absolute_error: 0.4290
# Epoch 36/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4324 - mean_absolute_error: 0.4324
# Epoch 36: val_loss improved from 0.42900 to 0.42590, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 41s 5ms/step - loss: 0.4324 - mean_absolute_error: 0.4324 - val_loss: 0.4259 - val_mean_absolute_error: 0.4259
# Epoch 37/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4307 - mean_absolute_error: 0.4307
# Epoch 37: val_loss did not improve from 0.42590
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4307 - mean_absolute_error: 0.4307 - val_loss: 0.4396 - val_mean_absolute_error: 0.4396
# Epoch 38/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4295 - mean_absolute_error: 0.4295
# Epoch 38: val_loss did not improve from 0.42590
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4295 - mean_absolute_error: 0.4295 - val_loss: 0.4628 - val_mean_absolute_error: 0.4628
# Epoch 39/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4262 - mean_absolute_error: 0.4262
# Epoch 39: val_loss did not improve from 0.42590
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4262 - mean_absolute_error: 0.4262 - val_loss: 0.4436 - val_mean_absolute_error: 0.4436
# Epoch 40/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4217 - mean_absolute_error: 0.4217
# Epoch 40: val_loss did not improve from 0.42590
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4218 - mean_absolute_error: 0.4218 - val_loss: 0.4604 - val_mean_absolute_error: 0.4604
# Epoch 41/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4219 - mean_absolute_error: 0.4219
# Epoch 41: val_loss improved from 0.42590 to 0.41101, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4219 - mean_absolute_error: 0.4219 - val_loss: 0.4110 - val_mean_absolute_error: 0.4110
# Epoch 42/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4204 - mean_absolute_error: 0.4204
# Epoch 42: val_loss did not improve from 0.41101
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4204 - mean_absolute_error: 0.4204 - val_loss: 0.4506 - val_mean_absolute_error: 0.4506
# Epoch 43/50
# 8803/8816 [============================>.] - ETA: 0s - loss: 0.4167 - mean_absolute_error: 0.4167
# Epoch 43: val_loss did not improve from 0.41101
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4166 - mean_absolute_error: 0.4166 - val_loss: 0.4821 - val_mean_absolute_error: 0.4821
# Epoch 44/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4146 - mean_absolute_error: 0.4146
# Epoch 44: val_loss did not improve from 0.41101
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4146 - mean_absolute_error: 0.4146 - val_loss: 0.4241 - val_mean_absolute_error: 0.4241
# Epoch 45/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4123 - mean_absolute_error: 0.4123
# Epoch 45: val_loss did not improve from 0.41101
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4124 - mean_absolute_error: 0.4124 - val_loss: 0.4147 - val_mean_absolute_error: 0.4147
# Epoch 46/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4099 - mean_absolute_error: 0.4099
# Epoch 46: val_loss improved from 0.41101 to 0.40745, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4099 - mean_absolute_error: 0.4099 - val_loss: 0.4074 - val_mean_absolute_error: 0.4074
# Epoch 47/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4092 - mean_absolute_error: 0.4092
# Epoch 47: val_loss did not improve from 0.40745
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.4092 - mean_absolute_error: 0.4092 - val_loss: 0.4099 - val_mean_absolute_error: 0.4099
# Epoch 48/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4072 - mean_absolute_error: 0.4072
# Epoch 48: val_loss did not improve from 0.40745
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.4072 - mean_absolute_error: 0.4072 - val_loss: 0.4177 - val_mean_absolute_error: 0.4177
# Epoch 49/50
# 8816/8816 [==============================] - ETA: 0s - loss: 0.4050 - mean_absolute_error: 0.4050
# Epoch 49: val_loss did not improve from 0.40745
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4050 - mean_absolute_error: 0.4050 - val_loss: 0.5473 - val_mean_absolute_error: 0.5473
# Epoch 50/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4044 - mean_absolute_error: 0.4044
# Epoch 50: val_loss improved from 0.40745 to 0.40021, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4044 - mean_absolute_error: 0.4044 - val_loss: 0.4002 - val_mean_absolute_error: 0.4002

# %%
# Load wights file of the best model :
wights_file = f'Weights--.hdf5'  # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(test_df)
# Out:
# 980/980 [==============================] - 2s 2ms/step

# %% [markdown]
# # Saving Dataset in correct format

# %%
predictions
# Out:
# array([[24.886732 ],
#        [24.8764   ],
#        [24.919472 ],
#        ...,
#        [ 2.3893156],
#        [ 2.8540196],
#        [ 2.8371758]], dtype=float32)

# %%
final=pd.DataFrame(predictions,columns=['contest-tmp2m-14d__tmp2m'])

# %%
i=375734
final['index']=0
while i<407088:
    final['index'][i-375734]=i
    i+=1
final
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     24.886732  375734
# 1                     24.876400  375735
# 2                     24.919472  375736
# 3                     25.061510  375737
# 4                     25.023455  375738
# ...                         ...     ...
# 31349                  3.879155  407083
# 31350                  3.641093  407084
# 31351                  2.389316  407085
# 31352                  2.854020  407086
# 31353                  2.837176  407087
#
# [31354 rows x 2 columns]

# %%
final.to_csv('/kaggle/working/wetherprediction.csv',index=False)
