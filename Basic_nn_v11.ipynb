# %% [markdown]
# Link to another tutorial site that I was using to figure this out:
# https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing #Convert categorical data to neumeric values

from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/widsdatathon2023/train_data.csv
# /kaggle/input/widsdatathon2023/test_data.csv
# /kaggle/input/widsdatathon2023/sample_solution.csv

# %%
keep_columns=['lat','month','contest-tmp2m-14d__tmp2m',
              'climateregions__climateregion','lon']
X_columns=[['lat','month',
              'climateregions__climateregion','lon']]

# %%
def seperate_monthly(df):
    df[['month','day','year']]=df.startdate.str.split('/',expand=True)
    df=df.drop('day', axis=1)
    df=df.drop('startdate',axis=1)
    return df

# %%
def eliminate_columns(df):
    for col in df.columns:
        if col in keep_columns:
            print(col)
        else: 
            df=df.drop(col, axis=1)
    return df

# %%
#need to come up with a different way to do this, because it is not working
def seperate_y(df):
    y_df=df['contest-tmp2m-14d__tmp2m']
    X_df=df.drop('contest-tmp2m-14d__tmp2m',axis=1)
    return y_df,X_df

# %%
def normanlize_data(df,train_df):
    for column in df.columns:
        df[column] = df[column]  /  train_df[column].abs().max()
    return df

# %%
train_df=pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
train_df=train_df.dropna(axis=0)
test_df=pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
test_df=test_df.dropna(axis=0)
train_df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                          29.02                     31.64
# 1                          29.02                     31.64
# 2                          29.02                     31.64
# 3                          29.02                     31.64
# 4                          29.02                     31.64
# ...                          ...                       ...
# 375729                     23.13                     27.20
# 375730                     23.13                     27.20
# 375731                     23.13                     27.20
# 375732                     23.13                     27.20
# 375733                     23.13                     27.20
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                         29.57                    30.73
# 1                         29.57                    30.73
# 2                         29.57                    30.73
# 3                         29.57                    30.73
# 4                         29.57                    30.73
# ...                         ...                      ...
# 375729                    20.25                    24.43
# 375730                    20.25                    24.43
# 375731                    20.25                    24.43
# 375732                    20.25                    24.43
# 375733                    20.25                    24.43
#
#         nmme0-tmp2m-34w__cfsv20  ...  wind-vwnd-925-2010-11  \
# 0                         29.71  ...                 -27.68
# 1                         29.71  ...                 -21.13
# 2                         29.71  ...                 -10.72
# 3                         29.71  ...                   0.33
# 4                         29.71  ...                   9.83
# ...                         ...  ...                    ...
# 375729                    18.35  ...                 -15.64
# 375730                    18.35  ...                  -7.59
# 375731                    18.35  ...                  -6.25
# 375732                    18.35  ...                  -7.16
# 375733                    18.35  ...                 -12.36
#
#         wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  \
# 0                      -37.21                   8.32                   9.56
# 1                      -36.57                   8.77                  21.17
# 2                      -34.16                   6.99                  32.16
# 3                      -31.04                   6.17                  39.66
# 4                      -31.80                   7.47                  38.62
# ...                       ...                    ...                    ...
# 375729                 -75.68                  -3.09                   6.93
# 375730                 -76.42                 -13.55                  13.36
# 375731                 -70.65                 -23.93                  22.62
# 375732                 -57.67                 -33.55                  32.06
# 375733                 -44.67                 -32.46                  36.25
#
#         wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  \
# 0                       -2.03                  48.13                  28.09
# 1                        4.44                  48.60                  27.41
# 2                        5.01                  48.53                  19.21
# 3                       -1.41                  50.59                   8.29
# 4                       -5.21                  54.73                  -2.58
# ...                       ...                    ...                    ...
# 375729                 -16.69                  16.98                 -13.85
# 375730                 -15.96                  20.45                 -16.36
# 375731                 -16.71                  20.28                 -15.48
# 375732                 -16.07                  16.60                 -20.61
# 375733                 -12.72                  15.98                 -22.56
#
#         wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  wind-vwnd-925-2010-20
# 0                      -13.50                  11.90                   4.58
# 1                      -23.77                  15.44                   3.42
# 2                      -33.16                  15.11                   4.82
# 3                      -37.22                  18.24                   9.74
# 4                      -42.30                  21.91                  10.95
# ...                       ...                    ...                    ...
# 375729                  50.25                 -31.33                   0.77
# 375730                  51.65                 -30.73                  10.10
# 375731                  48.58                 -18.74                   9.28
# 375732                  39.23                 -16.26                  -0.22
# 375733                  32.53                 -21.89                  -1.20
#
# [352604 rows x 246 columns]

# %%
#Shuffeling the data
train_df = train_df.sample(frac = 1)

# %%
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
train_df['climateregions__climateregion']=le.fit_transform(train_df['climateregions__climateregion'])
test_df['climateregions__climateregion']=le.fit_transform(test_df['climateregions__climateregion'])

# %%
print('training set prep')
train_df=seperate_monthly(train_df)
#train_df=eliminate_columns(train_df)
print('test set prep')
test_df=seperate_monthly(test_df)
#test_df=eliminate_columns(test_df)
# Out:
# training set prep
# test set prep

# %%
train_df
# Out:
#          index       lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 34620    34620  0.227273  0.833333                              244.01
# 260830  260830  0.772727  0.166667                              214.02
# 360712  360712  1.000000  0.200000                              526.69
# 275455  275455  0.772727  0.833333                              199.86
# 69377    69377  0.318182  0.833333                              688.21
# ...        ...       ...       ...                                 ...
# 260195  260195  0.772727  0.133333                              686.05
# 240237  240237  0.727273  0.166667                               26.33
# 238477  238477  0.727273  0.100000                               87.42
# 342972  342972  0.954545  0.233333                                5.54
# 128219  128219  0.454545  0.833333                              572.75
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 34620                      18.22                     20.76
# 260830                      1.97                      3.65
# 360712                     17.53                     23.29
# 275455                      3.24                      6.26
# 69377                      27.75                     31.24
# ...                          ...                       ...
# 260195                     13.85                     14.01
# 240237                      0.23                      0.16
# 238477                     -0.20                      0.49
# 342972                     -4.57                     -2.19
# 128219                     21.17                     26.33
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 34620                     17.35                    19.29
# 260830                     2.21                     2.92
# 360712                    13.78                    20.22
# 275455                     4.22                     6.04
# 69377                     25.47                    27.36
# ...                         ...                      ...
# 260195                    16.31                    14.82
# 240237                     1.77                     1.94
# 238477                     0.78                    -0.45
# 342972                    -6.51                    -1.34
# 128219                    20.78                    20.12
#
#         nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 34620                     17.63                        17.07  ...
# 260830                     4.43                         2.26  ...
# 360712                    16.91                        19.71  ...
# 275455                     4.25                         1.51  ...
# 69377                     25.69                        28.97  ...
# ...                         ...                          ...  ...
# 260195                    14.89                        14.79  ...
# 240237                     1.73                         1.95  ...
# 238477                     0.77                        -2.35  ...
# 342972                    -5.29                        -0.37  ...
# 128219                    18.39                        22.26  ...
#
#         wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 34620                   -7.84                  22.38                  -9.23
# 260830                 -29.46                  63.11                 -30.85
# 360712                 -19.29                   5.83                  45.87
# 275455                 -64.13                  65.20                 -39.92
# 69377                   -6.27                  17.87                 -17.84
# ...                       ...                    ...                    ...
# 260195                  10.20                   2.14                  -9.47
# 240237                 -22.72                  26.19                 -41.52
# 238477                 -37.76                  43.11                 -74.02
# 342972                 -40.03                   9.48                 -13.55
# 128219                 -17.74                  26.39                  17.20
#
#         wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 34620                  -19.53                 -21.74                   8.42
# 260830                 -17.83                  15.45                  36.87
# 360712                  -9.95                  -6.98                  25.16
# 275455                 -47.34                  29.59                  39.66
# 69377                  -35.66                 -34.88                  22.29
# ...                       ...                    ...                    ...
# 260195                  46.09                 -19.13                  43.73
# 240237                 -17.59                  -6.89                  20.52
# 238477                 -45.32                 -13.35                   5.76
# 342972                 -10.26                 -44.99                  65.30
# 128219                 -25.95                  21.39                  10.88
#
#         wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 34620                  -28.07                 -21.82      5    15
# 260830                 -50.89                  38.77      4    16
# 360712                   4.39                  -7.90      7    15
# 275455                 -64.44                  64.32      4    16
# 69377                    6.58                  -1.96      6    16
# ...                       ...                    ...    ...   ...
# 260195                  55.72                 -10.13      7    16
# 240237                   4.04                  31.79     12    15
# 238477                   0.02                   1.71      2    15
# 342972                   2.65                 -12.49      1    15
# 128219                  39.71                  11.18      6    15
#
# [352604 rows x 247 columns]

# %%
test_df
# Out:
#         index  lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333                              339.88
# 1      375735  0.0  0.833333                              334.63
# 2      375736  0.0  0.833333                              337.83
# 3      375737  0.0  0.833333                              345.81
# 4      375738  0.0  0.833333                              357.39
# ...       ...  ...       ...                                 ...
# 31349  407083  1.0  0.866667                               62.72
# 31350  407084  1.0  0.866667                               73.41
# 31351  407085  1.0  0.866667                               70.00
# 31352  407086  1.0  0.866667                               79.81
# 31353  407087  1.0  0.866667                               86.17
#
#        nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                         30.88                     30.92
# 1                         30.88                     30.92
# 2                         30.88                     30.92
# 3                         30.88                     30.92
# 4                         30.88                     30.92
# ...                         ...                       ...
# 31349                      4.60                      8.71
# 31350                      4.60                      8.71
# 31351                      4.60                      8.71
# 31352                      4.60                      8.71
# 31353                      4.60                      8.71
#
#        nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                        29.17                    31.02
# 1                        29.17                    31.02
# 2                        29.17                    31.02
# 3                        29.17                    31.02
# 4                        29.17                    31.02
# ...                        ...                      ...
# 31349                     6.05                    10.08
# 31350                     6.05                    10.08
# 31351                     6.05                    10.08
# 31352                     6.05                    10.08
# 31353                     6.05                    10.08
#
#        nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 0                        29.47                        30.93  ...
# 1                        29.47                        30.93  ...
# 2                        29.47                        30.93  ...
# 3                        29.47                        30.93  ...
# 4                        29.47                        30.93  ...
# ...                        ...                          ...  ...
# 31349                     6.39                         8.42  ...
# 31350                     6.39                         8.42  ...
# 31351                     6.39                         8.42  ...
# 31352                     6.39                         8.42  ...
# 31353                     6.39                         8.42  ...
#
#        wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 0                     -29.25                  40.88                  -8.31
# 1                     -28.62                  45.37                  -5.42
# 2                     -27.67                  49.76                  -1.31
# 3                     -19.32                  52.62                  -0.44
# 4                      -9.89                  51.23                  -7.57
# ...                      ...                    ...                    ...
# 31349                  32.39                  38.82                   7.42
# 31350                  26.23                  37.64                  13.01
# 31351                  21.06                  36.53                  14.15
# 31352                  20.42                  36.05                   6.38
# 31353                  26.17                  30.68                  -3.24
#
#        wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 0                      14.91                 -24.62                  31.05
# 1                      16.97                 -23.94                  28.84
# 2                      21.44                 -19.06                  26.85
# 3                      21.65                 -23.12                  23.70
# 4                      19.86                 -30.56                  20.66
# ...                      ...                    ...                    ...
# 31349                  11.75                 -23.62                  -0.24
# 31350                  17.84                 -22.05                  -3.03
# 31351                  23.12                 -25.60                  -5.88
# 31352                  29.00                 -27.06                  -1.42
# 31353                  27.70                 -28.75                   0.15
#
#        wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 0                     -23.69                   6.27     11    22
# 1                     -20.61                  14.16     11    22
# 2                     -16.78                  13.42     11    22
# 3                     -18.62                  10.69     11    22
# 4                     -25.08                  19.64     11    22
# ...                      ...                    ...    ...   ...
# 31349                  -5.94                  51.23     12    22
# 31350                   1.31                  51.45     12    22
# 31351                   9.32                  45.32     12    22
# 31352                  16.06                  31.88     12    22
# 31353                  16.64                  19.27     12    22
#
# [31354 rows x 246 columns]

# %%
train_df=train_df.astype('float')
test_df=test_df.astype('float')

# %%
y_train_df=train_df['contest-tmp2m-14d__tmp2m']
X_train_df=train_df.drop('contest-tmp2m-14d__tmp2m', axis=1)
type(y_train_df)
y_train_df=y_train_df.to_frame()
type(y_train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_df=normanlize_data(X_train_df,train_df)
test_df=normanlize_data(test_df,train_df)

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352604 entries, 34620 to 128219
# Columns: 246 entries, index to year
# dtypes: float64(246)
# memory usage: 664.5 MB

# %% [markdown]
# # Model

# %%
NN_model = Sequential()

#I might need to change the input_dim to give the actual dimentions
#Instead of being just 1
# The Input Layer :
NN_model.add(Dense(256, kernel_initializer='normal',input_dim = 246, activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(512, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(512, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(512, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               63232
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dense_4 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 720,641
# Trainable params: 720,641
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-22 02:47:45.379331: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-02-22 02:47:45.379387: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
checkpoint_name = 'Weights--.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train_df, y_train_df, epochs=50, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 1.0553 - mean_absolute_error: 1.0553
# Epoch 1: val_loss improved from inf to 1.08593, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 58s 7ms/step - loss: 1.0553 - mean_absolute_error: 1.0553 - val_loss: 1.0859 - val_mean_absolute_error: 1.0859
# Epoch 2/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.7891 - mean_absolute_error: 0.7891
# Epoch 2: val_loss improved from 1.08593 to 0.73873, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 62s 7ms/step - loss: 0.7891 - mean_absolute_error: 0.7891 - val_loss: 0.7387 - val_mean_absolute_error: 0.7387
# Epoch 3/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.7119 - mean_absolute_error: 0.7119
# Epoch 3: val_loss improved from 0.73873 to 0.66315, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 57s 6ms/step - loss: 0.7119 - mean_absolute_error: 0.7119 - val_loss: 0.6632 - val_mean_absolute_error: 0.6632
# Epoch 4/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.6645 - mean_absolute_error: 0.6645
# Epoch 4: val_loss improved from 0.66315 to 0.61693, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 57s 6ms/step - loss: 0.6645 - mean_absolute_error: 0.6645 - val_loss: 0.6169 - val_mean_absolute_error: 0.6169
# Epoch 5/50
# 8816/8816 [==============================] - ETA: 0s - loss: 0.6319 - mean_absolute_error: 0.6319
# Epoch 5: val_loss improved from 0.61693 to 0.59840, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 61s 7ms/step - loss: 0.6319 - mean_absolute_error: 0.6319 - val_loss: 0.5984 - val_mean_absolute_error: 0.5984
# Epoch 6/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.6040 - mean_absolute_error: 0.6040
# Epoch 6: val_loss improved from 0.59840 to 0.57063, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.6040 - mean_absolute_error: 0.6040 - val_loss: 0.5706 - val_mean_absolute_error: 0.5706
# Epoch 7/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.5855 - mean_absolute_error: 0.5855
# Epoch 7: val_loss did not improve from 0.57063
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.5855 - mean_absolute_error: 0.5855 - val_loss: 0.5944 - val_mean_absolute_error: 0.5944
# Epoch 8/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.5678 - mean_absolute_error: 0.5678
# Epoch 8: val_loss did not improve from 0.57063
# 8816/8816 [==============================] - 62s 7ms/step - loss: 0.5678 - mean_absolute_error: 0.5678 - val_loss: 0.6036 - val_mean_absolute_error: 0.6036
# Epoch 9/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5527 - mean_absolute_error: 0.5527
# Epoch 9: val_loss improved from 0.57063 to 0.55657, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 59s 7ms/step - loss: 0.5527 - mean_absolute_error: 0.5527 - val_loss: 0.5566 - val_mean_absolute_error: 0.5566
# Epoch 10/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5399 - mean_absolute_error: 0.5399
# Epoch 10: val_loss improved from 0.55657 to 0.54244, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 63s 7ms/step - loss: 0.5399 - mean_absolute_error: 0.5399 - val_loss: 0.5424 - val_mean_absolute_error: 0.5424
# Epoch 11/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.5271 - mean_absolute_error: 0.5271
# Epoch 11: val_loss improved from 0.54244 to 0.53558, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 57s 6ms/step - loss: 0.5272 - mean_absolute_error: 0.5272 - val_loss: 0.5356 - val_mean_absolute_error: 0.5356
# Epoch 12/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.5177 - mean_absolute_error: 0.5177
# Epoch 12: val_loss improved from 0.53558 to 0.52462, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.5177 - mean_absolute_error: 0.5177 - val_loss: 0.5246 - val_mean_absolute_error: 0.5246
# Epoch 13/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5100 - mean_absolute_error: 0.5100
# Epoch 13: val_loss improved from 0.52462 to 0.50117, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.5100 - mean_absolute_error: 0.5100 - val_loss: 0.5012 - val_mean_absolute_error: 0.5012
# Epoch 14/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.5011 - mean_absolute_error: 0.5011
# Epoch 14: val_loss did not improve from 0.50117
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.5011 - mean_absolute_error: 0.5011 - val_loss: 0.5230 - val_mean_absolute_error: 0.5230
# Epoch 15/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.4934 - mean_absolute_error: 0.4934
# Epoch 15: val_loss did not improve from 0.50117
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4934 - mean_absolute_error: 0.4934 - val_loss: 0.5020 - val_mean_absolute_error: 0.5020
# Epoch 16/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4854 - mean_absolute_error: 0.4854
# Epoch 16: val_loss improved from 0.50117 to 0.47005, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4854 - mean_absolute_error: 0.4854 - val_loss: 0.4700 - val_mean_absolute_error: 0.4700
# Epoch 17/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.4795 - mean_absolute_error: 0.4795
# Epoch 17: val_loss did not improve from 0.47005
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4795 - mean_absolute_error: 0.4795 - val_loss: 0.5210 - val_mean_absolute_error: 0.5210
# Epoch 18/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4744 - mean_absolute_error: 0.4744
# Epoch 18: val_loss did not improve from 0.47005
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4744 - mean_absolute_error: 0.4744 - val_loss: 0.4729 - val_mean_absolute_error: 0.4729
# Epoch 19/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4672 - mean_absolute_error: 0.4672
# Epoch 19: val_loss did not improve from 0.47005
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.4672 - mean_absolute_error: 0.4672 - val_loss: 0.5622 - val_mean_absolute_error: 0.5622
# Epoch 20/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4626 - mean_absolute_error: 0.4626
# Epoch 20: val_loss did not improve from 0.47005
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4626 - mean_absolute_error: 0.4626 - val_loss: 0.4701 - val_mean_absolute_error: 0.4701
# Epoch 21/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4573 - mean_absolute_error: 0.4573
# Epoch 21: val_loss improved from 0.47005 to 0.45880, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4573 - mean_absolute_error: 0.4573 - val_loss: 0.4588 - val_mean_absolute_error: 0.4588
# Epoch 22/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.4512 - mean_absolute_error: 0.4512
# Epoch 22: val_loss did not improve from 0.45880
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4512 - mean_absolute_error: 0.4512 - val_loss: 0.4788 - val_mean_absolute_error: 0.4788
# Epoch 23/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4455 - mean_absolute_error: 0.4455
# Epoch 23: val_loss improved from 0.45880 to 0.44497, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4455 - mean_absolute_error: 0.4455 - val_loss: 0.4450 - val_mean_absolute_error: 0.4450
# Epoch 24/50
# 8816/8816 [==============================] - ETA: 0s - loss: 0.4419 - mean_absolute_error: 0.4419
# Epoch 24: val_loss improved from 0.44497 to 0.43807, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4419 - mean_absolute_error: 0.4419 - val_loss: 0.4381 - val_mean_absolute_error: 0.4381
# Epoch 25/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4388 - mean_absolute_error: 0.4388
# Epoch 25: val_loss improved from 0.43807 to 0.43229, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4388 - mean_absolute_error: 0.4388 - val_loss: 0.4323 - val_mean_absolute_error: 0.4323
# Epoch 26/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4344 - mean_absolute_error: 0.4344
# Epoch 26: val_loss improved from 0.43229 to 0.42292, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4344 - mean_absolute_error: 0.4344 - val_loss: 0.4229 - val_mean_absolute_error: 0.4229
# Epoch 27/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4307 - mean_absolute_error: 0.4307
# Epoch 27: val_loss did not improve from 0.42292
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.4307 - mean_absolute_error: 0.4307 - val_loss: 0.4358 - val_mean_absolute_error: 0.4358
# Epoch 28/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4263 - mean_absolute_error: 0.4263
# Epoch 28: val_loss did not improve from 0.42292
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.4263 - mean_absolute_error: 0.4263 - val_loss: 0.5043 - val_mean_absolute_error: 0.5043
# Epoch 29/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4230 - mean_absolute_error: 0.4230
# Epoch 29: val_loss improved from 0.42292 to 0.42242, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4231 - mean_absolute_error: 0.4231 - val_loss: 0.4224 - val_mean_absolute_error: 0.4224
# Epoch 30/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4194 - mean_absolute_error: 0.4194
# Epoch 30: val_loss did not improve from 0.42242
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4194 - mean_absolute_error: 0.4194 - val_loss: 0.4483 - val_mean_absolute_error: 0.4483
# Epoch 31/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4156 - mean_absolute_error: 0.4156
# Epoch 31: val_loss improved from 0.42242 to 0.41218, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4156 - mean_absolute_error: 0.4156 - val_loss: 0.4122 - val_mean_absolute_error: 0.4122
# Epoch 32/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.4121 - mean_absolute_error: 0.4121
# Epoch 32: val_loss improved from 0.41218 to 0.40479, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.4121 - mean_absolute_error: 0.4121 - val_loss: 0.4048 - val_mean_absolute_error: 0.4048
# Epoch 33/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4092 - mean_absolute_error: 0.4092
# Epoch 33: val_loss did not improve from 0.40479
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.4092 - mean_absolute_error: 0.4092 - val_loss: 0.4049 - val_mean_absolute_error: 0.4049
# Epoch 34/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4057 - mean_absolute_error: 0.4057
# Epoch 34: val_loss improved from 0.40479 to 0.40102, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.4057 - mean_absolute_error: 0.4057 - val_loss: 0.4010 - val_mean_absolute_error: 0.4010
# Epoch 35/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4041 - mean_absolute_error: 0.4041
# Epoch 35: val_loss improved from 0.40102 to 0.39698, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.4041 - mean_absolute_error: 0.4041 - val_loss: 0.3970 - val_mean_absolute_error: 0.3970
# Epoch 36/50
# 8816/8816 [==============================] - ETA: 0s - loss: 0.4014 - mean_absolute_error: 0.4014
# Epoch 36: val_loss did not improve from 0.39698
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.4014 - mean_absolute_error: 0.4014 - val_loss: 0.4002 - val_mean_absolute_error: 0.4002
# Epoch 37/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.3975 - mean_absolute_error: 0.3975
# Epoch 37: val_loss did not improve from 0.39698
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.3975 - mean_absolute_error: 0.3975 - val_loss: 0.4277 - val_mean_absolute_error: 0.4277
# Epoch 38/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.3964 - mean_absolute_error: 0.3964
# Epoch 38: val_loss did not improve from 0.39698
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.3963 - mean_absolute_error: 0.3963 - val_loss: 0.4013 - val_mean_absolute_error: 0.4013
# Epoch 39/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.3934 - mean_absolute_error: 0.3934
# Epoch 39: val_loss did not improve from 0.39698
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.3934 - mean_absolute_error: 0.3934 - val_loss: 0.4096 - val_mean_absolute_error: 0.4096
# Epoch 40/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.3920 - mean_absolute_error: 0.3920
# Epoch 40: val_loss improved from 0.39698 to 0.39309, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.3920 - mean_absolute_error: 0.3920 - val_loss: 0.3931 - val_mean_absolute_error: 0.3931
# Epoch 41/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.3888 - mean_absolute_error: 0.3888
# Epoch 41: val_loss improved from 0.39309 to 0.38984, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.3888 - mean_absolute_error: 0.3888 - val_loss: 0.3898 - val_mean_absolute_error: 0.3898
# Epoch 42/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.3871 - mean_absolute_error: 0.3871
# Epoch 42: val_loss improved from 0.38984 to 0.38788, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.3871 - mean_absolute_error: 0.3871 - val_loss: 0.3879 - val_mean_absolute_error: 0.3879
# Epoch 43/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.3849 - mean_absolute_error: 0.3849
# Epoch 43: val_loss did not improve from 0.38788
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.3849 - mean_absolute_error: 0.3849 - val_loss: 0.3912 - val_mean_absolute_error: 0.3912
# Epoch 44/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.3832 - mean_absolute_error: 0.3832
# Epoch 44: val_loss did not improve from 0.38788
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.3832 - mean_absolute_error: 0.3832 - val_loss: 0.4009 - val_mean_absolute_error: 0.4009
# Epoch 45/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.3818 - mean_absolute_error: 0.3818
# Epoch 45: val_loss improved from 0.38788 to 0.38279, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 55s 6ms/step - loss: 0.3818 - mean_absolute_error: 0.3818 - val_loss: 0.3828 - val_mean_absolute_error: 0.3828
# Epoch 46/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.3793 - mean_absolute_error: 0.3793
# Epoch 46: val_loss did not improve from 0.38279
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.3793 - mean_absolute_error: 0.3793 - val_loss: 0.4100 - val_mean_absolute_error: 0.4100
# Epoch 47/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.3771 - mean_absolute_error: 0.3771
# Epoch 47: val_loss did not improve from 0.38279
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.3771 - mean_absolute_error: 0.3771 - val_loss: 0.3867 - val_mean_absolute_error: 0.3867
# Epoch 48/50
# 8811/8816 [============================>.] - ETA: 0s - loss: 0.3749 - mean_absolute_error: 0.3749
# Epoch 48: val_loss did not improve from 0.38279
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.3749 - mean_absolute_error: 0.3749 - val_loss: 0.4265 - val_mean_absolute_error: 0.4265
# Epoch 49/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.3729 - mean_absolute_error: 0.3729
# Epoch 49: val_loss did not improve from 0.38279
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.3729 - mean_absolute_error: 0.3729 - val_loss: 0.3917 - val_mean_absolute_error: 0.3917
# Epoch 50/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.3716 - mean_absolute_error: 0.3716
# Epoch 50: val_loss improved from 0.38279 to 0.37535, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 56s 6ms/step - loss: 0.3716 - mean_absolute_error: 0.3716 - val_loss: 0.3753 - val_mean_absolute_error: 0.3753

# %%
# Load wights file of the best model :
wights_file = f'Weights--.hdf5'  # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(test_df)
# Out:
# 980/980 [==============================] - 2s 2ms/step

# %% [markdown]
# # Saving Dataset in correct format

# %%
predictions
# Out:
# array([[25.711226  ],
#        [25.664059  ],
#        [25.683708  ],
#        ...,
#        [ 0.11119562],
#        [ 0.06579924],
#        [-0.23506087]], dtype=float32)

# %%
final=pd.DataFrame(predictions,columns=['contest-tmp2m-14d__tmp2m'])

# %%
i=375734
final['index']=0
while i<407088:
    final['index'][i-375734]=i
    i+=1
final
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     25.711226  375734
# 1                     25.664059  375735
# 2                     25.683708  375736
# 3                     25.743687  375737
# 4                     25.872469  375738
# ...                         ...     ...
# 31349                  1.329945  407083
# 31350                  0.881962  407084
# 31351                  0.111196  407085
# 31352                  0.065799  407086
# 31353                 -0.235061  407087
#
# [31354 rows x 2 columns]

# %%
final.to_csv('/kaggle/working/wetherprediction.csv',index=False)
