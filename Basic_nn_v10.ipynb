# %% [markdown]
# Link to another tutorial site that I was using to figure this out:
# https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import preprocessing #Convert categorical data to neumeric values

from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/widsdatathon2023/train_data.csv
# /kaggle/input/widsdatathon2023/test_data.csv
# /kaggle/input/widsdatathon2023/sample_solution.csv

# %%
keep_columns=['lat','month','contest-tmp2m-14d__tmp2m',
              'climateregions__climateregion','lon']
X_columns=[['lat','month',
              'climateregions__climateregion','lon']]

# %%
def seperate_monthly(df):
    df[['month','day','year']]=df.startdate.str.split('/',expand=True)
    df=df.drop('day', axis=1)
    df=df.drop('startdate',axis=1)
    return df

# %%
def eliminate_columns(df):
    for col in df.columns:
        if col in keep_columns:
            print(col)
        else: 
            df=df.drop(col, axis=1)
    return df

# %%
#need to come up with a different way to do this, because it is not working
def seperate_y(df):
    y_df=df['contest-tmp2m-14d__tmp2m']
    X_df=df.drop('contest-tmp2m-14d__tmp2m',axis=1)
    return y_df,X_df

# %%
def normanlize_data(df,train_df):
    for column in df.columns:
        df[column] = df[column]  /  train_df[column].abs().max()
    return df

# %%
train_df=pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
train_df=train_df.dropna(axis=0)
test_df=pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
test_df=test_df.dropna(axis=0)
train_df
# Out:
#          index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0            0  0.0  0.833333    9/1/14                              237.00
# 1            1  0.0  0.833333    9/2/14                              228.90
# 2            2  0.0  0.833333    9/3/14                              220.69
# 3            3  0.0  0.833333    9/4/14                              225.28
# 4            4  0.0  0.833333    9/5/14                              237.24
# ...        ...  ...       ...       ...                                 ...
# 375729  375729  1.0  0.866667   8/27/16                              312.05
# 375730  375730  1.0  0.866667   8/28/16                              305.82
# 375731  375731  1.0  0.866667   8/29/16                              311.62
# 375732  375732  1.0  0.866667   8/30/16                              304.54
# 375733  375733  1.0  0.866667   8/31/16                              295.29
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                          29.02                     31.64
# 1                          29.02                     31.64
# 2                          29.02                     31.64
# 3                          29.02                     31.64
# 4                          29.02                     31.64
# ...                          ...                       ...
# 375729                     23.13                     27.20
# 375730                     23.13                     27.20
# 375731                     23.13                     27.20
# 375732                     23.13                     27.20
# 375733                     23.13                     27.20
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                         29.57                    30.73
# 1                         29.57                    30.73
# 2                         29.57                    30.73
# 3                         29.57                    30.73
# 4                         29.57                    30.73
# ...                         ...                      ...
# 375729                    20.25                    24.43
# 375730                    20.25                    24.43
# 375731                    20.25                    24.43
# 375732                    20.25                    24.43
# 375733                    20.25                    24.43
#
#         nmme0-tmp2m-34w__cfsv20  ...  wind-vwnd-925-2010-11  \
# 0                         29.71  ...                 -27.68
# 1                         29.71  ...                 -21.13
# 2                         29.71  ...                 -10.72
# 3                         29.71  ...                   0.33
# 4                         29.71  ...                   9.83
# ...                         ...  ...                    ...
# 375729                    18.35  ...                 -15.64
# 375730                    18.35  ...                  -7.59
# 375731                    18.35  ...                  -6.25
# 375732                    18.35  ...                  -7.16
# 375733                    18.35  ...                 -12.36
#
#         wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  \
# 0                      -37.21                   8.32                   9.56
# 1                      -36.57                   8.77                  21.17
# 2                      -34.16                   6.99                  32.16
# 3                      -31.04                   6.17                  39.66
# 4                      -31.80                   7.47                  38.62
# ...                       ...                    ...                    ...
# 375729                 -75.68                  -3.09                   6.93
# 375730                 -76.42                 -13.55                  13.36
# 375731                 -70.65                 -23.93                  22.62
# 375732                 -57.67                 -33.55                  32.06
# 375733                 -44.67                 -32.46                  36.25
#
#         wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  \
# 0                       -2.03                  48.13                  28.09
# 1                        4.44                  48.60                  27.41
# 2                        5.01                  48.53                  19.21
# 3                       -1.41                  50.59                   8.29
# 4                       -5.21                  54.73                  -2.58
# ...                       ...                    ...                    ...
# 375729                 -16.69                  16.98                 -13.85
# 375730                 -15.96                  20.45                 -16.36
# 375731                 -16.71                  20.28                 -15.48
# 375732                 -16.07                  16.60                 -20.61
# 375733                 -12.72                  15.98                 -22.56
#
#         wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  wind-vwnd-925-2010-20
# 0                      -13.50                  11.90                   4.58
# 1                      -23.77                  15.44                   3.42
# 2                      -33.16                  15.11                   4.82
# 3                      -37.22                  18.24                   9.74
# 4                      -42.30                  21.91                  10.95
# ...                       ...                    ...                    ...
# 375729                  50.25                 -31.33                   0.77
# 375730                  51.65                 -30.73                  10.10
# 375731                  48.58                 -18.74                   9.28
# 375732                  39.23                 -16.26                  -0.22
# 375733                  32.53                 -21.89                  -1.20
#
# [352604 rows x 246 columns]

# %%
#Shuffeling the data
train_df = train_df.sample(frac = 1)

# %%
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
train_df['climateregions__climateregion']=le.fit_transform(train_df['climateregions__climateregion'])
test_df['climateregions__climateregion']=le.fit_transform(test_df['climateregions__climateregion'])

# %%
print('training set prep')
train_df=seperate_monthly(train_df)
#train_df=eliminate_columns(train_df)
print('test set prep')
test_df=seperate_monthly(test_df)
#test_df=eliminate_columns(test_df)
# Out:
# training set prep
# test set prep

# %%
train_df
# Out:
#          index       lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 281765  281765  0.818182  0.200000                              657.50
# 23745    23745  0.181818  1.000000                              349.06
# 277343  277343  0.818182  0.000000                              718.25
# 269421  269421  0.772727  0.566667                              217.61
# 236466  236466  0.727273  0.000000                              572.96
# ...        ...       ...       ...                                 ...
# 231870  231870  0.681818  0.733333                               67.55
# 160237  160237  0.545455  0.400000                              115.64
# 342398  342398  0.954545  0.200000                              501.92
# 106487  106487  0.409091  0.766667                               67.09
# 53988    53988  0.272727  0.933333                              278.17
#
#         nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 281765                     19.51                     24.99
# 23745                      29.31                     30.18
# 277343                     12.59                     12.50
# 269421                     14.58                     16.05
# 236466                     23.17                     23.56
# ...                          ...                       ...
# 231870                     -2.29                      1.97
# 160237                     -4.61                     -3.15
# 342398                      7.87                      9.91
# 106487                      0.86                      3.13
# 53988                      18.11                     19.83
#
#         nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 281765                    19.34                    23.77
# 23745                     28.79                    28.19
# 277343                    11.91                    12.50
# 269421                    14.24                    16.22
# 236466                    16.58                    17.39
# ...                         ...                      ...
# 231870                    -4.58                     0.36
# 160237                    -5.40                    -2.92
# 342398                     8.57                    11.61
# 106487                     3.63                     2.44
# 53988                     18.08                    19.71
#
#         nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 281765                    21.95                        19.72  ...
# 23745                     27.96                        32.37  ...
# 277343                    13.08                        13.13  ...
# 269421                    13.83                        10.49  ...
# 236466                    18.25                        17.22  ...
# ...                         ...                          ...  ...
# 231870                    -2.09                         0.35  ...
# 160237                    -2.33                        -4.52  ...
# 342398                    10.81                        12.96  ...
# 106487                     3.41                         5.19  ...
# 53988                     16.78                        17.86  ...
#
#         wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 281765                 -21.02                  13.59                  36.39
# 23745                   25.40                 -17.06                  14.11
# 277343                 -17.74                  26.39                  17.20
# 269421                  72.86                  20.22                 -46.71
# 236466                  25.40                 -17.06                  14.11
# ...                       ...                    ...                    ...
# 231870                  66.90                 -34.88                  12.15
# 160237                 103.90                 -30.81                  56.55
# 342398                  -1.10                  17.48                  32.41
# 106487                 -13.85                  20.75                   9.01
# 53988                   52.13                  -7.44                 -15.11
#
#         wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 281765                  -7.87                  -8.81                  19.45
# 23745                   26.46                 -74.24                  19.75
# 277343                 -25.95                  21.39                  10.88
# 269421                  12.13                  10.08                  10.31
# 236466                  26.46                 -74.24                  19.75
# ...                       ...                    ...                    ...
# 231870                  18.97                  32.58                  44.51
# 160237                  20.25                  18.65                  29.48
# 342398                 -30.94                  30.58                   8.16
# 106487                 -81.74                  -3.60                   2.72
# 53988                    6.97                   2.54                  31.86
#
#         wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 281765                   3.57                  -2.22      7    15
# 23745                  -24.48                   7.02      8    15
# 277343                  39.71                  11.18      6    15
# 269421                  16.96                  17.51     10    15
# 236466                 -24.48                   7.02      8    15
# ...                       ...                    ...    ...   ...
# 231870                  53.11                 -22.36      1    15
# 160237                  33.04                 -54.58      1    15
# 342398                  42.97                  28.96      6    15
# 106487                  -6.00                  16.98      1    16
# 53988                   13.80                 -13.81      5    16
#
# [352604 rows x 247 columns]

# %%
test_df
# Out:
#         index  lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333                              339.88
# 1      375735  0.0  0.833333                              334.63
# 2      375736  0.0  0.833333                              337.83
# 3      375737  0.0  0.833333                              345.81
# 4      375738  0.0  0.833333                              357.39
# ...       ...  ...       ...                                 ...
# 31349  407083  1.0  0.866667                               62.72
# 31350  407084  1.0  0.866667                               73.41
# 31351  407085  1.0  0.866667                               70.00
# 31352  407086  1.0  0.866667                               79.81
# 31353  407087  1.0  0.866667                               86.17
#
#        nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                         30.88                     30.92
# 1                         30.88                     30.92
# 2                         30.88                     30.92
# 3                         30.88                     30.92
# 4                         30.88                     30.92
# ...                         ...                       ...
# 31349                      4.60                      8.71
# 31350                      4.60                      8.71
# 31351                      4.60                      8.71
# 31352                      4.60                      8.71
# 31353                      4.60                      8.71
#
#        nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  \
# 0                        29.17                    31.02
# 1                        29.17                    31.02
# 2                        29.17                    31.02
# 3                        29.17                    31.02
# 4                        29.17                    31.02
# ...                        ...                      ...
# 31349                     6.05                    10.08
# 31350                     6.05                    10.08
# 31351                     6.05                    10.08
# 31352                     6.05                    10.08
# 31353                     6.05                    10.08
#
#        nmme0-tmp2m-34w__cfsv20  nmme0-tmp2m-34w__gfdlflora0  ...  \
# 0                        29.47                        30.93  ...
# 1                        29.47                        30.93  ...
# 2                        29.47                        30.93  ...
# 3                        29.47                        30.93  ...
# 4                        29.47                        30.93  ...
# ...                        ...                          ...  ...
# 31349                     6.39                         8.42  ...
# 31350                     6.39                         8.42  ...
# 31351                     6.39                         8.42  ...
# 31352                     6.39                         8.42  ...
# 31353                     6.39                         8.42  ...
#
#        wind-vwnd-925-2010-13  wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  \
# 0                     -29.25                  40.88                  -8.31
# 1                     -28.62                  45.37                  -5.42
# 2                     -27.67                  49.76                  -1.31
# 3                     -19.32                  52.62                  -0.44
# 4                      -9.89                  51.23                  -7.57
# ...                      ...                    ...                    ...
# 31349                  32.39                  38.82                   7.42
# 31350                  26.23                  37.64                  13.01
# 31351                  21.06                  36.53                  14.15
# 31352                  20.42                  36.05                   6.38
# 31353                  26.17                  30.68                  -3.24
#
#        wind-vwnd-925-2010-16  wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  \
# 0                      14.91                 -24.62                  31.05
# 1                      16.97                 -23.94                  28.84
# 2                      21.44                 -19.06                  26.85
# 3                      21.65                 -23.12                  23.70
# 4                      19.86                 -30.56                  20.66
# ...                      ...                    ...                    ...
# 31349                  11.75                 -23.62                  -0.24
# 31350                  17.84                 -22.05                  -3.03
# 31351                  23.12                 -25.60                  -5.88
# 31352                  29.00                 -27.06                  -1.42
# 31353                  27.70                 -28.75                   0.15
#
#        wind-vwnd-925-2010-19  wind-vwnd-925-2010-20  month  year
# 0                     -23.69                   6.27     11    22
# 1                     -20.61                  14.16     11    22
# 2                     -16.78                  13.42     11    22
# 3                     -18.62                  10.69     11    22
# 4                     -25.08                  19.64     11    22
# ...                      ...                    ...    ...   ...
# 31349                  -5.94                  51.23     12    22
# 31350                   1.31                  51.45     12    22
# 31351                   9.32                  45.32     12    22
# 31352                  16.06                  31.88     12    22
# 31353                  16.64                  19.27     12    22
#
# [31354 rows x 246 columns]

# %%
train_df=train_df.astype('float')
test_df=test_df.astype('float')

# %%
y_train_df=train_df['contest-tmp2m-14d__tmp2m']
X_train_df=train_df.drop('contest-tmp2m-14d__tmp2m', axis=1)
type(y_train_df)
y_train_df=y_train_df.to_frame()
type(y_train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_df=normanlize_data(X_train_df,train_df)
test_df=normanlize_data(test_df,train_df)

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352604 entries, 281765 to 53988
# Columns: 246 entries, index to year
# dtypes: float64(246)
# memory usage: 664.5 MB

# %% [markdown]
# # Model

# %%
NN_model = Sequential()

#I might need to change the input_dim to give the actual dimentions
#Instead of being just 1
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = 246, activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               31616
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 196,481
# Trainable params: 196,481
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-22 01:56:23.152112: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-02-22 01:56:23.152172: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
checkpoint_name = 'Weights--.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train_df, y_train_df, epochs=50, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 8816/8816 [==============================] - ETA: 0s - loss: 1.0727 - mean_absolute_error: 1.0727
# Epoch 1: val_loss improved from inf to 0.85512, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 1.0727 - mean_absolute_error: 1.0727 - val_loss: 0.8551 - val_mean_absolute_error: 0.8551
# Epoch 2/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.8152 - mean_absolute_error: 0.8152
# Epoch 2: val_loss improved from 0.85512 to 0.72435, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.8152 - mean_absolute_error: 0.8152 - val_loss: 0.7243 - val_mean_absolute_error: 0.7243
# Epoch 3/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.7398 - mean_absolute_error: 0.7398
# Epoch 3: val_loss improved from 0.72435 to 0.72107, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.7397 - mean_absolute_error: 0.7397 - val_loss: 0.7211 - val_mean_absolute_error: 0.7211
# Epoch 4/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.6929 - mean_absolute_error: 0.6929
# Epoch 4: val_loss improved from 0.72107 to 0.63581, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.6929 - mean_absolute_error: 0.6929 - val_loss: 0.6358 - val_mean_absolute_error: 0.6358
# Epoch 5/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.6611 - mean_absolute_error: 0.6611
# Epoch 5: val_loss did not improve from 0.63581
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.6611 - mean_absolute_error: 0.6611 - val_loss: 0.7751 - val_mean_absolute_error: 0.7751
# Epoch 6/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.6323 - mean_absolute_error: 0.6323
# Epoch 6: val_loss improved from 0.63581 to 0.61297, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.6323 - mean_absolute_error: 0.6323 - val_loss: 0.6130 - val_mean_absolute_error: 0.6130
# Epoch 7/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.6115 - mean_absolute_error: 0.6115
# Epoch 7: val_loss improved from 0.61297 to 0.60180, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 40s 4ms/step - loss: 0.6115 - mean_absolute_error: 0.6115 - val_loss: 0.6018 - val_mean_absolute_error: 0.6018
# Epoch 8/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5933 - mean_absolute_error: 0.5933
# Epoch 8: val_loss improved from 0.60180 to 0.59649, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.5933 - mean_absolute_error: 0.5933 - val_loss: 0.5965 - val_mean_absolute_error: 0.5965
# Epoch 9/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5790 - mean_absolute_error: 0.5790
# Epoch 9: val_loss improved from 0.59649 to 0.57131, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5791 - mean_absolute_error: 0.5791 - val_loss: 0.5713 - val_mean_absolute_error: 0.5713
# Epoch 10/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.5662 - mean_absolute_error: 0.5662
# Epoch 10: val_loss did not improve from 0.57131
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.5662 - mean_absolute_error: 0.5662 - val_loss: 0.5768 - val_mean_absolute_error: 0.5768
# Epoch 11/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.5536 - mean_absolute_error: 0.5536
# Epoch 11: val_loss improved from 0.57131 to 0.54727, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.5536 - mean_absolute_error: 0.5536 - val_loss: 0.5473 - val_mean_absolute_error: 0.5473
# Epoch 12/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.5450 - mean_absolute_error: 0.5450
# Epoch 12: val_loss improved from 0.54727 to 0.52236, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 40s 4ms/step - loss: 0.5450 - mean_absolute_error: 0.5450 - val_loss: 0.5224 - val_mean_absolute_error: 0.5224
# Epoch 13/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.5351 - mean_absolute_error: 0.5351
# Epoch 13: val_loss did not improve from 0.52236
# 8816/8816 [==============================] - 39s 4ms/step - loss: 0.5350 - mean_absolute_error: 0.5350 - val_loss: 0.5471 - val_mean_absolute_error: 0.5471
# Epoch 14/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.5259 - mean_absolute_error: 0.5259
# Epoch 14: val_loss improved from 0.52236 to 0.50467, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5259 - mean_absolute_error: 0.5259 - val_loss: 0.5047 - val_mean_absolute_error: 0.5047
# Epoch 15/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.5176 - mean_absolute_error: 0.5176
# Epoch 15: val_loss did not improve from 0.50467
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.5176 - mean_absolute_error: 0.5176 - val_loss: 0.5142 - val_mean_absolute_error: 0.5142
# Epoch 16/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.5115 - mean_absolute_error: 0.5115
# Epoch 16: val_loss did not improve from 0.50467
# 8816/8816 [==============================] - 40s 5ms/step - loss: 0.5115 - mean_absolute_error: 0.5115 - val_loss: 0.5054 - val_mean_absolute_error: 0.5054
# Epoch 17/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.5052 - mean_absolute_error: 0.5052
# Epoch 17: val_loss did not improve from 0.50467
# 8816/8816 [==============================] - 40s 4ms/step - loss: 0.5053 - mean_absolute_error: 0.5053 - val_loss: 0.5295 - val_mean_absolute_error: 0.5295
# Epoch 18/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.4980 - mean_absolute_error: 0.4980
# Epoch 18: val_loss improved from 0.50467 to 0.48019, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 41s 5ms/step - loss: 0.4980 - mean_absolute_error: 0.4980 - val_loss: 0.4802 - val_mean_absolute_error: 0.4802
# Epoch 19/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4933 - mean_absolute_error: 0.4933
# Epoch 19: val_loss did not improve from 0.48019
# 8816/8816 [==============================] - 38s 4ms/step - loss: 0.4933 - mean_absolute_error: 0.4933 - val_loss: 0.4828 - val_mean_absolute_error: 0.4828
# Epoch 20/50
# 8800/8816 [============================>.] - ETA: 0s - loss: 0.4877 - mean_absolute_error: 0.4877
# Epoch 20: val_loss did not improve from 0.48019
# 8816/8816 [==============================] - 34s 4ms/step - loss: 0.4877 - mean_absolute_error: 0.4877 - val_loss: 0.4883 - val_mean_absolute_error: 0.4883
# Epoch 21/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4832 - mean_absolute_error: 0.4832
# Epoch 21: val_loss did not improve from 0.48019
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4832 - mean_absolute_error: 0.4832 - val_loss: 0.4938 - val_mean_absolute_error: 0.4938
# Epoch 22/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4784 - mean_absolute_error: 0.4784
# Epoch 22: val_loss improved from 0.48019 to 0.46742, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 34s 4ms/step - loss: 0.4784 - mean_absolute_error: 0.4784 - val_loss: 0.4674 - val_mean_absolute_error: 0.4674
# Epoch 23/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.4731 - mean_absolute_error: 0.4731
# Epoch 23: val_loss did not improve from 0.46742
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4731 - mean_absolute_error: 0.4731 - val_loss: 0.4825 - val_mean_absolute_error: 0.4825
# Epoch 24/50
# 8809/8816 [============================>.] - ETA: 0s - loss: 0.4690 - mean_absolute_error: 0.4690
# Epoch 24: val_loss did not improve from 0.46742
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4690 - mean_absolute_error: 0.4690 - val_loss: 0.4765 - val_mean_absolute_error: 0.4765
# Epoch 25/50
# 8807/8816 [============================>.] - ETA: 0s - loss: 0.4643 - mean_absolute_error: 0.4643
# Epoch 25: val_loss did not improve from 0.46742
# 8816/8816 [==============================] - 34s 4ms/step - loss: 0.4643 - mean_absolute_error: 0.4643 - val_loss: 0.4785 - val_mean_absolute_error: 0.4785
# Epoch 26/50
# 8815/8816 [============================>.] - ETA: 0s - loss: 0.4597 - mean_absolute_error: 0.4597
# Epoch 26: val_loss did not improve from 0.46742
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4597 - mean_absolute_error: 0.4597 - val_loss: 0.4677 - val_mean_absolute_error: 0.4677
# Epoch 27/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4561 - mean_absolute_error: 0.4561
# Epoch 27: val_loss did not improve from 0.46742
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4561 - mean_absolute_error: 0.4561 - val_loss: 0.4839 - val_mean_absolute_error: 0.4839
# Epoch 28/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4535 - mean_absolute_error: 0.4535
# Epoch 28: val_loss improved from 0.46742 to 0.46432, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 32s 4ms/step - loss: 0.4535 - mean_absolute_error: 0.4535 - val_loss: 0.4643 - val_mean_absolute_error: 0.4643
# Epoch 29/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4506 - mean_absolute_error: 0.4506
# Epoch 29: val_loss did not improve from 0.46432
# 8816/8816 [==============================] - 35s 4ms/step - loss: 0.4506 - mean_absolute_error: 0.4506 - val_loss: 0.4777 - val_mean_absolute_error: 0.4777
# Epoch 30/50
# 8802/8816 [============================>.] - ETA: 0s - loss: 0.4476 - mean_absolute_error: 0.4476
# Epoch 30: val_loss improved from 0.46432 to 0.45695, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 35s 4ms/step - loss: 0.4476 - mean_absolute_error: 0.4476 - val_loss: 0.4570 - val_mean_absolute_error: 0.4570
# Epoch 31/50
# 8805/8816 [============================>.] - ETA: 0s - loss: 0.4431 - mean_absolute_error: 0.4431
# Epoch 31: val_loss improved from 0.45695 to 0.44138, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 37s 4ms/step - loss: 0.4432 - mean_absolute_error: 0.4432 - val_loss: 0.4414 - val_mean_absolute_error: 0.4414
# Epoch 32/50
# 8810/8816 [============================>.] - ETA: 0s - loss: 0.4419 - mean_absolute_error: 0.4419
# Epoch 32: val_loss did not improve from 0.44138
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4419 - mean_absolute_error: 0.4419 - val_loss: 0.4480 - val_mean_absolute_error: 0.4480
# Epoch 33/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4389 - mean_absolute_error: 0.4389
# Epoch 33: val_loss did not improve from 0.44138
# 8816/8816 [==============================] - 35s 4ms/step - loss: 0.4390 - mean_absolute_error: 0.4390 - val_loss: 0.5394 - val_mean_absolute_error: 0.5394
# Epoch 34/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4356 - mean_absolute_error: 0.4356
# Epoch 34: val_loss did not improve from 0.44138
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4356 - mean_absolute_error: 0.4356 - val_loss: 0.4524 - val_mean_absolute_error: 0.4524
# Epoch 35/50
# 8801/8816 [============================>.] - ETA: 0s - loss: 0.4322 - mean_absolute_error: 0.4322
# Epoch 35: val_loss did not improve from 0.44138
# 8816/8816 [==============================] - 32s 4ms/step - loss: 0.4322 - mean_absolute_error: 0.4322 - val_loss: 0.4930 - val_mean_absolute_error: 0.4930
# Epoch 36/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4300 - mean_absolute_error: 0.4300
# Epoch 36: val_loss improved from 0.44138 to 0.42266, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 35s 4ms/step - loss: 0.4300 - mean_absolute_error: 0.4300 - val_loss: 0.4227 - val_mean_absolute_error: 0.4227
# Epoch 37/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4273 - mean_absolute_error: 0.4273
# Epoch 37: val_loss did not improve from 0.42266
# 8816/8816 [==============================] - 34s 4ms/step - loss: 0.4273 - mean_absolute_error: 0.4273 - val_loss: 0.4388 - val_mean_absolute_error: 0.4388
# Epoch 38/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.4252 - mean_absolute_error: 0.4252
# Epoch 38: val_loss improved from 0.42266 to 0.42053, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 32s 4ms/step - loss: 0.4252 - mean_absolute_error: 0.4252 - val_loss: 0.4205 - val_mean_absolute_error: 0.4205
# Epoch 39/50
# 8804/8816 [============================>.] - ETA: 0s - loss: 0.4233 - mean_absolute_error: 0.4233
# Epoch 39: val_loss improved from 0.42053 to 0.41558, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 34s 4ms/step - loss: 0.4234 - mean_absolute_error: 0.4234 - val_loss: 0.4156 - val_mean_absolute_error: 0.4156
# Epoch 40/50
# 8812/8816 [============================>.] - ETA: 0s - loss: 0.4212 - mean_absolute_error: 0.4212
# Epoch 40: val_loss did not improve from 0.41558
# 8816/8816 [==============================] - 35s 4ms/step - loss: 0.4212 - mean_absolute_error: 0.4212 - val_loss: 0.4207 - val_mean_absolute_error: 0.4207
# Epoch 41/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4189 - mean_absolute_error: 0.4189
# Epoch 41: val_loss did not improve from 0.41558
# 8816/8816 [==============================] - 32s 4ms/step - loss: 0.4189 - mean_absolute_error: 0.4189 - val_loss: 0.4440 - val_mean_absolute_error: 0.4440
# Epoch 42/50
# 8803/8816 [============================>.] - ETA: 0s - loss: 0.4165 - mean_absolute_error: 0.4165
# Epoch 42: val_loss did not improve from 0.41558
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4165 - mean_absolute_error: 0.4165 - val_loss: 0.4269 - val_mean_absolute_error: 0.4269
# Epoch 43/50
# 8806/8816 [============================>.] - ETA: 0s - loss: 0.4139 - mean_absolute_error: 0.4139
# Epoch 43: val_loss did not improve from 0.41558
# 8816/8816 [==============================] - 32s 4ms/step - loss: 0.4139 - mean_absolute_error: 0.4139 - val_loss: 0.4310 - val_mean_absolute_error: 0.4310
# Epoch 44/50
# 8801/8816 [============================>.] - ETA: 0s - loss: 0.4127 - mean_absolute_error: 0.4127
# Epoch 44: val_loss did not improve from 0.41558
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4127 - mean_absolute_error: 0.4127 - val_loss: 0.4263 - val_mean_absolute_error: 0.4263
# Epoch 45/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4106 - mean_absolute_error: 0.4106
# Epoch 45: val_loss did not improve from 0.41558
# 8816/8816 [==============================] - 32s 4ms/step - loss: 0.4106 - mean_absolute_error: 0.4106 - val_loss: 0.4298 - val_mean_absolute_error: 0.4298
# Epoch 46/50
# 8813/8816 [============================>.] - ETA: 0s - loss: 0.4101 - mean_absolute_error: 0.4101
# Epoch 46: val_loss improved from 0.41558 to 0.41478, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4101 - mean_absolute_error: 0.4101 - val_loss: 0.4148 - val_mean_absolute_error: 0.4148
# Epoch 47/50
# 8814/8816 [============================>.] - ETA: 0s - loss: 0.4072 - mean_absolute_error: 0.4072
# Epoch 47: val_loss did not improve from 0.41478
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4072 - mean_absolute_error: 0.4072 - val_loss: 0.4471 - val_mean_absolute_error: 0.4471
# Epoch 48/50
# 8802/8816 [============================>.] - ETA: 0s - loss: 0.4057 - mean_absolute_error: 0.4057
# Epoch 48: val_loss did not improve from 0.41478
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4058 - mean_absolute_error: 0.4058 - val_loss: 0.4532 - val_mean_absolute_error: 0.4532
# Epoch 49/50
# 8800/8816 [============================>.] - ETA: 0s - loss: 0.4040 - mean_absolute_error: 0.4040
# Epoch 49: val_loss improved from 0.41478 to 0.40576, saving model to Weights--.hdf5
# 8816/8816 [==============================] - 34s 4ms/step - loss: 0.4040 - mean_absolute_error: 0.4040 - val_loss: 0.4058 - val_mean_absolute_error: 0.4058
# Epoch 50/50
# 8808/8816 [============================>.] - ETA: 0s - loss: 0.4024 - mean_absolute_error: 0.4024
# Epoch 50: val_loss did not improve from 0.40576
# 8816/8816 [==============================] - 33s 4ms/step - loss: 0.4024 - mean_absolute_error: 0.4024 - val_loss: 0.4067 - val_mean_absolute_error: 0.4067

# %%
# Load wights file of the best model :
wights_file = f'Weights--.hdf5'  # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(test_df)
# Out:
# 980/980 [==============================] - 2s 2ms/step

# %% [markdown]
# # Saving Dataset in correct format

# %%
predictions
# Out:
# array([[25.392126 ],
#        [25.597319 ],
#        [25.654905 ],
#        ...,
#        [ 1.7917068],
#        [ 2.0890653],
#        [ 1.593354 ]], dtype=float32)

# %%
final=pd.DataFrame(predictions,columns=['contest-tmp2m-14d__tmp2m'])

# %%
i=375734
final['index']=0
while i<407088:
    final['index'][i-375734]=i
    i+=1
final
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     25.392126  375734
# 1                     25.597319  375735
# 2                     25.654905  375736
# 3                     25.672850  375737
# 4                     25.481722  375738
# ...                         ...     ...
# 31349                  3.585718  407083
# 31350                  3.005149  407084
# 31351                  1.791707  407085
# 31352                  2.089065  407086
# 31353                  1.593354  407087
#
# [31354 rows x 2 columns]

# %%
final.to_csv('/kaggle/working/wetherprediction.csv',index=False)
